# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('data_extracted_laptop.csv',encoding_errors='ignore')

# %%
df.head()
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  rom  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
#
#           warranty  rating  ...                     intel_core   brand  \
# 0  1 Year Warranty    73.0  ...      5th Gen AMD Ryzen 5 5600H      HP
# 1  1 Year Warranty    60.0  ...   12th Gen Intel Core i3 1215U      HP
# 2  1 Year Warranty    66.0  ...   12th Gen Intel Core i5 1240P  Lenovo
# 3  1 Year Warranty    71.0  ...  11th Gen Intel Core i5 11300H  Lenovo
# 4  1 Year Warranty    64.0  ...  11th Gen Intel Core i5 1155G7    Acer
#
#        Touchscreen      Gaming display_inches  resolution_width  \
# 0      touchscreen      gaming           15.6              1920
# 1  not-touchscreen  not-gaming           15.6              1920
# 2  not-touchscreen  not-gaming           14.0              2240
# 3  not-touchscreen      gaming           15.6              1920
# 4  not-touchscreen  not-gaming           15.6              1920
#
#    resolution_height  ram_gb ram_type rom_gb
# 0               1080      8      DDR4   1024
# 1               1080      8      DDR4   1024
# 2               1400     16    LPDDR5   1024
# 3               1080      8      DDR4   1024
# 4               1080     16      DDR4   1024
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#    Unnamed: 0                                               name    price  \
# 0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  ₹52,000
# 1           1  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  ₹37,990
# 2           2  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  ₹59,990
# 3           3  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  ₹55,990
# 4           4  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  ₹39,790
#
#               os                      graphics  \
# 0  Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1  Windows 11 OS            Intel UHD Graphics
# 2  Windows 11 OS      Intel Integrated Iris Xe
# 3  Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4  Windows 11 OS        Intel Iris Xe Graphics
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
#
#           rom         warranty  rating                            core  \
# 0  512 GB SSD  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  512 GB SSD  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  512 GB SSD  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  512 GB SSD  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  512 GB SSD  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core
# 0      5th Gen AMD Ryzen 5 5600H
# 1   12th Gen Intel Core i3 1215U
# 2   12th Gen Intel Core i5 1240P
# 3  11th Gen Intel Core i5 11300H
# 4  11th Gen Intel Core i5 1155G7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  760 non-null    int64
#  1   name        760 non-null    object
#  2   price       760 non-null    object
#  3   os          760 non-null    object
#  4   graphics    760 non-null    object
#  5   display     760 non-null    object
#  6   ram         760 non-null    object
#  7   rom         760 non-null    object
#  8   warranty    757 non-null    object
#  9   rating      492 non-null    float64
#  10  core        760 non-null    object
#  11  intel_core  760 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 71.4+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# name            0
# price           0
# os              0
# graphics        0
# display         0
# ram             0
# rom             0
# warranty        3
# rating        268
# core            0
# intel_core      0
# dtype: int64

# %%
df['price']=df['price'].str.replace('₹', '').str.replace(',', '').astype(int)

# %%
df
# Out:
#      Unnamed: 0                                               name  price  \
# 0             0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1             1  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2             2  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3             3  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4             4  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
# ..          ...                                                ...    ...
# 755         755  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101
# 756         756  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388
# 757         757  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990
# 758         758  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440
# 759         759  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990
#
#                 os                      graphics  \
# 0    Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1    Windows 11 OS            Intel UHD Graphics
# 2    Windows 11 OS      Intel Integrated Iris Xe
# 3    Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4    Windows 11 OS        Intel Iris Xe Graphics
# ..             ...                           ...
# 755  Windows 11 OS       ‎Intel Iris Xe Graphics
# 756  Windows 11 OS           AMD Radeon Graphics
# 757  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
# 758  Windows 11 OS          Intel Integrated UHD
# 759  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
#
#                                            display               ram  \
# 0    15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                    14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 4                  15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
# ..                                             ...               ...
# 755    14 inches, 1920 x 1200 pixels, Touch Screen        16 GB  RAM
# 756                  14 inches, 1920 x 1200 pixels    16 GB DDR4 RAM
# 757                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
# 758                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 759                  16 inches, 1920 x 1200 pixels    16 GB DDR4 RAM
#
#             rom         warranty  rating                            core  \
# 0    512 GB SSD  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1    512 GB SSD  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2    512 GB SSD  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3    512 GB SSD  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4    512 GB SSD  1 Year Warranty    64.0            Quad Core, 8 Threads
# ..          ...              ...     ...                             ...
# 755  512 GB SSD  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 756  512 GB SSD  1 Year Warranty    62.0           Hexa Core, 12 Threads
# 757    1 TB SSD  1 Year Warranty    63.0           Hexa Core, 12 Threads
# 758    1 TB SSD  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 759    1 TB SSD  1 Year Warranty    73.0  10 Cores (6P + 4E), 16 Threads
#
#                         intel_core
# 0        5th Gen AMD Ryzen 5 5600H
# 1     12th Gen Intel Core i3 1215U
# 2     12th Gen Intel Core i5 1240P
# 3    11th Gen Intel Core i5 11300H
# 4    11th Gen Intel Core i5 1155G7
# ..                             ...
# 755   13th Gen Intel Core i7 1355U
# 756      7th Gen AMD Ryzen 5 7530U
# 757     5th Gen AMD Ryzen 5 5600HS
# 758   13th Gen Intel Core i5 1335U
# 759  12th Gen Intel Core i7 12650H
#
# [760 rows x 12 columns]

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0                                               name  \
# 0      0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...
# 1      1           1  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...
# 2      2           2  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...
# 3      3           3  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...
# 4      4           4  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...
#
#    price             os                      graphics  \
# 0  52000  Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1  37990  Windows 11 OS            Intel UHD Graphics
# 2  59990  Windows 11 OS      Intel Integrated Iris Xe
# 3  55990  Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4  39790  Windows 11 OS        Intel Iris Xe Graphics
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
#
#           rom         warranty  rating                            core  \
# 0  512 GB SSD  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  512 GB SSD  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  512 GB SSD  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  512 GB SSD  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  512 GB SSD  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core
# 0      5th Gen AMD Ryzen 5 5600H
# 1   12th Gen Intel Core i3 1215U
# 2   12th Gen Intel Core i5 1240P
# 3  11th Gen Intel Core i5 11300H
# 4  11th Gen Intel Core i5 1155G7

# %%
df['index']=df['index']+1

# %%
df.head()
# Out:
#    index  Unnamed: 0                                               name  \
# 0      1           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...
# 1      2           1  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...
# 2      3           2  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...
# 3      4           3  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...
# 4      5           4  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...
#
#    price             os                      graphics  \
# 0  52000  Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1  37990  Windows 11 OS            Intel UHD Graphics
# 2  59990  Windows 11 OS      Intel Integrated Iris Xe
# 3  55990  Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4  39790  Windows 11 OS        Intel Iris Xe Graphics
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
#
#           rom         warranty  rating                            core  \
# 0  512 GB SSD  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  512 GB SSD  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  512 GB SSD  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  512 GB SSD  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  512 GB SSD  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core
# 0      5th Gen AMD Ryzen 5 5600H
# 1   12th Gen Intel Core i3 1215U
# 2   12th Gen Intel Core i5 1240P
# 3  11th Gen Intel Core i5 11300H
# 4  11th Gen Intel Core i5 1155G7

# %%
df['brand']=df['name'].str.split(' ')

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.head()
# Out:
#    index                                               name  price  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
#
#               os                      graphics  \
# 0  Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1  Windows 11 OS            Intel UHD Graphics
# 2  Windows 11 OS      Intel Integrated Iris Xe
# 3  Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4  Windows 11 OS        Intel Iris Xe Graphics
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
#
#           rom         warranty  rating                            core  \
# 0  512 GB SSD  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  512 GB SSD  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  512 GB SSD  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  512 GB SSD  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  512 GB SSD  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core  \
# 0      5th Gen AMD Ryzen 5 5600H
# 1   12th Gen Intel Core i3 1215U
# 2   12th Gen Intel Core i5 1240P
# 3  11th Gen Intel Core i5 11300H
# 4  11th Gen Intel Core i5 1155G7
#
#                                                brand
# 0  [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...
# 1  [HP, 15s-fq5007TU, Laptop, (12th, Gen, Core, i...
# 2  [Lenovo, Yoga, Slim, 6, 14IAP8, 82WU0095IN, La...
# 3  [Lenovo, IdeaPad, Gaming, 3, 15IHU6, 82K101GSI...
# 4  [Acer, Aspire, Lite, AL15-51, 2023, Laptop, (1...

# %%
df.isna().sum()
# Out:
# index           0
# name            0
# price           0
# os              0
# graphics        0
# display         0
# ram             0
# rom             0
# warranty        3
# rating        268
# core            0
# intel_core      0
# brand           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       760 non-null    int64
#  1   name        760 non-null    object
#  2   price       760 non-null    int64
#  3   os          760 non-null    object
#  4   graphics    760 non-null    object
#  5   display     760 non-null    object
#  6   ram         760 non-null    object
#  7   rom         760 non-null    object
#  8   warranty    757 non-null    object
#  9   rating      492 non-null    float64
#  10  core        760 non-null    object
#  11  intel_core  760 non-null    object
#  12  brand       760 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 77.3+ KB

# %%
df['os'].value_counts()
# Out:
# os
# Windows 11 OS                      657
# Windows 10 OS                       18
# Mac OS                              17
# 15.6 inches, 1920 x 1080 pixels     12
# Chrome OS                           12
# 1 Year Warranty                     11
# Windows OS                           9
# DOS OS                               7
# Windows 10  OS                       6
# Windows 11  OS                       6
# Android 11 OS                        1
# DOS 3.0 OS                           1
# Ubuntu OS                            1
# 15.6 inches, 1366 x 768 pixels       1
# 14 inches, 1920 x 1080 pixels        1
# Name: count, dtype: int64

# %%
temp_df1=df[df['os'].str.contains('pixels')]

# %%
temp_df1
# Out:
#      index                                               name  price  \
# 61      62  MSI GF63 Thin 11UC-1294IN Gaming Laptop (11th ...  65990
# 163    164  MSI Thin GF63 11UCX-1492IN Gaming Laptop (11th...  53990
# 165    166  MSI Thin GF63 11UC-1490IN Gaming Laptop (11th ...  57990
# 298    299  Dell Inspiron 3520 Laptop (12th Gen Core i5/ 8...  50990
# 299    300  Dell Inspiron 3520 D560879WIN9S Laptop (12th G...  60990
# 317    318  HP 15s-GR0012AU Laptop (AMD Ryzen 3 3250U/ 8GB...  37290
# 431    432  Dell Vostro 15 3510 Laptop (11th Gen Core i3/ ...  36990
# 476    477  MSI GF63 Thin 11SC-1298IN Gaming Laptop (11th ...  59990
# 482    483  MSI Thin GF63 12VF-268IN Laptop (12th Gen Core...  86990
# 488    489  HP 250 G8 7M6L7PA Laptop (11th Gen Core i3/ 8G...  37790
# 575    576  HP 15s-dr3506TU Laptop (11th Gen Core i3/ 8GB/...  35999
# 618    619  Dell Inspiron 3511 Laptop (11th Gen Core i5/ 8...  64000
# 622    623  Dell Inspiron 3501 Laptop (11th Gen Core i5/ 8...  52500
# 628    629  Asus VivoBook S430FN-EB059T Laptop (8th Gen Co...  53190
#
#                                   os    graphics  \
# 61   15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 163  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 165  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 298  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 299  15.6 inches, 1920 x 1080 pixels  512 GB SSD
# 317  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 431  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 476  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 482  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 488   15.6 inches, 1366 x 768 pixels  256 GB SSD
# 575  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 618  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 622  15.6 inches, 1920 x 1080 pixels  256 GB SSD
# 628    14 inches, 1920 x 1080 pixels  256 GB SSD
#
#                            display             ram  \
# 61    4 GB NVIDIA GeForce RTX 3050  16 GB DDR4 RAM
# 163  4 GB NVIDIA GeForce RTX 2050   16 GB DDR4 RAM
# 165  4 GB NVIDIA GeForce RTX 3050   16 GB DDR4 RAM
# 298         Intel Iris Xe Graphics   8 GB DDR4 RAM
# 299         Intel Iris Xe Graphics  16 GB DDR4 RAM
# 317              AMD Radeon Vega 6   8 GB DDR4 RAM
# 431             Intel UHD Graphics   8 GB DDR4 RAM
# 476   4 GB NVIDIA GeForce GTX 1650  16 GB DDR4 RAM
# 482   8 GB NVIDIA GeForce RTX 4060  16 GB DDR4 RAM
# 488               Intel Integrated   8 GB DDR4 RAM
# 575             Intel UHD Graphics   8 GB DDR4 RAM
# 618      2 GB NVIDIA GeForce MX350   8 GB DDR4 RAM
# 622         Intel Iris Xe Graphics   8 GB DDR4 RAM
# 628      2 GB NVIDIA Geforce MX150   8 GB DDR4 RAM
#
#                                         rom        warranty  rating  \
# 61     1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS    76.0
# 163    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS    73.0
# 165    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS    73.0
# 298    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS     NaN
# 299  512 GB Hard Disk512 GB SSD+ 512 GB SSD   Windows 11 OS    63.0
# 317    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 10 OS    61.0
# 431    1 TB Hard Disk256 GB SSD+ 256 GB SSD  Windows 11  OS    60.0
# 476    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS    71.0
# 482    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS    77.0
# 488    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS     NaN
# 575    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 11 OS    60.0
# 618    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 10 OS    65.0
# 622    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 10 OS     NaN
# 628    1 TB Hard Disk256 GB SSD+ 256 GB SSD   Windows 10 OS    72.0
#
#                                 core                      intel_core  \
# 61             Octa Core, 16 Threads   11th Gen Intel Core i7 11800H
# 163            Hexa Core, 12 Threads   11th Gen Intel Core i5 11260H
# 165            Hexa Core, 12 Threads   11th Gen Intel Core i5 11260H
# 298   10 Cores (2P + 8E), 12 Threads    12th Gen Intel Core i5 1235U
# 299   10 Cores (2P + 8E), 12 Threads    12th Gen Intel Core i5 1235U
# 317             Dual Core, 4 Threads      3rd Gen AMD Ryzen 3  3250U
# 431             Dual Core, 4 Threads   11th Gen Intel Core i3 1115G4
# 476            Octa Core, 16 Threads   11th Gen Intel Core i7 11800H
# 482  Octa Core (4P + 4E), 12 Threads   12th Gen Intel Core i5 12450H
# 488             Dual Core, 4 Threads   11th Gen Intel Core i3 1115G4
# 575             Dual Core, 4 Threads   11th Gen Intel Core i3 1115G4
# 618             Quad Core, 8 Threads   11th Gen Intel Core i5 1135G7
# 622             Quad Core, 8 Threads  11th Gen Intel Core i5 1135G7
# 628             Quad Core, 8 Threads     8th Gen Intel Core i7 8565U
#
#                                                  brand
# 61   [MSI, GF63, Thin, 11UC-1294IN, Gaming, Laptop,...
# 163  [MSI, Thin, GF63, 11UCX-1492IN, Gaming, Laptop...
# 165  [MSI, Thin, GF63, 11UC-1490IN, Gaming, Laptop,...
# 298  [Dell, Inspiron, 3520, Laptop, (12th, Gen, Cor...
# 299  [Dell, Inspiron, 3520, D560879WIN9S, Laptop, (...
# 317  [HP, 15s-GR0012AU, Laptop, (AMD, Ryzen, 3, 325...
# 431  [Dell, Vostro, 15, 3510, Laptop, (11th, Gen, C...
# 476  [MSI, GF63, Thin, 11SC-1298IN, Gaming, Laptop,...
# 482  [MSI, Thin, GF63, 12VF-268IN, Laptop, (12th, G...
# 488  [HP, 250, G8, 7M6L7PA, Laptop, (11th, Gen, Cor...
# 575  [HP, 15s-dr3506TU, Laptop, (11th, Gen, Core, i...
# 618  [Dell, Inspiron, 3511, Laptop, (11th, Gen, Cor...
# 622  [Dell, Inspiron, 3501, Laptop, (11th, Gen, Cor...
# 628  [Asus, VivoBook, S430FN-EB059T, Laptop, (8th, ...

# %%
df['rom']=df['rom']+"+ " + temp_df1['graphics']

# %%
df
# Out:
#      index                                               name  price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1        2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2        3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3        4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4        5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
# ..     ...                                                ...    ...
# 755    756  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101
# 756    757  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388
# 757    758  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990
# 758    759  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440
# 759    760  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990
#
#                 os                      graphics  \
# 0    Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1    Windows 11 OS            Intel UHD Graphics
# 2    Windows 11 OS      Intel Integrated Iris Xe
# 3    Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4    Windows 11 OS        Intel Iris Xe Graphics
# ..             ...                           ...
# 755  Windows 11 OS       ‎Intel Iris Xe Graphics
# 756  Windows 11 OS           AMD Radeon Graphics
# 757  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
# 758  Windows 11 OS          Intel Integrated UHD
# 759  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
#
#                                            display               ram  rom  \
# 0    15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                    14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                  15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
# ..                                             ...               ...  ...
# 755    14 inches, 1920 x 1200 pixels, Touch Screen        16 GB  RAM  NaN
# 756                  14 inches, 1920 x 1200 pixels    16 GB DDR4 RAM  NaN
# 757                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
# 758                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 759                  16 inches, 1920 x 1200 pixels    16 GB DDR4 RAM  NaN
#
#             warranty  rating                            core  \
# 0    1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1    1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2    1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3    1 Year Warranty    71.0            Quad Core, 8 Threads
# 4    1 Year Warranty    64.0            Quad Core, 8 Threads
# ..               ...     ...                             ...
# 755  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 756  1 Year Warranty    62.0           Hexa Core, 12 Threads
# 757  1 Year Warranty    63.0           Hexa Core, 12 Threads
# 758  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 759  1 Year Warranty    73.0  10 Cores (6P + 4E), 16 Threads
#
#                         intel_core  \
# 0        5th Gen AMD Ryzen 5 5600H
# 1     12th Gen Intel Core i3 1215U
# 2     12th Gen Intel Core i5 1240P
# 3    11th Gen Intel Core i5 11300H
# 4    11th Gen Intel Core i5 1155G7
# ..                             ...
# 755   13th Gen Intel Core i7 1355U
# 756      7th Gen AMD Ryzen 5 7530U
# 757     5th Gen AMD Ryzen 5 5600HS
# 758   13th Gen Intel Core i5 1335U
# 759  12th Gen Intel Core i7 12650H
#
#                                                  brand
# 0    [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...
# 1    [HP, 15s-fq5007TU, Laptop, (12th, Gen, Core, i...
# 2    [Lenovo, Yoga, Slim, 6, 14IAP8, 82WU0095IN, La...
# 3    [Lenovo, IdeaPad, Gaming, 3, 15IHU6, 82K101GSI...
# 4    [Acer, Aspire, Lite, AL15-51, 2023, Laptop, (1...
# ..                                                 ...
# 755  [Lenovo, IdeaPad, Flex, 5, 82Y00053IN, Laptop,...
# 756  [Lenovo, Ideapad, Slim, 5, 82XE004QIN, Laptop,...
# 757  [Asus, Vivobook, Pro, 15, M6500QC-HN551WS, Lap...
# 758  [Dell, 15, Inspiron, 3530, Laptop, (13th, Gen,...
# 759  [Asus, Vivobook, 16X, 2023, K3605ZC-MBN752WS, ...
#
# [760 rows x 13 columns]

# %%
df[df['os'].str.contains("Windows")]
# Out:
#      index                                               name  price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1        2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2        3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3        4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4        5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
# ..     ...                                                ...    ...
# 755    756  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101
# 756    757  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388
# 757    758  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990
# 758    759  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440
# 759    760  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990
#
#                 os                      graphics  \
# 0    Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1    Windows 11 OS            Intel UHD Graphics
# 2    Windows 11 OS      Intel Integrated Iris Xe
# 3    Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4    Windows 11 OS        Intel Iris Xe Graphics
# ..             ...                           ...
# 755  Windows 11 OS       ‎Intel Iris Xe Graphics
# 756  Windows 11 OS           AMD Radeon Graphics
# 757  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
# 758  Windows 11 OS          Intel Integrated UHD
# 759  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
#
#                                            display               ram  \
# 0    15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                    14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 4                  15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
# ..                                             ...               ...
# 755    14 inches, 1920 x 1200 pixels, Touch Screen        16 GB  RAM
# 756                  14 inches, 1920 x 1200 pixels    16 GB DDR4 RAM
# 757                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
# 758                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 759                  16 inches, 1920 x 1200 pixels    16 GB DDR4 RAM
#
#             rom         warranty  rating                            core  \
# 0    512 GB SSD  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1    512 GB SSD  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2    512 GB SSD  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3    512 GB SSD  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4    512 GB SSD  1 Year Warranty    64.0            Quad Core, 8 Threads
# ..          ...              ...     ...                             ...
# 755  512 GB SSD  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 756  512 GB SSD  1 Year Warranty    62.0           Hexa Core, 12 Threads
# 757    1 TB SSD  1 Year Warranty    63.0           Hexa Core, 12 Threads
# 758    1 TB SSD  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 759    1 TB SSD  1 Year Warranty    73.0  10 Cores (6P + 4E), 16 Threads
#
#                         intel_core  \
# 0        5th Gen AMD Ryzen 5 5600H
# 1     12th Gen Intel Core i3 1215U
# 2     12th Gen Intel Core i5 1240P
# 3    11th Gen Intel Core i5 11300H
# 4    11th Gen Intel Core i5 1155G7
# ..                             ...
# 755   13th Gen Intel Core i7 1355U
# 756      7th Gen AMD Ryzen 5 7530U
# 757     5th Gen AMD Ryzen 5 5600HS
# 758   13th Gen Intel Core i5 1335U
# 759  12th Gen Intel Core i7 12650H
#
#                                                  brand
# 0    [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...
# 1    [HP, 15s-fq5007TU, Laptop, (12th, Gen, Core, i...
# 2    [Lenovo, Yoga, Slim, 6, 14IAP8, 82WU0095IN, La...
# 3    [Lenovo, IdeaPad, Gaming, 3, 15IHU6, 82K101GSI...
# 4    [Acer, Aspire, Lite, AL15-51, 2023, Laptop, (1...
# ..                                                 ...
# 755  [Lenovo, IdeaPad, Flex, 5, 82Y00053IN, Laptop,...
# 756  [Lenovo, Ideapad, Slim, 5, 82XE004QIN, Laptop,...
# 757  [Asus, Vivobook, Pro, 15, M6500QC-HN551WS, Lap...
# 758  [Dell, 15, Inspiron, 3530, Laptop, (13th, Gen,...
# 759  [Asus, Vivobook, 16X, 2023, K3605ZC-MBN752WS, ...
#
# [696 rows x 13 columns]

# %%
df
# Out:
#      index                                               name  price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1        2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2        3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3        4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4        5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
# ..     ...                                                ...    ...
# 755    756  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101
# 756    757  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388
# 757    758  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990
# 758    759  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440
# 759    760  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990
#
#                 os                      graphics  \
# 0    Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1    Windows 11 OS            Intel UHD Graphics
# 2    Windows 11 OS      Intel Integrated Iris Xe
# 3    Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4    Windows 11 OS        Intel Iris Xe Graphics
# ..             ...                           ...
# 755  Windows 11 OS       ‎Intel Iris Xe Graphics
# 756  Windows 11 OS           AMD Radeon Graphics
# 757  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
# 758  Windows 11 OS          Intel Integrated UHD
# 759  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
#
#                                            display               ram  \
# 0    15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                    14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 4                  15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
# ..                                             ...               ...
# 755    14 inches, 1920 x 1200 pixels, Touch Screen        16 GB  RAM
# 756                  14 inches, 1920 x 1200 pixels    16 GB DDR4 RAM
# 757                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM
# 758                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 759                  16 inches, 1920 x 1200 pixels    16 GB DDR4 RAM
#
#             rom         warranty  rating                            core  \
# 0    512 GB SSD  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1    512 GB SSD  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2    512 GB SSD  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3    512 GB SSD  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4    512 GB SSD  1 Year Warranty    64.0            Quad Core, 8 Threads
# ..          ...              ...     ...                             ...
# 755  512 GB SSD  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 756  512 GB SSD  1 Year Warranty    62.0           Hexa Core, 12 Threads
# 757    1 TB SSD  1 Year Warranty    63.0           Hexa Core, 12 Threads
# 758    1 TB SSD  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 759    1 TB SSD  1 Year Warranty    73.0  10 Cores (6P + 4E), 16 Threads
#
#                         intel_core  \
# 0        5th Gen AMD Ryzen 5 5600H
# 1     12th Gen Intel Core i3 1215U
# 2     12th Gen Intel Core i5 1240P
# 3    11th Gen Intel Core i5 11300H
# 4    11th Gen Intel Core i5 1155G7
# ..                             ...
# 755   13th Gen Intel Core i7 1355U
# 756      7th Gen AMD Ryzen 5 7530U
# 757     5th Gen AMD Ryzen 5 5600HS
# 758   13th Gen Intel Core i5 1335U
# 759  12th Gen Intel Core i7 12650H
#
#                                                  brand
# 0    [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...
# 1    [HP, 15s-fq5007TU, Laptop, (12th, Gen, Core, i...
# 2    [Lenovo, Yoga, Slim, 6, 14IAP8, 82WU0095IN, La...
# 3    [Lenovo, IdeaPad, Gaming, 3, 15IHU6, 82K101GSI...
# 4    [Acer, Aspire, Lite, AL15-51, 2023, Laptop, (1...
# ..                                                 ...
# 755  [Lenovo, IdeaPad, Flex, 5, 82Y00053IN, Laptop,...
# 756  [Lenovo, Ideapad, Slim, 5, 82XE004QIN, Laptop,...
# 757  [Asus, Vivobook, Pro, 15, M6500QC-HN551WS, Lap...
# 758  [Dell, 15, Inspiron, 3530, Laptop, (13th, Gen,...
# 759  [Asus, Vivobook, 16X, 2023, K3605ZC-MBN752WS, ...
#
# [760 rows x 13 columns]

# %%
temp_df1['graphics']=temp_df1['display']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\469393929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['graphics']=temp_df1['display']

# %%
temp_df1['display']=temp_df1['os']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\2231681460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['display']=temp_df1['os']

# %%
temp_df1['os']=temp_df1['warranty']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\1730586659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['os']=temp_df1['warranty']

# %%
temp_df1['warranty']=np.nan
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\3561653305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['warranty']=np.nan

# %%
temp_df1.head()
# Out:
#      index                                               name  price  \
# 61      62  MSI GF63 Thin 11UC-1294IN Gaming Laptop (11th ...  65990
# 163    164  MSI Thin GF63 11UCX-1492IN Gaming Laptop (11th...  53990
# 165    166  MSI Thin GF63 11UC-1490IN Gaming Laptop (11th ...  57990
# 298    299  Dell Inspiron 3520 Laptop (12th Gen Core i5/ 8...  50990
# 299    300  Dell Inspiron 3520 D560879WIN9S Laptop (12th G...  60990
#
#                 os                       graphics  \
# 61   Windows 11 OS   4 GB NVIDIA GeForce RTX 3050
# 163  Windows 11 OS  4 GB NVIDIA GeForce RTX 2050
# 165  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
# 298  Windows 11 OS         Intel Iris Xe Graphics
# 299  Windows 11 OS         Intel Iris Xe Graphics
#
#                              display             ram  \
# 61   15.6 inches, 1920 x 1080 pixels  16 GB DDR4 RAM
# 163  15.6 inches, 1920 x 1080 pixels  16 GB DDR4 RAM
# 165  15.6 inches, 1920 x 1080 pixels  16 GB DDR4 RAM
# 298  15.6 inches, 1920 x 1080 pixels   8 GB DDR4 RAM
# 299  15.6 inches, 1920 x 1080 pixels  16 GB DDR4 RAM
#
#                                         rom  warranty  rating  \
# 61     1 TB Hard Disk256 GB SSD+ 256 GB SSD       NaN    76.0
# 163    1 TB Hard Disk256 GB SSD+ 256 GB SSD       NaN    73.0
# 165    1 TB Hard Disk256 GB SSD+ 256 GB SSD       NaN    73.0
# 298    1 TB Hard Disk256 GB SSD+ 256 GB SSD       NaN     NaN
# 299  512 GB Hard Disk512 GB SSD+ 512 GB SSD       NaN    63.0
#
#                                core                     intel_core  \
# 61            Octa Core, 16 Threads  11th Gen Intel Core i7 11800H
# 163           Hexa Core, 12 Threads  11th Gen Intel Core i5 11260H
# 165           Hexa Core, 12 Threads  11th Gen Intel Core i5 11260H
# 298  10 Cores (2P + 8E), 12 Threads   12th Gen Intel Core i5 1235U
# 299  10 Cores (2P + 8E), 12 Threads   12th Gen Intel Core i5 1235U
#
#                                                  brand
# 61   [MSI, GF63, Thin, 11UC-1294IN, Gaming, Laptop,...
# 163  [MSI, Thin, GF63, 11UCX-1492IN, Gaming, Laptop...
# 165  [MSI, Thin, GF63, 11UC-1490IN, Gaming, Laptop,...
# 298  [Dell, Inspiron, 3520, Laptop, (12th, Gen, Cor...
# 299  [Dell, Inspiron, 3520, D560879WIN9S, Laptop, (...

# %%
df.loc[temp_df1.index,temp_df1.columns]=temp_df1.values

# %%
temp_df1.values
# Out:
# array([[62,
#         'MSI GF63 Thin 11UC-1294IN Gaming Laptop (11th Gen Core i7/ 16GB/ 1TB 256GB SSD/ Win11/ 4GB Graph)',
#         65990, 'Windows 11 OS', '4\u2009GB NVIDIA GeForce RTX 3050',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '16\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 76.0,
#         'Octa Core, 16 Threads', '11th Gen Intel Core i7 11800H',
#         list(['MSI', 'GF63', 'Thin', '11UC-1294IN', 'Gaming', 'Laptop', '(11th', 'Gen', 'Core', 'i7/', '16GB/', '1TB', '256GB', 'SSD/', 'Win11/', '4GB', 'Graph)'])],
#        [164,
#         'MSI Thin GF63 11UCX-1492IN Gaming Laptop (11th Gen Core i5/ 16GB/ 1TB 256GB SSD/ Win11 Home/ 4GB Graph)',
#         53990, 'Windows 11 OS', '4\u2009GB NVIDIA GeForce RTX 2050 ',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '16\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 73.0,
#         'Hexa Core, 12 Threads', '11th Gen Intel Core i5 11260H',
#         list(['MSI', 'Thin', 'GF63', '11UCX-1492IN', 'Gaming', 'Laptop', '(11th', 'Gen', 'Core', 'i5/', '16GB/', '1TB', '256GB', 'SSD/', 'Win11', 'Home/', '4GB', 'Graph)'])],
#        [166,
#         'MSI Thin GF63 11UC-1490IN Gaming Laptop (11th Gen Core i5/ 16GB/ 1TB 256GB SSD/ Win11 Home/ 4GB Graph)',
#         57990, 'Windows 11 OS', '4\u2009GB NVIDIA GeForce RTX 3050 ',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '16\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 73.0,
#         'Hexa Core, 12 Threads', '11th Gen Intel Core i5 11260H',
#         list(['MSI', 'Thin', 'GF63', '11UC-1490IN', 'Gaming', 'Laptop', '(11th', 'Gen', 'Core', 'i5/', '16GB/', '1TB', '256GB', 'SSD/', 'Win11', 'Home/', '4GB', 'Graph)'])],
#        [299,
#         'Dell Inspiron 3520 Laptop (12th Gen Core i5/ 8GB/ 1TB 256GB SSD/ Win11)',
#         50990, 'Windows 11 OS', 'Intel Iris Xe Graphics',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, nan,
#         '10 Cores (2P + 8E), 12 Threads', '12th Gen Intel Core i5 1235U',
#         list(['Dell', 'Inspiron', '3520', 'Laptop', '(12th', 'Gen', 'Core', 'i5/', '8GB/', '1TB', '256GB', 'SSD/', 'Win11)'])],
#        [300,
#         'Dell Inspiron 3520 D560879WIN9S Laptop (12th Gen Core i5/ 16GB/ 512GB SSD/ Win11)',
#         60990, 'Windows 11 OS', 'Intel Iris Xe Graphics',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '16\u2009GB DDR4 RAM',
#         '512\u2009GB Hard Disk512\u2009GB SSD+ 512\u2009GB SSD', nan,
#         63.0, '10 Cores (2P + 8E), 12 Threads',
#         '12th Gen Intel Core i5 1235U',
#         list(['Dell', 'Inspiron', '3520', 'D560879WIN9S', 'Laptop', '(12th', 'Gen', 'Core', 'i5/', '16GB/', '512GB', 'SSD/', 'Win11)'])],
#        [318,
#         'HP 15s-GR0012AU Laptop (AMD Ryzen 3 3250U/ 8GB/ 1TB 256GB SSD/ Win10 Home)',
#         37290, 'Windows 10 OS', 'AMD Radeon Vega 6',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 61.0,
#         'Dual Core, 4 Threads', '3rd Gen AMD Ryzen 3  3250U',
#         list(['HP', '15s-GR0012AU', 'Laptop', '(AMD', 'Ryzen', '3', '3250U/', '8GB/', '1TB', '256GB', 'SSD/', 'Win10', 'Home)'])],
#        [432,
#         'Dell Vostro 15 3510 Laptop (11th Gen Core i3/ 8GB/ 1TB 256GB SSD/ Win11 Home)',
#         36990, 'Windows 11  OS', 'Intel UHD Graphics',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 60.0,
#         'Dual Core, 4 Threads', '11th Gen Intel Core i3 1115G4',
#         list(['Dell', 'Vostro', '15', '3510', 'Laptop', '(11th', 'Gen', 'Core', 'i3/', '8GB/', '1TB', '256GB', 'SSD/', 'Win11', 'Home)'])],
#        [477,
#         'MSI GF63 Thin 11SC-1298IN Gaming Laptop (11th Gen Core i7/ 16GB/ 1TB 256GB SSD/ Win11/ 4GB Graph)',
#         59990, 'Windows 11 OS', '4\u2009GB NVIDIA GeForce GTX 1650',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '16\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 71.0,
#         'Octa Core, 16 Threads', '11th Gen Intel Core i7 11800H',
#         list(['MSI', 'GF63', 'Thin', '11SC-1298IN', 'Gaming', 'Laptop', '(11th', 'Gen', 'Core', 'i7/', '16GB/', '1TB', '256GB', 'SSD/', 'Win11/', '4GB', 'Graph)'])],
#        [483,
#         'MSI Thin GF63 12VF-268IN Laptop (12th Gen Core i5/ 16GB/ 1TB 256GB SSD/ Win11/ 8GB Graph)',
#         86990, 'Windows 11 OS', '8\u2009GB NVIDIA GeForce RTX 4060',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '16\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 77.0,
#         'Octa Core (4P + 4E), 12 Threads',
#         '12th Gen Intel Core i5 12450H',
#         list(['MSI', 'Thin', 'GF63', '12VF-268IN', 'Laptop', '(12th', 'Gen', 'Core', 'i5/', '16GB/', '1TB', '256GB', 'SSD/', 'Win11/', '8GB', 'Graph)'])],
#        [489,
#         'HP 250 G8 7M6L7PA Laptop (11th Gen Core i3/ 8GB/ 1TB 256GB SSD/ Win11)',
#         37790, 'Windows 11 OS', 'Intel Integrated',
#         '15.6\u2009inches, 1366\u2009x\u2009768\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, nan,
#         'Dual Core, 4 Threads', '11th Gen Intel Core i3 1115G4',
#         list(['HP', '250', 'G8', '7M6L7PA', 'Laptop', '(11th', 'Gen', 'Core', 'i3/', '8GB/', '1TB', '256GB', 'SSD/', 'Win11)'])],
#        [576,
#         'HP 15s-dr3506TU Laptop (11th Gen Core i3/ 8GB/ 1TB 256GB SSD/ Win 11 Home)',
#         35999, 'Windows 11 OS', 'Intel UHD Graphics',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 60.0,
#         'Dual Core, 4 Threads', '11th Gen Intel Core i3 1115G4',
#         list(['HP', '15s-dr3506TU', 'Laptop', '(11th', 'Gen', 'Core', 'i3/', '8GB/', '1TB', '256GB', 'SSD/', 'Win', '11', 'Home)'])],
#        [619,
#         'Dell Inspiron 3511 Laptop (11th Gen Core i5/ 8GB/ 1TB 256GB SSD/ Win10/ 2GB Graph)',
#         64000, 'Windows 10 OS', '2\u2009GB NVIDIA GeForce MX350',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 65.0,
#         'Quad Core, 8 Threads', '11th Gen Intel Core i5 1135G7',
#         list(['Dell', 'Inspiron', '3511', 'Laptop', '(11th', 'Gen', 'Core', 'i5/', '8GB/', '1TB', '256GB', 'SSD/', 'Win10/', '2GB', 'Graph)'])],
#        [623,
#         'Dell Inspiron 3501 Laptop (11th Gen Core i5/ 8GB/ 1TB 256GB SSD/ Win10)',
#         52500, 'Windows 10 OS', 'Intel Iris Xe Graphics',
#         '15.6\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, nan,
#         'Quad Core, 8 Threads', '11th Gen Intel Core i5 1135G7 ',
#         list(['Dell', 'Inspiron', '3501', 'Laptop', '(11th', 'Gen', 'Core', 'i5/', '8GB/', '1TB', '256GB', 'SSD/', 'Win10)'])],
#        [629,
#         'Asus VivoBook S430FN-EB059T Laptop (8th Gen Core i7/ 8GB/ 1TB 256GB SSD/ Win10 Home/ 2GB Graph)',
#         53190, 'Windows 10 OS', '2\u2009GB NVIDIA Geforce MX150',
#         '14\u2009inches, 1920\u2009x\u20091080\u2009pixels',
#         '8\u2009GB DDR4 RAM',
#         '1\u2009TB Hard Disk256\u2009GB SSD+ 256\u2009GB SSD', nan, 72.0,
#         'Quad Core, 8 Threads', '8th Gen Intel Core i7 8565U',
#         list(['Asus', 'VivoBook', 'S430FN-EB059T', 'Laptop', '(8th', 'Gen', 'Core', 'i7/', '8GB/', '1TB', '256GB', 'SSD/', 'Win10', 'Home/', '2GB', 'Graph)'])]],
#       dtype=object)

# %%
df['os'].value_counts()
# Out:
# os
# Windows 11 OS      666
# Windows 10 OS       22
# Mac OS              17
# Chrome OS           12
# 1 Year Warranty     11
# Windows OS           9
# Windows 11  OS       7
# DOS OS               7
# Windows 10  OS       6
# Android 11 OS        1
# DOS 3.0 OS           1
# Ubuntu OS            1
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#      index                                               name   price  \
# 429    430  HP Pavilion Plus ‎14-eh1047TU Laptop (13th Gen...  107763
# 201    202  Dell Inspiron 5420 Laptop (12th Gen Core i5/ 1...   79699
# 665    666  Lenovo Thinkpad L14 Gen 2 ‎20X1S10V00 Laptop (...   49499
# 723    724  Lenovo V15 G3 82TTA02UIH Laptop (12th Gen Core...   48990
# 445    446  MSI Thin GF63 11UCX-1476IN Gaming Laptop (11th...   51990
#
#                 os                       graphics  \
# 429  Windows 11 OS       Intel Integrated Iris Xe
# 201  Windows 11 OS           Intel Integrated UHD
# 665         DOS OS         Intel Iris Xe Graphics
# 723  Windows 11 OS           Intel Integrated UHD
# 445  Windows 11 OS  4 GB NVIDIA GeForce RTX 2050
#
#                              display             ram  rom         warranty  \
# 429    14 inches, 2880 x 1800 pixels  16 GB DDR4 RAM  NaN  1 Year Warranty
# 201    14 inches, 1920 x 1080 pixels  16 GB DDR5 RAM  NaN  1 Year Warranty
# 665    14 inches, 1920 x 1080 pixels   8 GB DDR4 RAM  NaN  3 Year Warranty
# 723  15.6 inches, 1920 x 1080 pixels   8 GB DDR4 RAM  NaN  1 Year Warranty
# 445  15.6 inches, 1920 x 1080 pixels  16 GB DDR4 RAM  NaN  2 Year Warranty
#
#      rating                            core                     intel_core  \
# 429    71.0  14 Cores (6P + 8E), 20 Threads  13th Gen Intel Core i7 13700H
# 201    62.0  12 Cores (4P + 8E), 16 Threads   12th Gen Intel Core i5 1240P
# 665     NaN            Dual Core, 4 Threads  11th Gen Intel Core i3 1115G4
# 723    63.0  10 Cores (2P + 8E), 12 Threads   12th Gen Intel Core i5 1235U
# 445    72.0           Hexa Core, 12 Threads  11th Gen Intel Core i5 11260H
#
#                                                  brand
# 429  [HP, Pavilion, Plus, ‎14-eh1047TU, Laptop, (13...
# 201  [Dell, Inspiron, 5420, Laptop, (12th, Gen, Cor...
# 665  [Lenovo, Thinkpad, L14, Gen, 2, ‎20X1S10V00, L...
# 723  [Lenovo, V15, G3, 82TTA02UIH, Laptop, (12th, G...
# 445  [MSI, Thin, GF63, 11UCX-1476IN, Gaming, Laptop...

# %%
temp_df2=df[df['os'].str.contains("Warranty") & df['display'].str.contains("pixels") ]

# %%
temp_df2
# Out:
#      index                                               name  price  \
# 51      52  Primebook 4G Android Laptop (MediaTek Kompanio...  11990
# 145    146  Primebook S Wi-Fi Laptop (MediaTek MT8183/ 4GB...  10990
# 414    415  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...  14499
# 683    684  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...  10990
#
#                   os          graphics                         display  \
# 51   1 Year Warranty      ARM Mali G72  11.6 inches, 1366 x 768 pixels
# 145  1 Year Warranty      ARM Mali G72  11.6 inches, 1366 x 768 pixels
# 414  1 Year Warranty  Arm Mali-G72 MP3  11.6 inches, 1366 x 768 pixels
# 683  1 Year Warranty      ARM Mali G72  11.6 inches, 1366 x 768 pixels
#
#                   ram  rom         warranty  rating       core  \
# 51    4 GB LPDDR4 RAM  NaN  2 USB 3.0 Ports     NaN  Octa Core
# 145   4 GB LPDDR4 RAM  NaN  2 USB 3.0 Ports     NaN  Octa Core
# 414  4 GB ‎LPDDR4 RAM  NaN              NaN     NaN  Octa Core
# 683   4 GB LPDDR4 RAM  NaN  2 USB 3.0 Ports     NaN  Octa Core
#
#             intel_core                                              brand
# 51    MediaTek MTK8788  [Primebook, 4G, Android, Laptop, (MediaTek, Ko...
# 145    MediaTek MT8183  [Primebook, S, Wi-Fi, Laptop, (MediaTek, MT818...
# 414   Mediatek  MT8788  [Jio, JioBook, NB1112MM, BLU, 2023, Netbook, L...
# 683    MediaTek MT8183  [Primebook, PBMTWIFI11064, Wi-Fi, Laptop, (Med...

# %%
temp_df2['warranty'].value_counts()
# Out:
# warranty
# 2 USB 3.0 Ports    3
# Name: count, dtype: int64

# %%
temp_df2['warranty']=temp_df2['os']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\555395982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df2['warranty']=temp_df2['os']

# %%
temp_df2
# Out:
#      index                                               name  price  \
# 51      52  Primebook 4G Android Laptop (MediaTek Kompanio...  11990
# 145    146  Primebook S Wi-Fi Laptop (MediaTek MT8183/ 4GB...  10990
# 414    415  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...  14499
# 683    684  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...  10990
#
#                   os          graphics                         display  \
# 51   1 Year Warranty      ARM Mali G72  11.6 inches, 1366 x 768 pixels
# 145  1 Year Warranty      ARM Mali G72  11.6 inches, 1366 x 768 pixels
# 414  1 Year Warranty  Arm Mali-G72 MP3  11.6 inches, 1366 x 768 pixels
# 683  1 Year Warranty      ARM Mali G72  11.6 inches, 1366 x 768 pixels
#
#                   ram  rom         warranty  rating       core  \
# 51    4 GB LPDDR4 RAM  NaN  1 Year Warranty     NaN  Octa Core
# 145   4 GB LPDDR4 RAM  NaN  1 Year Warranty     NaN  Octa Core
# 414  4 GB ‎LPDDR4 RAM  NaN  1 Year Warranty     NaN  Octa Core
# 683   4 GB LPDDR4 RAM  NaN  1 Year Warranty     NaN  Octa Core
#
#             intel_core                                              brand
# 51    MediaTek MTK8788  [Primebook, 4G, Android, Laptop, (MediaTek, Ko...
# 145    MediaTek MT8183  [Primebook, S, Wi-Fi, Laptop, (MediaTek, MT818...
# 414   Mediatek  MT8788  [Jio, JioBook, NB1112MM, BLU, 2023, Netbook, L...
# 683    MediaTek MT8183  [Primebook, PBMTWIFI11064, Wi-Fi, Laptop, (Med...

# %%
temp_df2['os']=np.nan
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\2610167317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df2['os']=np.nan

# %%
temp_df2
# Out:
#      index                                               name  price  os  \
# 51      52  Primebook 4G Android Laptop (MediaTek Kompanio...  11990 NaN
# 145    146  Primebook S Wi-Fi Laptop (MediaTek MT8183/ 4GB...  10990 NaN
# 414    415  Jio JioBook NB1112MM BLU 2023 Netbook Laptop (...  14499 NaN
# 683    684  Primebook PBMTWIFI11064 Wi-Fi Laptop (MediaTek...  10990 NaN
#
#              graphics                         display               ram  rom  \
# 51       ARM Mali G72  11.6 inches, 1366 x 768 pixels   4 GB LPDDR4 RAM  NaN
# 145      ARM Mali G72  11.6 inches, 1366 x 768 pixels   4 GB LPDDR4 RAM  NaN
# 414  Arm Mali-G72 MP3  11.6 inches, 1366 x 768 pixels  4 GB ‎LPDDR4 RAM  NaN
# 683      ARM Mali G72  11.6 inches, 1366 x 768 pixels   4 GB LPDDR4 RAM  NaN
#
#             warranty  rating       core         intel_core  \
# 51   1 Year Warranty     NaN  Octa Core   MediaTek MTK8788
# 145  1 Year Warranty     NaN  Octa Core    MediaTek MT8183
# 414  1 Year Warranty     NaN  Octa Core   Mediatek  MT8788
# 683  1 Year Warranty     NaN  Octa Core    MediaTek MT8183
#
#                                                  brand
# 51   [Primebook, 4G, Android, Laptop, (MediaTek, Ko...
# 145  [Primebook, S, Wi-Fi, Laptop, (MediaTek, MT818...
# 414  [Jio, JioBook, NB1112MM, BLU, 2023, Netbook, L...
# 683  [Primebook, PBMTWIFI11064, Wi-Fi, Laptop, (Med...

# %%
df.loc[temp_df2.index,temp_df2.columns]=temp_df2.values

# %%
df['os'].value_counts()
# Out:
# os
# Windows 11 OS      666
# Windows 10 OS       22
# Mac OS              17
# Chrome OS           12
# Windows OS           9
# DOS OS               7
# Windows 11  OS       7
# 1 Year Warranty      7
# Windows 10  OS       6
# Android 11 OS        1
# DOS 3.0 OS           1
# Ubuntu OS            1
# Name: count, dtype: int64

# %%
temp_df3=df[df['os']=='1 Year Warranty']

# %%
temp_df3
# Out:
#      index                                               name   price  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990
# 81      82  Acer C733 NX.H8VSI.004 Chromebook (Celeron Dua...    9990
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990
# 601    602  Samsung Galaxy Book Go Laptop (Snapdragon 7c/ ...   29990
# 612    613  Lenovo Chromebook 3 82BA0003US Laptop (Intel C...   35842
# 614    615  Lenovo IdeaPad 3 CB 11IGL05 82BA001PHA Laptop ...   17600
# 621    622  HP 11A-NA0002MU Chromebook (MT8183/ 4GB/ 64GB ...   17990
#
#                   os                                      graphics  \
# 67   1 Year Warranty               15.6 inches, 1920 x 1080 pixels
# 81   1 Year Warranty                11.6 inches, 1366 x 768 pixels
# 495  1 Year Warranty               15.6 inches, 1920 x 1080 pixels
# 601  1 Year Warranty                 14 inches, 1920 x 1080 pixels
# 612  1 Year Warranty                11.6 inches, 1366 x 768 pixels
# 614  1 Year Warranty                11.6 inches, 1366 x 768 pixels
# 621  1 Year Warranty  11.6 inches, 1366 x 768 pixels, Touch Screen
#
#            display               ram  rom          warranty  rating  \
# 67   Windows 11 OS        512 GB SSD  NaN  Backlit Keyboard    63.0
# 81       Chrome OS     4 GB DDR4 RAM  NaN   2 USB 3.0 Ports     NaN
# 495         DOS OS        256 GB SSD  NaN   1 USB 3.0 Ports     NaN
# 601  Windows 11 OS  128 GB Hard Disk  NaN               NaN     NaN
# 612      Chrome OS     4 GB DDR4 RAM  NaN   2 USB 3.0 Ports     NaN
# 614      Chrome OS   4 GB LPDDR4 RAM  NaN  Backlit Keyboard     NaN
# 621      Chrome OS     4 GB DDR4 RAM  NaN               NaN     NaN
#
#                      core                      intel_core  \
# 67         16 GB DDR5 RAM          13th Gen Intel Core i7
# 81   Dual Core, 2 Threads            Intel Celeron  N4000
# 495         8 GB DDR4 RAM            Intel Celeron  N4500
# 601     4 GB LPDDR4x  RAM  2nd Gen Qualcomm Snapdragon 7c
# 612  Dual Core, 2 Threads           Intel Celeron  N4020
# 614  Dual Core, 2 Threads            Intel Celeron  N4020
# 621             Octa Core          MediaTek MT8183 MT8183
#
#                                                  brand
# 67   [Lenovo, LOQ, 15IRH8, 82XV00BRIN, 2023, Gaming...
# 81   [Acer, C733, NX.H8VSI.004, Chromebook, (Celero...
# 495  [‎Lenovo, V15, G2, IJL, 82QYA00HIN, Laptop, (C...
# 601  [Samsung, Galaxy, Book, Go, Laptop, (Snapdrago...
# 612  [Lenovo, Chromebook, 3, 82BA0003US, Laptop, (I...
# 614  [Lenovo, IdeaPad, 3, CB, 11IGL05, 82BA001PHA, ...
# 621  [HP, 11A-NA0002MU, Chromebook, (MT8183/, 4GB/,...

# %%
temp_df3['warranty']=temp_df3['os']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\125083596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['warranty']=temp_df3['os']

# %%
temp_df3['warranty']=temp_df3['os']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\125083596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['warranty']=temp_df3['os']

# %%
temp_df3['display']=temp_df3['graphics']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\722555688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['display']=temp_df3['graphics']

# %%
temp_df3['graphics']=temp_df3['rom']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\1813169312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['graphics']=temp_df3['rom']

# %%
temp_df3['rom']=np.nan
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\851502817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['rom']=np.nan

# %%
df.loc[temp_df3.index,temp_df3.columns]=temp_df3.values

# %%
df
# Out:
#      index                                               name  price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1        2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2        3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3        4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4        5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
# ..     ...                                                ...    ...
# 755    756  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101
# 756    757  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388
# 757    758  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990
# 758    759  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440
# 759    760  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990
#
#                 os                      graphics  \
# 0    Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1    Windows 11 OS            Intel UHD Graphics
# 2    Windows 11 OS      Intel Integrated Iris Xe
# 3    Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4    Windows 11 OS        Intel Iris Xe Graphics
# ..             ...                           ...
# 755  Windows 11 OS       ‎Intel Iris Xe Graphics
# 756  Windows 11 OS           AMD Radeon Graphics
# 757  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
# 758  Windows 11 OS          Intel Integrated UHD
# 759  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
#
#                                            display               ram  rom  \
# 0    15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                    14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                  15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
# ..                                             ...               ...  ...
# 755    14 inches, 1920 x 1200 pixels, Touch Screen        16 GB  RAM  NaN
# 756                  14 inches, 1920 x 1200 pixels    16 GB DDR4 RAM  NaN
# 757                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
# 758                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 759                  16 inches, 1920 x 1200 pixels    16 GB DDR4 RAM  NaN
#
#             warranty  rating                            core  \
# 0    1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1    1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2    1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3    1 Year Warranty    71.0            Quad Core, 8 Threads
# 4    1 Year Warranty    64.0            Quad Core, 8 Threads
# ..               ...     ...                             ...
# 755  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 756  1 Year Warranty    62.0           Hexa Core, 12 Threads
# 757  1 Year Warranty    63.0           Hexa Core, 12 Threads
# 758  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 759  1 Year Warranty    73.0  10 Cores (6P + 4E), 16 Threads
#
#                         intel_core  \
# 0        5th Gen AMD Ryzen 5 5600H
# 1     12th Gen Intel Core i3 1215U
# 2     12th Gen Intel Core i5 1240P
# 3    11th Gen Intel Core i5 11300H
# 4    11th Gen Intel Core i5 1155G7
# ..                             ...
# 755   13th Gen Intel Core i7 1355U
# 756      7th Gen AMD Ryzen 5 7530U
# 757     5th Gen AMD Ryzen 5 5600HS
# 758   13th Gen Intel Core i5 1335U
# 759  12th Gen Intel Core i7 12650H
#
#                                                  brand
# 0    [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...
# 1    [HP, 15s-fq5007TU, Laptop, (12th, Gen, Core, i...
# 2    [Lenovo, Yoga, Slim, 6, 14IAP8, 82WU0095IN, La...
# 3    [Lenovo, IdeaPad, Gaming, 3, 15IHU6, 82K101GSI...
# 4    [Acer, Aspire, Lite, AL15-51, 2023, Laptop, (1...
# ..                                                 ...
# 755  [Lenovo, IdeaPad, Flex, 5, 82Y00053IN, Laptop,...
# 756  [Lenovo, Ideapad, Slim, 5, 82XE004QIN, Laptop,...
# 757  [Asus, Vivobook, Pro, 15, M6500QC-HN551WS, Lap...
# 758  [Dell, 15, Inspiron, 3530, Laptop, (13th, Gen,...
# 759  [Asus, Vivobook, 16X, 2023, K3605ZC-MBN752WS, ...
#
# [760 rows x 13 columns]

# %%
df['os']=df['os'].str.strip()

# %%
df.head()
# Out:
#    index                                               name  price  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
#
#               os                      graphics  \
# 0  Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1  Windows 11 OS            Intel UHD Graphics
# 2  Windows 11 OS      Intel Integrated Iris Xe
# 3  Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4  Windows 11 OS        Intel Iris Xe Graphics
#
#                                          display               ram  rom  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
#
#           warranty  rating                            core  \
# 0  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core  \
# 0      5th Gen AMD Ryzen 5 5600H
# 1   12th Gen Intel Core i3 1215U
# 2   12th Gen Intel Core i5 1240P
# 3  11th Gen Intel Core i5 11300H
# 4  11th Gen Intel Core i5 1155G7
#
#                                                brand
# 0  [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...
# 1  [HP, 15s-fq5007TU, Laptop, (12th, Gen, Core, i...
# 2  [Lenovo, Yoga, Slim, 6, 14IAP8, 82WU0095IN, La...
# 3  [Lenovo, IdeaPad, Gaming, 3, 15IHU6, 82K101GSI...
# 4  [Acer, Aspire, Lite, AL15-51, 2023, Laptop, (1...

# %%
df['os'].value_counts()
# Out:
# os
# Windows 11 OS      666
# Windows 10 OS       22
# Mac OS              17
# Chrome OS           12
# Windows OS           9
# DOS OS               7
# Windows 11  OS       7
# 1 Year Warranty      7
# Windows 10  OS       6
# Android 11 OS        1
# DOS 3.0 OS           1
# Ubuntu OS            1
# Name: count, dtype: int64

# %%
df['os']=df['os'].fillna('')

# %%
df['os'].value_counts()
# Out:
# os
# Windows 11 OS      666
# Windows 10 OS       22
# Mac OS              17
# Chrome OS           12
# Windows OS           9
# Windows 11  OS       7
# 1 Year Warranty      7
# DOS OS               7
# Windows 10  OS       6
#                      4
# Android 11 OS        1
# DOS 3.0 OS           1
# Ubuntu OS            1
# Name: count, dtype: int64

# %%
temp_df4=df[df['os'].str.contains("Windows")]

# %%
temp_df4
# Out:
#      index                                               name  price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1        2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2        3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3        4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4        5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
# ..     ...                                                ...    ...
# 755    756  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101
# 756    757  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388
# 757    758  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990
# 758    759  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440
# 759    760  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990
#
#                 os                      graphics  \
# 0    Windows 11 OS      4 GB AMD Radeon RX 6500M
# 1    Windows 11 OS            Intel UHD Graphics
# 2    Windows 11 OS      Intel Integrated Iris Xe
# 3    Windows 11 OS  4 GB NVIDIA GeForce GTX 1650
# 4    Windows 11 OS        Intel Iris Xe Graphics
# ..             ...                           ...
# 755  Windows 11 OS       ‎Intel Iris Xe Graphics
# 756  Windows 11 OS           AMD Radeon Graphics
# 757  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
# 758  Windows 11 OS          Intel Integrated UHD
# 759  Windows 11 OS  4 GB NVIDIA GeForce RTX 3050
#
#                                            display               ram  rom  \
# 0    15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                    14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                  15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                  15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
# ..                                             ...               ...  ...
# 755    14 inches, 1920 x 1200 pixels, Touch Screen        16 GB  RAM  NaN
# 756                  14 inches, 1920 x 1200 pixels    16 GB DDR4 RAM  NaN
# 757                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
# 758                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 759                  16 inches, 1920 x 1200 pixels    16 GB DDR4 RAM  NaN
#
#             warranty  rating                            core  \
# 0    1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1    1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2    1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3    1 Year Warranty    71.0            Quad Core, 8 Threads
# 4    1 Year Warranty    64.0            Quad Core, 8 Threads
# ..               ...     ...                             ...
# 755  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 756  1 Year Warranty    62.0           Hexa Core, 12 Threads
# 757  1 Year Warranty    63.0           Hexa Core, 12 Threads
# 758  1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 759  1 Year Warranty    73.0  10 Cores (6P + 4E), 16 Threads
#
#                         intel_core  \
# 0        5th Gen AMD Ryzen 5 5600H
# 1     12th Gen Intel Core i3 1215U
# 2     12th Gen Intel Core i5 1240P
# 3    11th Gen Intel Core i5 11300H
# 4    11th Gen Intel Core i5 1155G7
# ..                             ...
# 755   13th Gen Intel Core i7 1355U
# 756      7th Gen AMD Ryzen 5 7530U
# 757     5th Gen AMD Ryzen 5 5600HS
# 758   13th Gen Intel Core i5 1335U
# 759  12th Gen Intel Core i7 12650H
#
#                                                  brand
# 0    [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...
# 1    [HP, 15s-fq5007TU, Laptop, (12th, Gen, Core, i...
# 2    [Lenovo, Yoga, Slim, 6, 14IAP8, 82WU0095IN, La...
# 3    [Lenovo, IdeaPad, Gaming, 3, 15IHU6, 82K101GSI...
# 4    [Acer, Aspire, Lite, AL15-51, 2023, Laptop, (1...
# ..                                                 ...
# 755  [Lenovo, IdeaPad, Flex, 5, 82Y00053IN, Laptop,...
# 756  [Lenovo, Ideapad, Slim, 5, 82XE004QIN, Laptop,...
# 757  [Asus, Vivobook, Pro, 15, M6500QC-HN551WS, Lap...
# 758  [Dell, 15, Inspiron, 3530, Laptop, (13th, Gen,...
# 759  [Asus, Vivobook, 16X, 2023, K3605ZC-MBN752WS, ...
#
# [710 rows x 13 columns]

# %%
temp_df4['os'].value_counts()
# Out:
# os
# Windows 11 OS     666
# Windows 10 OS      22
# Windows OS          9
# Windows 11  OS      7
# Windows 10  OS      6
# Name: count, dtype: int64

# %%
temp_df4['os']="windows"
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\1367928528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df4['os']="windows"

# %%
temp_df4['os'].value_counts()
# Out:
# os
# windows    710
# Name: count, dtype: int64

# %%
df.loc[temp_df4.index,temp_df4.columns]=temp_df4.values

# %%
temp_df5=df[df['os']=="Mac OS"]

# %%
temp_df5.sample(4)
# Out:
#      index                                               name   price      os  \
# 640    641  Apple MacBook Pro 14 2023 Laptop (Apple M3/ 8G...  189900  Mac OS
# 13      14  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...  107990  Mac OS
# 610    611  Apple MacBook Pro 14 inch MKGQ3HN Laptop (M1 P...  239900  Mac OS
# 263    264  Apple MacBook Air 15 2023 Laptop (Apple M2/ 8G...  144990  Mac OS
#
#         graphics                          display                       ram  \
# 640  10 Core GPU  14.2 inches, 3024 x 1964 pixels                 8 GB  RAM
# 13    8-Core GPU  13.6 inches, 2560 x 1664 pixels             8 GB DDR4 RAM
# 610  16-core GPU  14.2 inches, 3024 x 1964 pixels  16 GB Unified Memory RAM
# 263  10-Core GPU  15.3 inches, 2880 x 1864 pixels             8 GB DDR4 RAM
#
#      rom         warranty  rating                 core           intel_core  \
# 640  NaN  1 Year Warranty     NaN  Octa Core (4P + 4E)             Apple M3
# 13   NaN  1 Year Warranty     NaN  Octa Core (4P + 4E)             Apple M2
# 610  NaN  1 Year Warranty     NaN   10 Cores (8P + 2E)  Apple M1 Pro M1 Pro
# 263  NaN  1 Year Warranty     NaN  Octa Core (4P + 4E)             Apple M2
#
#                                                  brand
# 640  [Apple, MacBook, Pro, 14, 2023, Laptop, (Apple...
# 13   [Apple, MacBook, Air, 2022, Laptop, (Apple, M2...
# 610  [Apple, MacBook, Pro, 14, inch, MKGQ3HN, Lapto...
# 263  [Apple, MacBook, Air, 15, 2023, Laptop, (Apple...

# %%
temp_df5['os'].value_counts()
# Out:
# os
# Mac OS    17
# Name: count, dtype: int64

# %%
temp_df5['os']="Mac"
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\3189121335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df5['os']="Mac"

# %%
temp_df5.head(2)
# Out:
#     index                                               name   price   os  \
# 8       9  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...   75999  Mac
# 13     14  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...  107990  Mac
#
#                         graphics                          display  \
# 8   Apple M1 Integrated Graphics  13.3 inches, 2560 x 1600 pixels
# 13                    8-Core GPU  13.6 inches, 2560 x 1664 pixels
#
#               ram  rom         warranty  rating                 core  \
# 8   8 GB DDR4 RAM  NaN  1 Year Warranty     NaN  Octa Core (4P + 4E)
# 13  8 GB DDR4 RAM  NaN  1 Year Warranty     NaN  Octa Core (4P + 4E)
#
#    intel_core                                              brand
# 8    Apple M1  [Apple, MacBook, Air, 2020, MGND3HN, Laptop, (...
# 13   Apple M2  [Apple, MacBook, Air, 2022, Laptop, (Apple, M2...

# %%
df.loc[temp_df5.index,temp_df5.columns]=temp_df5.values

# %%
df['os'].value_counts()
# Out:
# os
# windows            710
# Mac                 17
# Chrome OS           12
# 1 Year Warranty      7
# DOS OS               7
#                      4
# Android 11 OS        1
# DOS 3.0 OS           1
# Ubuntu OS            1
# Name: count, dtype: int64

# %%
temp_df6=df[df['os'].str.contains("OS")]

# %%
temp_df6['os']="other"
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\3447078054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df6['os']="other"

# %%
temp_df6['os'].value_counts()
# Out:
# os
# other    22
# Name: count, dtype: int64

# %%
temp_df6.head()
# Out:
#      index                                               name  price     os  \
# 24      25  Primebook 4G Android Laptop (MediaTek Kompanio...  10990  other
# 41      42  HP 255 G9 840T7PA Laptop (AMD Athlon Silver-30...  19959  other
# 132    133  HP Chromebook 14a-na1004TU Laptop (Celeron N45...  17990  other
# 193    194  HP Chromebook 15a-na0008TU Laptop (Intel Celer...  16990  other
# 228    229  HP 255 G9 841W6PA Laptop (AMD Ryzen 3 3250U/ 8...  24999  other
#
#                           graphics  \
# 24                    ARM Mali G72
# 41                  AMD Integrated
# 132  Intel Integrated UHD Graphics
# 193  Intel Integrated UHD Graphics
# 228            AMD Radeon Graphics
#
#                                         display               ram  rom  \
# 24               11.6 inches, 1366 x 768 pixels   4 GB LPDDR4 RAM  NaN
# 41               15.6 inches, 1366 x 768 pixels     4 GB DDR4 RAM  NaN
# 132  14 inches, 1366 x 768 pixels, Touch Screen   4 GB LPDDR4 RAM  NaN
# 193              15.6 inches, 1366 x 768 pixels  4 GB LPDDR4x RAM  NaN
# 228              15.6 inches, 1366 x 768 pixels     8 GB DDR4 RAM  NaN
#
#             warranty  rating                  core  \
# 24   1 Year Warranty     NaN             Octa Core
# 41   1 Year Warranty     NaN  Dual Core, 2 Threads
# 132  1 Year Warranty     NaN  Dual Core, 2 Threads
# 193  1 Year Warranty     NaN  Dual Core, 2 Threads
# 228  1 Year Warranty     NaN  Dual Core, 4 Threads
#
#                      intel_core  \
# 24             MediaTek MTK8788
# 41     3rd Gen AMD Athlon 3050U
# 132        Intel Celeron  N4500
# 193        Intel Celeron  N4500
# 228  3rd Gen AMD Ryzen 3  3250U
#
#                                                  brand
# 24   [Primebook, 4G, Android, Laptop, (MediaTek, Ko...
# 41   [HP, 255, G9, 840T7PA, Laptop, (AMD, Athlon, S...
# 132  [HP, Chromebook, 14a-na1004TU, Laptop, (Celero...
# 193  [HP, Chromebook, 15a-na0008TU, Laptop, (Intel,...
# 228  [HP, 255, G9, 841W6PA, Laptop, (AMD, Ryzen, 3,...

# %%
df.loc[temp_df6.index,temp_df5.columns]=temp_df6.values

# %%
df['os'].value_counts()
# Out:
# os
# windows            710
# other               22
# Mac                 17
# 1 Year Warranty      7
#                      4
# Name: count, dtype: int64

# %%
temp_df7=df[df['os'].str.contains('1 Year Warranty')]

# %%
temp_df7['os']='other'
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\634674937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df7['os']='other'

# %%
temp_df7
# Out:
#      index                                               name   price     os  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990  other
# 81      82  Acer C733 NX.H8VSI.004 Chromebook (Celeron Dua...    9990  other
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990  other
# 601    602  Samsung Galaxy Book Go Laptop (Snapdragon 7c/ ...   29990  other
# 612    613  Lenovo Chromebook 3 82BA0003US Laptop (Intel C...   35842  other
# 614    615  Lenovo IdeaPad 3 CB 11IGL05 82BA001PHA Laptop ...   17600  other
# 621    622  HP 11A-NA0002MU Chromebook (MT8183/ 4GB/ 64GB ...   17990  other
#
#     graphics                                       display               ram  \
# 67       NaN               15.6 inches, 1920 x 1080 pixels        512 GB SSD
# 81       NaN                11.6 inches, 1366 x 768 pixels     4 GB DDR4 RAM
# 495      NaN               15.6 inches, 1920 x 1080 pixels        256 GB SSD
# 601      NaN                 14 inches, 1920 x 1080 pixels  128 GB Hard Disk
# 612      NaN                11.6 inches, 1366 x 768 pixels     4 GB DDR4 RAM
# 614      NaN                11.6 inches, 1366 x 768 pixels   4 GB LPDDR4 RAM
# 621      NaN  11.6 inches, 1366 x 768 pixels, Touch Screen     4 GB DDR4 RAM
#
#      rom         warranty  rating                  core  \
# 67   NaN  1 Year Warranty    63.0        16 GB DDR5 RAM
# 81   NaN  1 Year Warranty     NaN  Dual Core, 2 Threads
# 495  NaN  1 Year Warranty     NaN         8 GB DDR4 RAM
# 601  NaN  1 Year Warranty     NaN     4 GB LPDDR4x  RAM
# 612  NaN  1 Year Warranty     NaN  Dual Core, 2 Threads
# 614  NaN  1 Year Warranty     NaN  Dual Core, 2 Threads
# 621  NaN  1 Year Warranty     NaN             Octa Core
#
#                          intel_core  \
# 67           13th Gen Intel Core i7
# 81             Intel Celeron  N4000
# 495            Intel Celeron  N4500
# 601  2nd Gen Qualcomm Snapdragon 7c
# 612           Intel Celeron  N4020
# 614            Intel Celeron  N4020
# 621          MediaTek MT8183 MT8183
#
#                                                  brand
# 67   [Lenovo, LOQ, 15IRH8, 82XV00BRIN, 2023, Gaming...
# 81   [Acer, C733, NX.H8VSI.004, Chromebook, (Celero...
# 495  [‎Lenovo, V15, G2, IJL, 82QYA00HIN, Laptop, (C...
# 601  [Samsung, Galaxy, Book, Go, Laptop, (Snapdrago...
# 612  [Lenovo, Chromebook, 3, 82BA0003US, Laptop, (I...
# 614  [Lenovo, IdeaPad, 3, CB, 11IGL05, 82BA001PHA, ...
# 621  [HP, 11A-NA0002MU, Chromebook, (MT8183/, 4GB/,...

# %%
df.loc[temp_df7.index,temp_df7.columns]=temp_df7.values

# %%
df['os'].value_counts()
# Out:
# os
# windows    710
# other       29
# Mac         17
#              4
# Name: count, dtype: int64

# %%
df['os']=df['os'].replace('',np.nan)

# %%
df['os'].value_counts()
# Out:
# os
# windows    710
# other       29
# Mac         17
# Name: count, dtype: int64

# %%
## graphics
df['graphics'].value_counts()
# Out:
# graphics
# Intel Iris Xe Graphics           70
# Intel UHD Graphics               57
# Intel Integrated UHD             53
# 4 GB NVIDIA GeForce RTX 3050     52
# Intel Integrated Iris Xe         44
#                                  ..
# 12 GB NVIDIA GeForce RTX 4080     1
# 12 GB NVIDIA Geforce RTX 4080     1
# 8 GB NVIDIA RTX 3000 Ada          1
# 4 GB NVIDIA GeForce GTX 2050      1
# Intel Integrated UHD 600          1
# Name: count, Length: 127, dtype: int64

# %%
pd.set_option('display.max_rows',760)

# %%
df['graphics']=df['graphics'].str.strip()

# %%
#display
df['display']=df['display'].str.strip()

# %%
df['display'].value_counts()
# Out:
# display
# 15.6 inches, 1920 x 1080 pixels                  391
# 14 inches, 1920 x 1080 pixels                     87
# 16 inches, 1920 x 1200 pixels                     36
# 16 inches, 2560 x 1600 pixels                     24
# 14 inches, 1920 x 1200 pixels, Touch Screen       19
# 14 inches, 1920 x 1200 pixels                     16
# 14 inches, 2880 x 1800 pixels                     15
# 15.6 inches, 1366 x 768 pixels                    14
# 11.6 inches, 1366 x 768 pixels                    13
# 16.1 inches, 1920 x 1080 pixels                   10
# 17.3 inches, 1920 x 1080 pixels                    8
# 14 inches, 1920 x 1080 pixels, Touch Screen        8
# 14 inches, 1366 x 768 pixels                       7
# 14.2 inches, 3024 x 1964 pixels                    6
# 13.3 inches, 2560 x 1600 pixels                    5
# 15.6 inches, 1920 x 1080 pixels, Touch Screen      5
# 14 inches, 2880 x 1800 pixels, Touch Screen        5
# 15.6 inches, 2560 x 1440 pixels                    4
# 16 inches, 1920 x 1080 pixels                      4
# 16.1 inches, 2560 x 1440 pixels                    4
# 13.3 inches, 1920 x 1080 pixels, Touch Screen      3
# 14.1 inches, 1366 x 768 pixels                     3
# 16.2 inches, 3456 x 2234 pixels                    3
# 15.6 inches, 1080 x 1920 pixels                    3
# 14 inches, 1080 x 1920 pixels                      3
# 16.1 inches, 2560 x 1600 pixels                    3
# 16 inches, 3840 x 2400 pixels                      3
# 15.6 inches, 2880 x 1620 pixels                    3
# 14.1 inches, 1920 x 1080 pixels                    3
# 13.3 inches, 1920 x 1080 pixels                    3
# 17.3 inches, 2560 x 1440 pixels                    3
# 14 inches, 2240 x 1400 pixels                      2
# 16 inches, 3200 x 2000 pixels                      2
# 13.4 inches, 1920 x 1200 pixels, Touch Screen      2
# 13.3 inches, 1080 x 1920 pixels                    2
# 13.6 inches, 2560 x 1664 pixels                    2
# 13.4 inches, 2560 x 1600 pixels, Touch Screen      2
# 13.3 inches, 1920 x 1200 pixels                    2
# 15.6 inches, 3200 x 2000 pixels                    2
# 15.3 inches, 2880 x 1864 pixels                    2
# 14 inches, 1366 x 768 pixels, Touch Screen         1
# 17.3 inches, 3840 x 2160 pixels                    1
# 17 inches, 2560 x 1600 pixels                      1
# 15 inches, 1920 x 1080 pixels                      1
# 17 inches, 3840 x 2400 pixels, Touch Screen        1
# 13 inches, 1920 x 1080 pixels, Touch Screen        1
# 14 inches, 1440 x 2160 pixels                      1
# 16 inches, 2880 x 1800 pixels                      1
# 13.5 inches, 2256 x 1504 pixels, Touch Screen      1
# 14 inches, 2560 x 1600 pixels                      1
# 16 inches, 1200 x 1920 pixels                      1
# 14 inches, 2160 x 1440 pixels                      1
# 18 inches, 1920 x 1200 pixels                      1
# 18 inches, 3200 x 1800 pixels                      1
# 14 inches, 3840 x 2400 pixels, Touch Screen        1
# 16 inches, 2880 x 1800 pixels, Touch Screen        1
# 13 inches, 2880 x 1920 pixels, Touch Screen        1
# 15.56 inches, 1920 x 1080 pixels                   1
# 11.6 inches, 1366 x 768 pixels, Touch Screen       1
# 15 inches, 2496 x 1664 pixels, Touch Screen        1
# 14.1 inches, 2560 x 1600 pixels, Touch Screen      1
# 13.3 inches, 2560 x 1600 pixels, Touch Screen      1
# 13.5 inches, 3000 x 2000 pixels, Touch Screen      1
# 15.6 inches, 1366 x 720 pixels                     1
# 14 inches, 1280 x 1024 pixels                      1
# 13.3 inches, 1920 x 1200 pixels, Touch Screen      1
# 14.5 inches, 2560 x 1600 pixels                    1
# 14.5 inches, 3072 x 1920 pixels                    1
# Name: count, dtype: int64

# %%
temp_df8=df[df['display'].str.contains("Touch Screen")]

# %%
temp_df8['Touchscreen']="touchscreen"
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\2411183411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df8['Touchscreen']="touchscreen"

# %%
temp_df8
# Out:
#      index                                               name   price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...   52000
# 99     100  Asus ROG Flow X13 GV301RC-LJ073WS Gaming Lapto...  131990
# 124    125  Asus Vivobook S14 Flip 2022 TN3402QA-LZ741WS L...   64990
# 132    133  HP Chromebook 14a-na1004TU Laptop (Celeron N45...   17990
# 154    155  Dell Latitude 7440 14 Laptop (13th Gen Core i5...  152000
# 155    156  Lenovo Yoga 7 82YM0074IN Laptop (AMD Ryzen 7 7...   97990
# 156    157  Dell Latitude 7440 Laptop (13th Gen Core i5/ 1...  152000
# 191    192  HP Pavilion x360 14-ek1010TU Laptop (13th Gen ...   77889
# 205    206  Asus Vivobook 15 Touch X515EA-EZ311WS Laptop (...   38990
# 208    209  Lenovo Tab Yoga Duet 7 (11th Gen Core i5/ 8GB/...   47999
# 230    231  Asus Chromebook CX1400FKA-EC0158 Laptop (Celer...   20990
# 257    258  Dell XPS 17 9730 Laptop (13th Gen Core i9/ 32G...  354490
# 269    270  Asus ROG Flow Z13 2023 GZ301VV-MU014WS Gaming ...  209990
# 301    302  Asus Vivobook S14 Flip 2022 TN3402QA-LZ501WS L...   55800
# 303    304  HP Pavilion x360 14-ek0074TU Laptop (12th Gen ...   74990
# 330    331  Lenovo Yoga 7 82YL0095IN Laptop (13th Gen Core...   92890
# 335    336  Dell Inspiron 7430 2 in 1 2023 Laptop (13th Ge...   57990
# 345    346  Lenovo IdeaPad Flex 5 14IRU8 82Y00051IN Laptop...   76890
# 360    361  Chuwi FreeBook Laptop (12th Gen Core i3/ 12GB/...   37990
# 408    409  Asus Zenbook Flip 14 OLED UP5401ZA-KU741WS Lap...   89990
# 430    431  Dell Inspiron 7430 2 in 1 Laptop (13th Gen Cor...   58990
# 434    435  Lenovo Ideapad Flex 5i 14IAU7 82R70067IN Lapto...   49990
# 436    437  HP Envy 15-fe0032TU Laptop (13th Gen Core i7/ ...  116990
# 456    457  Dell Inspiron 7430 IC7430FD64T001ORS1 Laptop (...   97990
# 463    464  HP Pavilion x360 14-ek1020TU Laptop (13th Gen ...   92070
# 483    484  Asus Vivobook S14 Flip 2022 TN3402QA-LZ540WS L...   62990
# 489    490  Asus Zenbook 14 OLED 2023 UX3402VA-KN541WS Lap...   94399
# 494    495  Asus Zenbook 14 Flip OLED 2023 UP3404VA-KN542W...  104490
# 520    521  Samsung Galaxy Book 3 360 13 NP730QFG-KA2IN La...  109990
# 521    522  Samsung Galaxy Book 3 360 NP750QFG-KA1IN Lapto...  122990
# 522    523  Samsung Galaxy Book 3 Pro 360 NP960QFG-KA3IN L...  179990
# 523    524  Samsung Galaxy Book 3 360 NP750QFG-KA3IN Lapto...  138990
# 535    536  HP Envy x360 13-bf0121TU  Laptop (12th Gen Cor...   85490
# 545    546  Microsoft Surface Pro 9 Laptop (12th Gen Core ...  261990
# 549    550  Lenovo IdeaPad Flex 5 82R90068IN Laptop (AMD R...   62890
# 556    557  Asus VivoBook 14 2022 X1402ZA-MW311WS Laptop (...   49990
# 558    559  HP Envy x360 13-bf0078TU Laptop (12th Gen Core...   81990
# 586    587  Dell Inspiron 7420 Laptop (12th Gen Core i5/ 8...   72990
# 621    622  HP 11A-NA0002MU Chromebook (MT8183/ 4GB/ 64GB ...   17990
# 625    626  Microsoft Surface Laptop 3 1873 (V4G-00021) La...   60390
# 629    630  Dell Latitude 13 5320 2 in 1 Laptop (11th Gen ...   89999
# 630    631  Dell Latitude 9430 Laptop (12th Gen Core i7/ 3...  260000
# 641    642  Lenovo Yoga Slim 7i Carbon 13IRP8 83AY003CIN L...  132590
# 644    645  Asus Chromebook CX1400FKA-EC0168 Laptop (Celer...   32990
# 646    647  HP Spectre x360 14-ef2036TU Laptop (13th Gen C...  145990
# 654    655  Dell Inspiron 7430 IC7430MH5K0M01ORS1 Laptop (...   74990
# 659    660  Lenovo IdeaPad Flex 5 82R9008FIN Laptop (AMD R...   61990
# 670    671  Acer Chromebook Spin CP714-2WN Laptop (13th Ge...   87999
# 673    674  Asus ROG Flow X13 GV302XV-MU016WS Gaming Lapto...  188752
# 708    709  Lenovo IdeaPad Flex 5 14IRU8 82Y0004TIN Laptop...   89990
# 718    719  Asus Vivobook S14 Flip TN3402QA-LZ751WS Laptop...   75000
# 727    728  Lenovo IdeaPad Flex 5 Gen 8 82XX0070IN Laptop ...   61990
# 733    734  Lenovo Yoga 6 13ABR8 83B2007UIN Laptop (AMD Ry...   88990
# 734    735  Lenovo IdeaPad Flex 5 82R900D4IN Laptop (AMD R...   61990
# 738    739  HP Pavilion x360 14-ek1021TU Laptop (13th Gen ...   91590
# 754    755  Lenovo Yoga 7 82YL0060IN Laptop (13th Gen Core...  112990
# 755    756  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...   91101
#
#           os                             graphics  \
# 0    windows             4 GB AMD Radeon RX 6500M
# 99   windows        4 GB ‎NVIDIA GeForce RTX 3050
# 124  windows                  AMD Radeon Graphics
# 132    other        Intel Integrated UHD Graphics
# 154  windows               Intel Iris Xe Graphics
# 155  windows                  AMD Radeon Graphics
# 156  windows               Intel Iris Xe Graphics
# 191  windows             Intel Integrated Iris Xe
# 205  windows        Intel Integrated UHD Graphics
# 208  windows               Intel Iris Xe Graphics
# 230    other                 Intel Integrated UHD
# 257  windows         8 GB NVIDIA GeForce RTX 4070
# 269  windows         8 GB NVIDIA GeForce RTX 4060
# 301  windows                  AMD Radeon Graphics
# 303  windows             Intel Integrated Iris Xe
# 330  windows    Integrated Intel Iris Xe Graphics
# 335  windows                   Intel UHD Graphics
# 345  windows             Intel Integrated Iris Xe
# 360  windows  Intel Integrated Intel UHD Graphics
# 408  windows             Intel Integrated Iris Xe
# 430  windows                   Intel UHD Graphics
# 434  windows                 Intel Integrated UHD
# 436  windows                Intel Iris X Graphics
# 456  windows               Intel Iris Xe Graphics
# 463  windows             Intel Integrated Iris Xe
# 483  windows                       AMD Radeon AMD
# 489  windows               Intel Iris Xe Graphics
# 494  windows               Intel Iris Xe Graphics
# 520  windows               Intel Iris Xe Graphics
# 521  windows               Intel Iris Xe Graphics
# 522  windows               Intel Iris Xe Graphics
# 523  windows               Intel Iris Xe Graphics
# 535  windows             Intel Integrated Iris Xe
# 545  windows               Intel Iris Xe Graphics
# 549  windows                           AMD Radeon
# 556  windows                 Intel Integrated UHD
# 558  windows                Intel Iris X Graphics
# 586  windows            2 GB NVIDIA GeForce MX550
# 621    other                                  NaN
# 625  windows                    AMD Radeon Vega 9
# 629  windows                   Intel UHD Graphics
# 630  windows               Intel Iris Xe Graphics
# 641  windows             Intel Integrated Iris Xe
# 644    other                 Intel Integrated UHD
# 646  windows               Intel Iris Xe Graphics
# 654  windows                     Intel Integrated
# 659  windows                  AMD Radeon Graphics
# 670    other                 Intel Integrated UHD
# 673  windows         8 GB NVIDIA GeForce RTX 4060
# 708  windows             Intel Integrated Iris Xe
# 718  windows                  AMD Radeon Graphics
# 727  windows                       AMD Radeon AMD
# 733  windows                  AMD Radeon Graphics
# 734  windows                           AMD Radeon
# 738  windows             Intel Integrated Iris Xe
# 754  windows    Integrated Intel Iris Xe Graphics
# 755  windows              ‎Intel Iris Xe Graphics
#
#                                            display                ram  rom  \
# 0    15.6 inches, 1920 x 1080 pixels, Touch Screen      8 GB DDR4 RAM  NaN
# 99   13.4 inches, 1920 x 1200 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 124    14 inches, 1920 x 1200 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 132     14 inches, 1366 x 768 pixels, Touch Screen    4 GB LPDDR4 RAM  NaN
# 154    14 inches, 1920 x 1200 pixels, Touch Screen         16 GB  RAM  NaN
# 155    14 inches, 2880 x 1800 pixels, Touch Screen     16 GB DDR5 RAM  NaN
# 156    14 inches, 1920 x 1200 pixels, Touch Screen         16 GB  RAM  NaN
# 191    14 inches, 1920 x 1080 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 205  15.6 inches, 1920 x 1080 pixels, Touch Screen      8 GB DDR4 RAM  NaN
# 208    13 inches, 1920 x 1080 pixels, Touch Screen          8 GB  RAM  NaN
# 230    14 inches, 1920 x 1080 pixels, Touch Screen   4 GB LPDDR4X RAM  NaN
# 257    17 inches, 3840 x 2400 pixels, Touch Screen     32 GB DDR5 RAM  NaN
# 269  13.4 inches, 2560 x 1600 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 301    14 inches, 1920 x 1200 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 303    14 inches, 1920 x 1080 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 330    14 inches, 2880 x 1800 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 335    14 inches, 1920 x 1200 pixels, Touch Screen    8 GB LPDDR5 RAM  NaN
# 345    14 inches, 1920 x 1200 pixels, Touch Screen  16 GB LPDDR4X RAM  NaN
# 360  13.5 inches, 2256 x 1504 pixels, Touch Screen   12 GB LPDDR4 RAM  NaN
# 408    14 inches, 3840 x 2400 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 430    14 inches, 1920 x 1200 pixels, Touch Screen    8 GB LPDDR5 RAM  NaN
# 434    14 inches, 1920 x 1080 pixels, Touch Screen    8 GB LPDDR4 RAM  NaN
# 436  15.6 inches, 1920 x 1080 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 456    14 inches, 1920 x 1200 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 463    14 inches, 1920 x 1080 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 483    14 inches, 1920 x 1200 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 489    14 inches, 2880 x 1800 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 494    14 inches, 2880 x 1800 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 520  13.3 inches, 1920 x 1080 pixels, Touch Screen  16 GB LPDDR4x RAM  NaN
# 521  15.6 inches, 1920 x 1080 pixels, Touch Screen  16 GB LPDDR4x RAM  NaN
# 522    16 inches, 2880 x 1800 pixels, Touch Screen     16 GB DDR5 RAM  NaN
# 523  15.6 inches, 1920 x 1080 pixels, Touch Screen  16 GB LPDDR4x RAM  NaN
# 535  13.4 inches, 1920 x 1200 pixels, Touch Screen  16 GB LPDDR4X RAM  NaN
# 545    13 inches, 2880 x 1920 pixels, Touch Screen   32 GB LPDDR5 RAM  NaN
# 549    14 inches, 1920 x 1200 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 556    14 inches, 1920 x 1080 pixels, Touch Screen      8 GB DDR4 RAM  NaN
# 558  13.3 inches, 1920 x 1080 pixels, Touch Screen   8 GB LPDDR4x RAM  NaN
# 586    14 inches, 1920 x 1200 pixels, Touch Screen      8 GB DDR4 RAM  NaN
# 621   11.6 inches, 1366 x 768 pixels, Touch Screen      4 GB DDR4 RAM  NaN
# 625    15 inches, 2496 x 1664 pixels, Touch Screen      8 GB DDR4 RAM  NaN
# 629  13.3 inches, 1920 x 1080 pixels, Touch Screen      8 GB DDR4 RAM  NaN
# 630  14.1 inches, 2560 x 1600 pixels, Touch Screen   32 GB LPDDR5 RAM  NaN
# 641  13.3 inches, 2560 x 1600 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 644    14 inches, 1920 x 1080 pixels, Touch Screen   8 GB LPDDR4X RAM  NaN
# 646  13.5 inches, 3000 x 2000 pixels, Touch Screen  16 GB LPDDR4X RAM  NaN
# 654    14 inches, 1920 x 1200 pixels, Touch Screen    8 GB LPDDR5 RAM  NaN
# 659    14 inches, 1920 x 1200 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 670    14 inches, 1920 x 1200 pixels, Touch Screen  16 GB LPDDR4X RAM  NaN
# 673  13.4 inches, 2560 x 1600 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 708    14 inches, 1920 x 1200 pixels, Touch Screen  16 GB LPDDR4X RAM  NaN
# 718    14 inches, 1920 x 1200 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 727    14 inches, 1920 x 1200 pixels, Touch Screen  16 GB LPDDR4X RAM  NaN
# 733  13.3 inches, 1920 x 1200 pixels, Touch Screen  16 GB LPDDR4X RAM  NaN
# 734    14 inches, 1920 x 1200 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 738    14 inches, 1920 x 1080 pixels, Touch Screen     16 GB DDR4 RAM  NaN
# 754    14 inches, 2880 x 1800 pixels, Touch Screen   16 GB LPDDR5 RAM  NaN
# 755    14 inches, 1920 x 1200 pixels, Touch Screen         16 GB  RAM  NaN
#
#              warranty  rating                            core  \
# 0     1 Year Warranty    73.0           Hexa Core, 12 Threads
# 99    1 Year Warranty    79.0           Octa Core, 16 Threads
# 124   1 Year Warranty    70.0           Octa Core, 16 Threads
# 132   1 Year Warranty     NaN            Dual Core, 2 Threads
# 154  Backlit Keyboard     NaN  10 Cores (2P + 8E), 12 Threads
# 155   1 Year Warranty    80.0           Octa Core, 16 Threads
# 156  Backlit Keyboard     NaN  10 Cores (2P + 8E), 12 Threads
# 191   1 Year Warranty    70.0  10 Cores (2P + 8E), 12 Threads
# 205   1 Year Warranty     NaN            Dual Core, 4 Threads
# 208   1 Year Warranty     NaN            Quad Core, 8 Threads
# 230   1 Year Warranty     NaN            Dual Core, 2 Threads
# 257   1 Year Warranty     NaN  14 Cores (6P + 8E), 20 Threads
# 269   1 Year Warranty    73.0  14 Cores (6P + 8E), 20 Threads
# 301   1 Year Warranty     NaN           Hexa Core, 12 Threads
# 303   1 Year Warranty    67.0  10 Cores (2P + 8E), 12 Threads
# 330   1 Year Warranty    75.0  12 Cores (4P + 8E), 16 Threads
# 335   1 Year Warranty     NaN  Hexa Core (2P + 4E), 8 Threads
# 345   1 Year Warranty    64.0  10 Cores (2P + 8E), 12 Threads
# 360   1 Year Warranty     NaN  Hexa Core (2P + 4E), 8 Threads
# 408   1 Year Warranty    75.0  14 Cores (6P + 8E), 20 Threads
# 430   1 Year Warranty     NaN  Hexa Core (2P + 4E), 8 Threads
# 434   1 Year Warranty    64.0  Hexa Core (2P + 4E), 8 Threads
# 436   1 Year Warranty    70.0  10 Cores (2P + 8E), 12 Threads
# 456   1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 463   1 Year Warranty    71.0  10 Cores (2P + 8E), 12 Threads
# 483   1 Year Warranty    65.0           Hexa Core, 12 Threads
# 489   1 Year Warranty    75.0  12 Cores (4P + 8E), 16 Threads
# 494   1 Year Warranty    71.0  12 Cores (4P + 8E), 16 Threads
# 520   1 Year Warranty    66.0  10 Cores (2P + 8E), 12 Threads
# 521   1 Year Warranty    72.0  12 Cores (4P + 8E), 16 Threads
# 522   1 Year Warranty    81.0  12 Cores (4P + 8E), 16 Threads
# 523   1 Year Warranty    74.0  12 Cores (4P + 8E), 16 Threads
# 535   1 Year Warranty    71.0            10 Cores, 12 Threads
# 545   1 Year Warranty    65.0  10 Cores (2P + 8E), 12 Threads
# 549   1 Year Warranty    74.0           Octa Core, 16 Threads
# 556   1 Year Warranty    62.0  10 Cores (2P + 8E), 12 Threads
# 558   1 Year Warranty    64.0  10 Cores (2P + 8E), 12 Threads
# 586   1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 621   1 Year Warranty     NaN                       Octa Core
# 625   1 Year Warranty     NaN            Quad Core, 8 Threads
# 629   1 Year Warranty    62.0            Quad Core, 8 Threads
# 630   1 Year Warranty    62.0  10 Cores (2P + 8E), 12 Threads
# 641   1 Year Warranty    67.0  12 Cores (4P + 8E), 16 Threads
# 644   1 Year Warranty     NaN            Dual Core, 2 Threads
# 646   1 Year Warranty    70.0  10 Cores (2P + 8E), 12 Threads
# 654   1 Year Warranty    64.0  10 Cores (2P + 8E), 12 Threads
# 659   1 Year Warranty    69.0           Hexa Core, 12 Threads
# 670   1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
# 673   1 Year Warranty    75.0           Octa Core, 16 Threads
# 708   1 Year Warranty    65.0  10 Cores (2P + 8E), 12 Threads
# 718   1 Year Warranty    62.0           Octa Core, 16 Threads
# 727   1 Year Warranty    69.0           Hexa Core, 12 Threads
# 733   1 Year Warranty    71.0           Octa Core, 16 Threads
# 734   1 Year Warranty    63.0           Octa Core, 16 Threads
# 738   1 Year Warranty    70.0  10 Cores (2P + 8E), 12 Threads
# 754   1 Year Warranty    76.0  12 Cores (4P + 8E), 16 Threads
# 755   1 Year Warranty     NaN  10 Cores (2P + 8E), 12 Threads
#
#                          intel_core  \
# 0         5th Gen AMD Ryzen 5 5600H
# 99      6th Gen AMD Ryzen 9 6900HS​
# 124       5th Gen AMD Ryzen 7 5800H
# 132            Intel Celeron  N4500
# 154    13th Gen Intel Core i5 1345U
# 155       7th Gen AMD Ryzen 7 7735U
# 156    13th Gen Intel Core i5 1345U
# 191    13th Gen Intel Core i5 1335U
# 205   11th Gen Intel Core i3 1115G4
# 208  11th Gen Intel Core i5 1135G7
# 230             Intel Celeron N4500
# 257   13th Gen Intel Core i9 13900H
# 269   13th Gen Intel Core i9 13900H
# 301      5th Gen AMD Ryzen 5  5600H
# 303    12th Gen Intel Core i5 1235U
# 330    13th Gen Intel Core i5 1340P
# 335    13th Gen Intel Core i3 1315U
# 345    13th Gen Intel Core i5 1335U
# 360    12th Gen Intel Core i3 1215U
# 408   12th Gen Intel Core i7 12700H
# 430    13th Gen Intel Core i3 1315U
# 434    12th Gen Intel Core i3 1215U
# 436    13th Gen Intel Core i7 1355U
# 456    13th Gen Intel Core i7 1355U
# 463   13th Gen Intel Core i7 1355U
# 483       5th Gen AMD Ryzen 5 5600H
# 489    13th Gen Intel Core i5 1340P
# 494    13th Gen Intel Core i5 1340P
# 520    13th Gen Intel Core i7 1355U
# 521    13th Gen Intel Core i7 1360P
# 522    13th Gen Intel Core i7 1360P
# 523    13th Gen Intel Core i7 1360P
# 535    12th Gen Intel Core i5 1230U
# 545    12th Gen Intel Core i7 1255U
# 549       5th Gen AMD Ryzen 7 5700U
# 556    12th Gen Intel Core i3 1220P
# 558    12th Gen Intel Core i5 1230U
# 586    12th Gen Intel Core i5 1235U
# 621          MediaTek MT8183 MT8183
# 625      3rd Gen AMD Ryzen 5  3580U
# 629   11th Gen Intel Core i5 1135G7
# 630    12th Gen Intel Core i7 1265U
# 641    13th Gen Intel Core i7 1360P
# 644             Intel Celeron N4500
# 646    13th Gen Intel Core i7 1355U
# 654    13th Gen Intel Core i5 1335U
# 659      5th Gen AMD Ryzen 5  5500U
# 670    13th Gen Intel Core i5 1335U
# 673     7th Gen AMD Ryzen 9  7940HS
# 708    13th Gen Intel Core i7 1355U
# 718       5th Gen AMD Ryzen 7 5800H
# 727       7th Gen AMD Ryzen 5 7530U
# 733       7th Gen AMD Ryzen 7 7730U
# 734       5th Gen AMD Ryzen 7 5700U
# 738   13th Gen Intel Core i7 1355U
# 754    13th Gen Intel Core i7 1360P
# 755    13th Gen Intel Core i7 1355U
#
#                                                  brand  Touchscreen
# 0    [HP, Victus, 15-fb0157AX, Gaming, Laptop, (AMD...  touchscreen
# 99   [Asus, ROG, Flow, X13, GV301RC-LJ073WS, Gaming...  touchscreen
# 124  [Asus, Vivobook, S14, Flip, 2022, TN3402QA-LZ7...  touchscreen
# 132  [HP, Chromebook, 14a-na1004TU, Laptop, (Celero...  touchscreen
# 154  [Dell, Latitude, 7440, 14, Laptop, (13th, Gen,...  touchscreen
# 155  [Lenovo, Yoga, 7, 82YM0074IN, Laptop, (AMD, Ry...  touchscreen
# 156  [Dell, Latitude, 7440, Laptop, (13th, Gen, Cor...  touchscreen
# 191  [HP, Pavilion, x360, 14-ek1010TU, Laptop, (13t...  touchscreen
# 205  [Asus, Vivobook, 15, Touch, X515EA-EZ311WS, La...  touchscreen
# 208  [Lenovo, Tab, Yoga, Duet, 7, (11th, Gen, Core,...  touchscreen
# 230  [Asus, Chromebook, CX1400FKA-EC0158, Laptop, (...  touchscreen
# 257  [Dell, XPS, 17, 9730, Laptop, (13th, Gen, Core...  touchscreen
# 269  [Asus, ROG, Flow, Z13, 2023, GZ301VV-MU014WS, ...  touchscreen
# 301  [Asus, Vivobook, S14, Flip, 2022, TN3402QA-LZ5...  touchscreen
# 303  [HP, Pavilion, x360, 14-ek0074TU, Laptop, (12t...  touchscreen
# 330  [Lenovo, Yoga, 7, 82YL0095IN, Laptop, (13th, G...  touchscreen
# 335  [Dell, Inspiron, 7430, 2, in, 1, 2023, Laptop,...  touchscreen
# 345  [Lenovo, IdeaPad, Flex, 5, 14IRU8, 82Y00051IN,...  touchscreen
# 360  [Chuwi, FreeBook, Laptop, (12th, Gen, Core, i3...  touchscreen
# 408  [Asus, Zenbook, Flip, 14, OLED, UP5401ZA-KU741...  touchscreen
# 430  [Dell, Inspiron, 7430, 2, in, 1, Laptop, (13th...  touchscreen
# 434  [Lenovo, Ideapad, Flex, 5i, 14IAU7, 82R70067IN...  touchscreen
# 436  [HP, Envy, 15-fe0032TU, Laptop, (13th, Gen, Co...  touchscreen
# 456  [Dell, Inspiron, 7430, IC7430FD64T001ORS1, Lap...  touchscreen
# 463  [HP, Pavilion, x360, 14-ek1020TU, Laptop, (13t...  touchscreen
# 483  [Asus, Vivobook, S14, Flip, 2022, TN3402QA-LZ5...  touchscreen
# 489  [Asus, Zenbook, 14, OLED, 2023, UX3402VA-KN541...  touchscreen
# 494  [Asus, Zenbook, 14, Flip, OLED, 2023, UP3404VA...  touchscreen
# 520  [Samsung, Galaxy, Book, 3, 360, 13, NP730QFG-K...  touchscreen
# 521  [Samsung, Galaxy, Book, 3, 360, NP750QFG-KA1IN...  touchscreen
# 522  [Samsung, Galaxy, Book, 3, Pro, 360, NP960QFG-...  touchscreen
# 523  [Samsung, Galaxy, Book, 3, 360, NP750QFG-KA3IN...  touchscreen
# 535  [HP, Envy, x360, 13-bf0121TU, , Laptop, (12th,...  touchscreen
# 545  [Microsoft, Surface, Pro, 9, Laptop, (12th, Ge...  touchscreen
# 549  [Lenovo, IdeaPad, Flex, 5, 82R90068IN, Laptop,...  touchscreen
# 556  [Asus, VivoBook, 14, 2022, X1402ZA-MW311WS, La...  touchscreen
# 558  [HP, Envy, x360, 13-bf0078TU, Laptop, (12th, G...  touchscreen
# 586  [Dell, Inspiron, 7420, Laptop, (12th, Gen, Cor...  touchscreen
# 621  [HP, 11A-NA0002MU, Chromebook, (MT8183/, 4GB/,...  touchscreen
# 625  [Microsoft, Surface, Laptop, 3, 1873, (V4G-000...  touchscreen
# 629  [Dell, Latitude, 13, 5320, 2, in, 1, Laptop, (...  touchscreen
# 630  [Dell, Latitude, 9430, Laptop, (12th, Gen, Cor...  touchscreen
# 641  [Lenovo, Yoga, Slim, 7i, Carbon, 13IRP8, 83AY0...  touchscreen
# 644  [Asus, Chromebook, CX1400FKA-EC0168, Laptop, (...  touchscreen
# 646  [HP, Spectre, x360, 14-ef2036TU, Laptop, (13th...  touchscreen
# 654  [Dell, Inspiron, 7430, IC7430MH5K0M01ORS1, Lap...  touchscreen
# 659  [Lenovo, IdeaPad, Flex, 5, 82R9008FIN, Laptop,...  touchscreen
# 670  [Acer, Chromebook, Spin, CP714-2WN, Laptop, (1...  touchscreen
# 673  [Asus, ROG, Flow, X13, GV302XV-MU016WS, Gaming...  touchscreen
# 708  [Lenovo, IdeaPad, Flex, 5, 14IRU8, 82Y0004TIN,...  touchscreen
# 718  [Asus, Vivobook, S14, Flip, TN3402QA-LZ751WS, ...  touchscreen
# 727  [Lenovo, IdeaPad, Flex, 5, Gen, 8, 82XX0070IN,...  touchscreen
# 733  [Lenovo, Yoga, 6, 13ABR8, 83B2007UIN, Laptop, ...  touchscreen
# 734  [Lenovo, IdeaPad, Flex, 5, 82R900D4IN, Laptop,...  touchscreen
# 738  [HP, Pavilion, x360, 14-ek1021TU, Laptop, (13t...  touchscreen
# 754  [Lenovo, Yoga, 7, 82YL0060IN, Laptop, (13th, G...  touchscreen
# 755  [Lenovo, IdeaPad, Flex, 5, 82Y00053IN, Laptop,...  touchscreen

# %%
df.loc[temp_df8.index,temp_df8.columns]=temp_df8.values

# %%
df['ram'].value_counts()
# Out:
# ram
# 8 GB DDR4 RAM               224
# 16 GB DDR4 RAM              208
# 16 GB DDR5 RAM               76
# 16 GB LPDDR5 RAM             43
# 8 GB LPDDR5 RAM              36
# 8 GB DDR5 RAM                19
# 16 GB LPDDR4X RAM            16
# 32 GB DDR5 RAM               15
# 8 GB LPDDR4X RAM             13
# 4 GB DDR4 RAM                10
# 8 GB  RAM                    10
# 16 GB  LPDDR5 RAM             8
# 16 GB LPDDR4x RAM             7
# 4 GB LPDDR4 RAM               7
# 16 GB  RAM                    6
# 8 GB DDR4  RAM                6
# 8 GB LPDDR4 RAM               5
# 16 GB LPDDR4 RAM              5
# 18 GB  RAM                    3
# 16 GB LPDDR5  RAM             3
# 64 GB DDR5 RAM                3
# 32 GB LPDDR5 RAM              3
# 8 GB LPDDR5  RAM              3
# 32 GB LPDDR5X RAM             2
# 8 GB LPDDR4x RAM              2
# 16 GB Unified Memory RAM      2
# 4 GB LPDDR4X RAM              2
# 16 GB LPDDR5X RAM             2
# 4 GB LPDDR4x RAM              2
# 16 GB DDR5 SDRAM RAM          1
# 512 GB SSD                    1
# 12 GB DDR4 RAM                1
# 8 GB Unified Memory RAM       1
# 36 GB  RAM                    1
# 16 GB LPDDR5x RAM             1
# 16 GB DDR4  RAM               1
# 16 GB DDR5  RAM               1
# 12 GB LPDDR4 RAM              1
# 8 GB LPDDR4x  RAM             1
# 2 GB DDR3 RAM                 1
# 4 GB ‎LPDDR4 RAM              1
# 16 GB DDR4- RAM               1
# 256 GB SSD                    1
# 64 GB LPDDR5 RAM              1
# 32 GB  RAM                    1
# 32 GB DDR4 RAM                1
# 128 GB Hard Disk              1
# 32 GB Unified Memory RAM      1
# Name: count, dtype: int64

# %%
temp_df9=df[df['ram'].str.contains("SSD")]

# %%
temp_df9
# Out:
#      index                                               name   price     os  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990  other
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990  other
#
#     graphics                          display         ram  rom  \
# 67       NaN  15.6 inches, 1920 x 1080 pixels  512 GB SSD  NaN
# 495      NaN  15.6 inches, 1920 x 1080 pixels  256 GB SSD  NaN
#
#             warranty  rating            core              intel_core  \
# 67   1 Year Warranty    63.0  16 GB DDR5 RAM  13th Gen Intel Core i7
# 495  1 Year Warranty     NaN   8 GB DDR4 RAM    Intel Celeron  N4500
#
#                                                  brand Touchscreen
# 67   [Lenovo, LOQ, 15IRH8, 82XV00BRIN, 2023, Gaming...         NaN
# 495  [‎Lenovo, V15, G2, IJL, 82QYA00HIN, Laptop, (C...         NaN

# %%
temp_df9['rom']=temp_df9['ram']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\2732539836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df9['rom']=temp_df9['ram']

# %%
temp_df9['ram']=temp_df9['core']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\2641221713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df9['ram']=temp_df9['core']

# %%
temp_df9
# Out:
#      index                                               name   price     os  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990  other
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990  other
#
#     graphics                          display             ram         rom  \
# 67       NaN  15.6 inches, 1920 x 1080 pixels  16 GB DDR5 RAM  512 GB SSD
# 495      NaN  15.6 inches, 1920 x 1080 pixels   8 GB DDR4 RAM  256 GB SSD
#
#             warranty  rating            core              intel_core  \
# 67   1 Year Warranty    63.0  16 GB DDR5 RAM  13th Gen Intel Core i7
# 495  1 Year Warranty     NaN   8 GB DDR4 RAM    Intel Celeron  N4500
#
#                                                  brand Touchscreen
# 67   [Lenovo, LOQ, 15IRH8, 82XV00BRIN, 2023, Gaming...         NaN
# 495  [‎Lenovo, V15, G2, IJL, 82QYA00HIN, Laptop, (C...         NaN

# %%
df.loc[temp_df8.index,temp_df8.columns]=temp_df8.values

# %%
df['warranty'].value_counts()
# Out:
# warranty
# 1 Year Warranty     691
# 2 Year Warranty      40
# 3 Year Warranty      10
# Backlit Keyboard      5
# Name: count, dtype: int64

# %%
df[df['warranty']=="Backlit Keyboard"]
# Out:
#      index                                               name   price  \
# 154    155  Dell Latitude 7440 14 Laptop (13th Gen Core i5...  152000
# 156    157  Dell Latitude 7440 Laptop (13th Gen Core i5/ 1...  152000
# 496    497  Dell Precision 3470 Laptop (12th Gen Core i5/ ...  113000
# 527    528  HP 15s-eq2213AU Laptop (AMD Ryzen 3 5300U/ 8GB...   31999
# 623    624  HP Omen 15-ek0025tx Laptop (10th Gen Core i5/ ...   69999
#
#           os                      graphics  \
# 154  windows        Intel Iris Xe Graphics
# 156  windows        Intel Iris Xe Graphics
# 496  windows              4 GB NVIDIA T550
# 527  windows           AMD Radeon Graphics
# 623  windows  4 GB NVIDIA Geforce GTX 1650
#
#                                          display            ram  rom  \
# 154  14 inches, 1920 x 1200 pixels, Touch Screen     16 GB  RAM  NaN
# 156  14 inches, 1920 x 1200 pixels, Touch Screen     16 GB  RAM  NaN
# 496                14 inches, 1920 x 1080 pixels     32 GB  RAM  NaN
# 527              15.6 inches, 1920 x 1080 pixels  8 GB DDR4 RAM  NaN
# 623              15.6 inches, 1920 x 1080 pixels  8 GB DDR4 RAM  NaN
#
#              warranty  rating                            core  \
# 154  Backlit Keyboard     NaN  10 Cores (2P + 8E), 12 Threads
# 156  Backlit Keyboard     NaN  10 Cores (2P + 8E), 12 Threads
# 496  Backlit Keyboard     NaN  12 Cores (4P + 8E), 16 Threads
# 527  Backlit Keyboard     NaN            Quad Core, 8 Threads
# 623  Backlit Keyboard    64.0            Quad Core, 8 Threads
#
#                         intel_core  \
# 154   13th Gen Intel Core i5 1345U
# 156   13th Gen Intel Core i5 1345U
# 496   12th Gen Intel Core i5 1250P
# 527      5th Gen AMD Ryzen 3 5300U
# 623  10th Gen Intel Core i5 10300H
#
#                                                  brand  Touchscreen
# 154  [Dell, Latitude, 7440, 14, Laptop, (13th, Gen,...  touchscreen
# 156  [Dell, Latitude, 7440, Laptop, (13th, Gen, Cor...  touchscreen
# 496  [Dell, Precision, 3470, Laptop, (12th, Gen, Co...          NaN
# 527  [HP, 15s-eq2213AU, Laptop, (AMD, Ryzen, 3, 530...          NaN
# 623  [HP, Omen, 15-ek0025tx, Laptop, (10th, Gen, Co...          NaN

# %%
df['warranty']=df['warranty'].replace('Backlit Keyboard',np.nan)

# %%
df['warranty'].value_counts()
# Out:
# warranty
# 1 Year Warranty    691
# 2 Year Warranty     40
# 3 Year Warranty     10
# Name: count, dtype: int64

# %%
df['core'].value_counts()
# Out:
# core
# Quad Core, 8 Threads               119
# 10 Cores (2P + 8E), 12 Threads     105
# Hexa Core, 12 Threads              104
# Octa Core, 16 Threads               78
# 12 Cores (4P + 8E), 16 Threads      67
# Octa Core (4P + 4E), 12 Threads     49
# Dual Core, 4 Threads                47
# Dual Core, 2 Threads                37
# Hexa Core (2P + 4E), 8 Threads      33
# 14 Cores (6P + 8E), 20 Threads      32
# 10 Cores (6P + 4E), 16 Threads      22
# 24 Cores (8P + 16E), 32 Threads     13
# 16 Cores (8P + 8E), 24 Threads      10
# Octa Core                            9
# Octa Core (4P + 4E)                  7
# 5 Cores (1P + 4E), 6 Threads         4
# Octa Core, 8 Threads                 3
# 12 Cores (6P + 6E)                   3
# Quad Core, 4 Threads                 2
# 16 GB DDR5 RAM                       1
# 14 Cores, 20 Threads                 1
# 11 Cores (5P + 6E)                   1
# 16 Cores, 32 Threads                 1
# Octa Core, 12 Threads                1
# Quad Core                            1
# 20 Threads                           1
# 14 Cores (6P + 8E)                   1
# 8 GB DDR4 RAM                        1
# 12 Cores                             1
# 10 Cores, 12 Threads                 1
# 4 GB LPDDR4x  RAM                    1
# 10 Cores (8P + 2E)                   1
# 10 Cores                             1
# Dual Core                            1
# 24 Cores (8P + 16E)                  1
# Name: count, dtype: int64

# %%
temp_df10=df[df['core'].str.contains("RAM")]

# %%
temp_df10
# Out:
#      index                                               name   price     os  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990  other
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990  other
# 601    602  Samsung Galaxy Book Go Laptop (Snapdragon 7c/ ...   29990  other
#
#     graphics                          display               ram  rom  \
# 67       NaN  15.6 inches, 1920 x 1080 pixels        512 GB SSD  NaN
# 495      NaN  15.6 inches, 1920 x 1080 pixels        256 GB SSD  NaN
# 601      NaN    14 inches, 1920 x 1080 pixels  128 GB Hard Disk  NaN
#
#             warranty  rating               core  \
# 67   1 Year Warranty    63.0     16 GB DDR5 RAM
# 495  1 Year Warranty     NaN      8 GB DDR4 RAM
# 601  1 Year Warranty     NaN  4 GB LPDDR4x  RAM
#
#                          intel_core  \
# 67           13th Gen Intel Core i7
# 495            Intel Celeron  N4500
# 601  2nd Gen Qualcomm Snapdragon 7c
#
#                                                  brand Touchscreen
# 67   [Lenovo, LOQ, 15IRH8, 82XV00BRIN, 2023, Gaming...         NaN
# 495  [‎Lenovo, V15, G2, IJL, 82QYA00HIN, Laptop, (C...         NaN
# 601  [Samsung, Galaxy, Book, Go, Laptop, (Snapdrago...         NaN

# %%
temp_df10['core']=np.nan
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\1512050626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df10['core']=np.nan

# %%
df.loc[temp_df10.index,temp_df10.columns]=temp_df10.values

# %%
df['core'].value_counts()
# Out:
# core
# Quad Core, 8 Threads               119
# 10 Cores (2P + 8E), 12 Threads     105
# Hexa Core, 12 Threads              104
# Octa Core, 16 Threads               78
# 12 Cores (4P + 8E), 16 Threads      67
# Octa Core (4P + 4E), 12 Threads     49
# Dual Core, 4 Threads                47
# Dual Core, 2 Threads                37
# Hexa Core (2P + 4E), 8 Threads      33
# 14 Cores (6P + 8E), 20 Threads      32
# 10 Cores (6P + 4E), 16 Threads      22
# 24 Cores (8P + 16E), 32 Threads     13
# 16 Cores (8P + 8E), 24 Threads      10
# Octa Core                            9
# Octa Core (4P + 4E)                  7
# 5 Cores (1P + 4E), 6 Threads         4
# 12 Cores (6P + 6E)                   3
# Octa Core, 8 Threads                 3
# Quad Core, 4 Threads                 2
# 14 Cores, 20 Threads                 1
# 11 Cores (5P + 6E)                   1
# 16 Cores, 32 Threads                 1
# Octa Core, 12 Threads                1
# Quad Core                            1
# 20 Threads                           1
# 14 Cores (6P + 8E)                   1
# 12 Cores                             1
# 10 Cores, 12 Threads                 1
# 10 Cores (8P + 2E)                   1
# 10 Cores                             1
# Dual Core                            1
# 24 Cores (8P + 16E)                  1
# Name: count, dtype: int64

# %%
df['intel_core']=df['intel_core'].str.strip()

# %% [markdown]
# **Creating the feature**

# %%
df['brand']=df['name'].str.split().str[0]

# %%
df.head()
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  rom  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
#
#           warranty  rating                            core  \
# 0  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core   brand  Touchscreen
# 0      5th Gen AMD Ryzen 5 5600H      HP  touchscreen
# 1   12th Gen Intel Core i3 1215U      HP          NaN
# 2   12th Gen Intel Core i5 1240P  Lenovo          NaN
# 3  11th Gen Intel Core i5 11300H  Lenovo          NaN
# 4  11th Gen Intel Core i5 1155G7    Acer          NaN

# %%
df['brand'].value_counts()
# Out:
# brand
# HP           163
# Lenovo       154
# Asus         144
# Acer          78
# Dell          74
# MSI           50
# Apple         17
# Samsung       16
# Infinix       14
# Zebronics      8
# Ultimus        5
# Primebook      4
# Avita          4
# Gigabyte       4
# Wings          3
# Xiaomi         3
# Tecno          3
# Honor          2
# Realme         2
# Chuwi          2
# Fujitsu        2
# Microsoft      2
# iBall          1
# Jio            1
# AXL            1
# Walker         1
# ‎Lenovo        1
# Vaio           1
# Name: count, dtype: int64

# %%
temp_df11=df[df['name'].str.contains("Gaming")]

# %%
temp_df11['Gaming']="gaming"
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\3777204264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df11['Gaming']="gaming"

# %%
df.loc[temp_df11.index,temp_df11.columns]=temp_df11.values

# %%
df.head()
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  rom  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
#
#           warranty  rating                            core  \
# 0  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core   brand  Touchscreen  Gaming
# 0      5th Gen AMD Ryzen 5 5600H      HP  touchscreen  gaming
# 1   12th Gen Intel Core i3 1215U      HP          NaN     NaN
# 2   12th Gen Intel Core i5 1240P  Lenovo          NaN     NaN
# 3  11th Gen Intel Core i5 11300H  Lenovo          NaN  gaming
# 4  11th Gen Intel Core i5 1155G7    Acer          NaN     NaN

# %%
df[df['Touchscreen']=='touchscreen']['name']
# Out:
# 0      HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...
# 99     Asus ROG Flow X13 GV301RC-LJ073WS Gaming Lapto...
# 124    Asus Vivobook S14 Flip 2022 TN3402QA-LZ741WS L...
# 132    HP Chromebook 14a-na1004TU Laptop (Celeron N45...
# 154    Dell Latitude 7440 14 Laptop (13th Gen Core i5...
# 155    Lenovo Yoga 7 82YM0074IN Laptop (AMD Ryzen 7 7...
# 156    Dell Latitude 7440 Laptop (13th Gen Core i5/ 1...
# 191    HP Pavilion x360 14-ek1010TU Laptop (13th Gen ...
# 205    Asus Vivobook 15 Touch X515EA-EZ311WS Laptop (...
# 208    Lenovo Tab Yoga Duet 7 (11th Gen Core i5/ 8GB/...
# 230    Asus Chromebook CX1400FKA-EC0158 Laptop (Celer...
# 257    Dell XPS 17 9730 Laptop (13th Gen Core i9/ 32G...
# 269    Asus ROG Flow Z13 2023 GZ301VV-MU014WS Gaming ...
# 301    Asus Vivobook S14 Flip 2022 TN3402QA-LZ501WS L...
# 303    HP Pavilion x360 14-ek0074TU Laptop (12th Gen ...
# 330    Lenovo Yoga 7 82YL0095IN Laptop (13th Gen Core...
# 335    Dell Inspiron 7430 2 in 1 2023 Laptop (13th Ge...
# 345    Lenovo IdeaPad Flex 5 14IRU8 82Y00051IN Laptop...
# 360    Chuwi FreeBook Laptop (12th Gen Core i3/ 12GB/...
# 408    Asus Zenbook Flip 14 OLED UP5401ZA-KU741WS Lap...
# 430    Dell Inspiron 7430 2 in 1 Laptop (13th Gen Cor...
# 434    Lenovo Ideapad Flex 5i 14IAU7 82R70067IN Lapto...
# 436    HP Envy 15-fe0032TU Laptop (13th Gen Core i7/ ...
# 456    Dell Inspiron 7430 IC7430FD64T001ORS1 Laptop (...
# 463    HP Pavilion x360 14-ek1020TU Laptop (13th Gen ...
# 483    Asus Vivobook S14 Flip 2022 TN3402QA-LZ540WS L...
# 489    Asus Zenbook 14 OLED 2023 UX3402VA-KN541WS Lap...
# 494    Asus Zenbook 14 Flip OLED 2023 UP3404VA-KN542W...
# 520    Samsung Galaxy Book 3 360 13 NP730QFG-KA2IN La...
# 521    Samsung Galaxy Book 3 360 NP750QFG-KA1IN Lapto...
# 522    Samsung Galaxy Book 3 Pro 360 NP960QFG-KA3IN L...
# 523    Samsung Galaxy Book 3 360 NP750QFG-KA3IN Lapto...
# 535    HP Envy x360 13-bf0121TU  Laptop (12th Gen Cor...
# 545    Microsoft Surface Pro 9 Laptop (12th Gen Core ...
# 549    Lenovo IdeaPad Flex 5 82R90068IN Laptop (AMD R...
# 556    Asus VivoBook 14 2022 X1402ZA-MW311WS Laptop (...
# 558    HP Envy x360 13-bf0078TU Laptop (12th Gen Core...
# 586    Dell Inspiron 7420 Laptop (12th Gen Core i5/ 8...
# 621    HP 11A-NA0002MU Chromebook (MT8183/ 4GB/ 64GB ...
# 625    Microsoft Surface Laptop 3 1873 (V4G-00021) La...
# 629    Dell Latitude 13 5320 2 in 1 Laptop (11th Gen ...
# 630    Dell Latitude 9430 Laptop (12th Gen Core i7/ 3...
# 641    Lenovo Yoga Slim 7i Carbon 13IRP8 83AY003CIN L...
# 644    Asus Chromebook CX1400FKA-EC0168 Laptop (Celer...
# 646    HP Spectre x360 14-ef2036TU Laptop (13th Gen C...
# 654    Dell Inspiron 7430 IC7430MH5K0M01ORS1 Laptop (...
# 659    Lenovo IdeaPad Flex 5 82R9008FIN Laptop (AMD R...
# 670    Acer Chromebook Spin CP714-2WN Laptop (13th Ge...
# 673    Asus ROG Flow X13 GV302XV-MU016WS Gaming Lapto...
# 708    Lenovo IdeaPad Flex 5 14IRU8 82Y0004TIN Laptop...
# 718    Asus Vivobook S14 Flip TN3402QA-LZ751WS Laptop...
# 727    Lenovo IdeaPad Flex 5 Gen 8 82XX0070IN Laptop ...
# 733    Lenovo Yoga 6 13ABR8 83B2007UIN Laptop (AMD Ry...
# 734    Lenovo IdeaPad Flex 5 82R900D4IN Laptop (AMD R...
# 738    HP Pavilion x360 14-ek1021TU Laptop (13th Gen ...
# 754    Lenovo Yoga 7 82YL0060IN Laptop (13th Gen Core...
# 755    Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...
# Name: name, dtype: object

# %%
df['Touchscreen'].fillna("not-touchscreen",inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\2240235938.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Touchscreen'].fillna("not-touchscreen",inplace=True)

# %%
df['Gaming'].fillna("not-gaming",inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\634503212.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gaming'].fillna("not-gaming",inplace=True)

# %%
df['display_inches']=df['display'].str.split("inches").str[0]

# %%
df['resolution_width']=df['display'].str.split("x").str[0].str.split(",").str[-1]

# %%
df['display'].str.split("x").str[0].str.split(",").str[-1]
# Out:
# 0       1920
# 1       1920
# 2       2240
# 3       1920
# 4       1920
# 5       1920
# 6       1920
# 7       1920
# 8       2560
# 9       1080
# 10      1920
# 11      1920
# 12      1920
# 13      2560
# 14      1920
# 15      1920
# 16      1920
# 17      1920
# 18      1920
# 19      1920
# 20      1920
# 21      1080
# 22      1920
# 23      1920
# 24      1366
# 25      1920
# 26      1920
# 27      1920
# 28      1920
# 29      1920
# 30      1920
# 31      1920
# 32      1920
# 33      1920
# 34      1920
# 35      1920
# 36      1920
# 37      1920
# 38      1920
# 39      1920
# 40      1920
# 41      1366
# 42      2880
# 43      1920
# 44      1920
# 45      1920
# 46      1366
# 47      1920
# 48      1920
# 49      1920
# 50      1920
# 51      1366
# 52      1920
# 53      1920
# 54      1920
# 55      1920
# 56      1920
# 57      1920
# 58      1920
# 59      1920
# 60      1920
# 61      1920
# 62      1920
# 63      1920
# 64      1920
# 65      2880
# 66      1920
# 67      1920
# 68      1920
# 69      1920
# 70      1920
# 71      1920
# 72      1920
# 73      1366
# 74      1920
# 75      1920
# 76      3840
# 77      1920
# 78      1920
# 79      1920
# 80      1920
# 81      1366
# 82      1920
# 83      1920
# 84      1920
# 85      1920
# 86      1920
# 87      1920
# 88      1920
# 89      1920
# 90      1920
# 91      1920
# 92      1920
# 93      1920
# 94      1920
# 95      1920
# 96      1920
# 97      1920
# 98      3456
# 99      1920
# 100     1920
# 101     1920
# 102     1920
# 103     1920
# 104     1920
# 105     1920
# 106     1920
# 107     1920
# 108     1920
# 109     1920
# 110     1920
# 111     1920
# 112     1920
# 113     1366
# 114     1920
# 115     1920
# 116     1920
# 117     1920
# 118     1920
# 119     1920
# 120     1920
# 121     1920
# 122     1920
# 123     2560
# 124     1920
# 125     1920
# 126     2880
# 127     1920
# 128     1920
# 129     1920
# 130     1920
# 131     1920
# 132     1366
# 133     1920
# 134     1920
# 135     1920
# 136     1920
# 137     1920
# 138     1920
# 139     3200
# 140     1920
# 141     1366
# 142     2880
# 143     1920
# 144     1920
# 145     1366
# 146     1920
# 147     1920
# 148     1920
# 149     1920
# 150     1920
# 151     1920
# 152     1920
# 153     1920
# 154     1920
# 155     2880
# 156     1920
# 157     1920
# 158     1920
# 159     1920
# 160     2880
# 161     1920
# 162     1920
# 163     1920
# 164     1920
# 165     1920
# 166     2880
# 167     1920
# 168     2240
# 169     1920
# 170     1920
# 171     2560
# 172     1920
# 173     1920
# 174     1920
# 175     1920
# 176     1920
# 177     1920
# 178     1920
# 179     1920
# 180     1920
# 181     3200
# 182     1920
# 183     2880
# 184     1920
# 185     2560
# 186     2560
# 187     1920
# 188     1920
# 189     1920
# 190     1920
# 191     1920
# 192     1920
# 193     1366
# 194     1920
# 195     1920
# 196     1920
# 197     1920
# 198     1920
# 199     1920
# 200     1920
# 201     1920
# 202     1920
# 203     1920
# 204     1920
# 205     1920
# 206     2560
# 207     2560
# 208     1920
# 209     2560
# 210     3024
# 211     1920
# 212     3024
# 213     1920
# 214     2560
# 215     1920
# 216     1920
# 217     1366
# 218     1920
# 219     1920
# 220     1920
# 221     1920
# 222     1920
# 223     1920
# 224     1920
# 225     1920
# 226     1920
# 227     1366
# 228     1366
# 229     1920
# 230     1920
# 231     1920
# 232     1920
# 233     1920
# 234     1920
# 235     1920
# 236     1920
# 237     1920
# 238     1920
# 239     1920
# 240     1920
# 241     1920
# 242     1920
# 243     1920
# 244     1920
# 245     1920
# 246     1920
# 247     1920
# 248     1920
# 249     1920
# 250     2560
# 251     1920
# 252     1920
# 253     1920
# 254     1920
# 255     1920
# 256     1920
# 257     3840
# 258     1920
# 259     1920
# 260     1920
# 261     1920
# 262     1920
# 263     2880
# 264     2560
# 265     2880
# 266     1920
# 267     1920
# 268     2560
# 269     2560
# 270     2880
# 271     1920
# 272     1920
# 273     1920
# 274     1920
# 275     2160
# 276     1920
# 277     1920
# 278     1920
# 279     1920
# 280     1920
# 281     1920
# 282     2880
# 283     1920
# 284     1920
# 285     1920
# 286     1920
# 287     3840
# 288     1920
# 289     1920
# 290     1920
# 291     1920
# 292     1920
# 293     2880
# 294     1920
# 295     1920
# 296     1920
# 297     1200
# 298     1920
# 299     1920
# 300     1920
# 301     1920
# 302     1366
# 303     1920
# 304     2560
# 305     1920
# 306     1920
# 307     1920
# 308     1920
# 309     1920
# 310     1920
# 311     1920
# 312     2560
# 313     1920
# 314     2880
# 315     3200
# 316     1440
# 317     1920
# 318     1366
# 319     1920
# 320     1366
# 321     3456
# 322     2560
# 323     1920
# 324     1920
# 325     1920
# 326     1920
# 327     1920
# 328     1920
# 329     1366
# 330     2880
# 331     1920
# 332     1366
# 333     1080
# 334     1920
# 335     1920
# 336     1920
# 337     1920
# 338     1920
# 339     1920
# 340     2560
# 341     2560
# 342     1920
# 343     1920
# 344     1366
# 345     1920
# 346     1920
# 347     1366
# 348     1920
# 349     2560
# 350     1920
# 351     1920
# 352     1920
# 353     1920
# 354     1920
# 355     1920
# 356     1366
# 357     1920
# 358     1920
# 359     1920
# 360     2256
# 361     1920
# 362     3200
# 363     2560
# 364     1920
# 365     1920
# 366     1920
# 367     1920
# 368     1920
# 369     1920
# 370     1920
# 371     1920
# 372     1920
# 373     1920
# 374     1920
# 375     1366
# 376     1920
# 377     1920
# 378     1920
# 379     1920
# 380     1920
# 381     1920
# 382     1920
# 383     1920
# 384     2560
# 385     1920
# 386     1080
# 387     1080
# 388     3840
# 389     3840
# 390     1920
# 391     1920
# 392     1920
# 393     1920
# 394     1920
# 395     1920
# 396     1920
# 397     1920
# 398     1920
# 399     2560
# 400     1920
# 401     1920
# 402     1920
# 403     1920
# 404     2560
# 405     1920
# 406     1920
# 407     1920
# 408     3840
# 409     1920
# 410     1920
# 411     1920
# 412     1920
# 413     1920
# 414     1366
# 415     1920
# 416     3200
# 417     2880
# 418     1920
# 419     1920
# 420     1920
# 421     1920
# 422     1920
# 423     1920
# 424     2560
# 425     1920
# 426     1366
# 427     1920
# 428     2880
# 429     2880
# 430     1920
# 431     1920
# 432     1920
# 433     1920
# 434     1920
# 435     1920
# 436     1920
# 437     1920
# 438     1920
# 439     1920
# 440     1920
# 441     1920
# 442     1920
# 443     1920
# 444     1920
# 445     1920
# 446     1920
# 447     1920
# 448     1920
# 449     1920
# 450     1920
# 451     1920
# 452     1920
# 453     1920
# 454     1920
# 455     1920
# 456     1920
# 457     1366
# 458     1920
# 459     1920
# 460     1920
# 461     1920
# 462     2560
# 463     1920
# 464     1920
# 465     1920
# 466     1920
# 467     1920
# 468     2560
# 469     1920
# 470     1920
# 471     1920
# 472     2560
# 473     2880
# 474     2880
# 475     1920
# 476     1920
# 477     1920
# 478     1920
# 479     1920
# 480     1920
# 481     1920
# 482     1920
# 483     1920
# 484     1920
# 485     1920
# 486     1920
# 487     1920
# 488     1366
# 489     2880
# 490     1366
# 491     1920
# 492     1920
# 493     1920
# 494     2880
# 495     1920
# 496     1920
# 497     1920
# 498     1920
# 499     1920
# 500     1920
# 501     1366
# 502     1920
# 503     1920
# 504     1920
# 505     1920
# 506     1920
# 507     2880
# 508     1920
# 509     1920
# 510     1920
# 511     1920
# 512     1920
# 513     1920
# 514     1920
# 515     1920
# 516     1920
# 517     1920
# 518     2560
# 519     1920
# 520     1920
# 521     1920
# 522     2880
# 523     1920
# 524     1920
# 525     1920
# 526     1920
# 527     1920
# 528     1920
# 529     1920
# 530     1920
# 531     3024
# 532     2880
# 533     1920
# 534     1920
# 535     1920
# 536     1920
# 537     1920
# 538     1920
# 539     1920
# 540     1920
# 541     1920
# 542     1920
# 543     1920
# 544     1920
# 545     2880
# 546     2560
# 547     1920
# 548     1920
# 549     1920
# 550     1920
# 551     1920
# 552     1920
# 553     1920
# 554     2560
# 555     2560
# 556     1920
# 557     1920
# 558     1920
# 559     1920
# 560     1920
# 561     1920
# 562     1920
# 563     1920
# 564     1920
# 565     2560
# 566     1920
# 567     1920
# 568     2560
# 569     1920
# 570     1920
# 571     1920
# 572     1920
# 573     2560
# 574     1920
# 575     1920
# 576     1920
# 577     1920
# 578     1920
# 579     1920
# 580     1920
# 581     1366
# 582     1920
# 583     1080
# 584     1920
# 585     1920
# 586     1920
# 587     1920
# 588     1920
# 589     1920
# 590     1920
# 591     1920
# 592     1920
# 593     1920
# 594     1920
# 595     1920
# 596     1920
# 597     1920
# 598     1920
# 599     1920
# 600     1920
# 601     1920
# 602     1080
# 603     1920
# 604     1080
# 605     1920
# 606     1920
# 607     1920
# 608     1920
# 609     1920
# 610     3024
# 611     3456
# 612     1366
# 613     1920
# 614     1366
# 615     1920
# 616     1920
# 617     1920
# 618     1920
# 619     1920
# 620     1920
# 621     1366
# 622     1920
# 623     1920
# 624     1920
# 625     2496
# 626     1920
# 627     1920
# 628     1920
# 629     1920
# 630     2560
# 631     1920
# 632     1920
# 633     1920
# 634     1920
# 635     1920
# 636     1920
# 637     1920
# 638     1920
# 639     3024
# 640     3024
# 641     2560
# 642     1920
# 643     1920
# 644     1920
# 645     1920
# 646     3000
# 647     1366
# 648     1366
# 649     2880
# 650     1920
# 651     1920
# 652     2560
# 653     1920
# 654     1920
# 655     1920
# 656     1920
# 657     2560
# 658     1920
# 659     1920
# 660     1920
# 661     1920
# 662     1920
# 663     1920
# 664     2560
# 665     1920
# 666     1920
# 667     1920
# 668     1920
# 669     1920
# 670     1920
# 671     1920
# 672     1920
# 673     2560
# 674     1366
# 675     1920
# 676     1920
# 677     1920
# 678     1920
# 679     1920
# 680     1920
# 681     2560
# 682     1920
# 683     1366
# 684     1920
# 685     1920
# 686     1920
# 687     1920
# 688     1920
# 689     2560
# 690     1920
# 691     2560
# 692     1920
# 693     1920
# 694     1920
# 695     1366
# 696     1920
# 697     1920
# 698     1920
# 699     1920
# 700     2560
# 701     1920
# 702     2560
# 703     2560
# 704     1920
# 705     2560
# 706     2560
# 707     1920
# 708     1920
# 709     1920
# 710     1366
# 711     1920
# 712     1920
# 713     1920
# 714     1280
# 715     1920
# 716     1920
# 717     1920
# 718     1920
# 719     1920
# 720     1920
# 721     1920
# 722     1920
# 723     1920
# 724     1920
# 725     1920
# 726     1920
# 727     1920
# 728     1920
# 729     1920
# 730     1920
# 731     1920
# 732     1920
# 733     1920
# 734     1920
# 735     1920
# 736     1920
# 737     2560
# 738     1920
# 739     1920
# 740     1920
# 741     1920
# 742     2560
# 743     3072
# 744     2560
# 745     1920
# 746     1920
# 747     1366
# 748     1920
# 749     1920
# 750     1920
# 751     1920
# 752     1920
# 753     1920
# 754     2880
# 755     1920
# 756     1920
# 757     1920
# 758     1920
# 759     1920
# Name: display, dtype: object

# %%
df.head()
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  rom  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
#
#           warranty  rating                            core  \
# 0  1 Year Warranty    73.0           Hexa Core, 12 Threads
# 1  1 Year Warranty    60.0  Hexa Core (2P + 4E), 8 Threads
# 2  1 Year Warranty    66.0  12 Cores (4P + 8E), 16 Threads
# 3  1 Year Warranty    71.0            Quad Core, 8 Threads
# 4  1 Year Warranty    64.0            Quad Core, 8 Threads
#
#                       intel_core   brand      Touchscreen      Gaming  \
# 0      5th Gen AMD Ryzen 5 5600H      HP      touchscreen      gaming
# 1   12th Gen Intel Core i3 1215U      HP  not-touchscreen  not-gaming
# 2   12th Gen Intel Core i5 1240P  Lenovo  not-touchscreen  not-gaming
# 3  11th Gen Intel Core i5 11300H  Lenovo  not-touchscreen      gaming
# 4  11th Gen Intel Core i5 1155G7    Acer  not-touchscreen  not-gaming
#
#   display_inches resolution_width
# 0          15.6             1920
# 1          15.6             1920
# 2            14             2240
# 3          15.6             1920
# 4          15.6             1920

# %%
df['resolution_height']=df['display'].str.split("x").str[1].str.split("pi").str[0]

# %%
df['resolution_height']
# Out:
# 0       1080
# 1       1080
# 2       1400
# 3       1080
# 4       1080
# 5       1080
# 6       1080
# 7       1080
# 8       1600
# 9       1920
# 10      1080
# 11      1080
# 12      1080
# 13      1664
# 14      1080
# 15      1080
# 16      1080
# 17      1080
# 18      1080
# 19      1080
# 20      1080
# 21      1920
# 22      1080
# 23      1080
# 24       768
# 25      1080
# 26      1080
# 27      1080
# 28      1080
# 29      1080
# 30      1080
# 31      1080
# 32      1080
# 33      1080
# 34      1080
# 35      1080
# 36      1080
# 37      1080
# 38      1080
# 39      1080
# 40      1080
# 41       768
# 42      1800
# 43      1080
# 44      1200
# 45      1080
# 46       768
# 47      1080
# 48      1080
# 49      1080
# 50      1080
# 51       768
# 52      1080
# 53      1080
# 54      1080
# 55      1080
# 56      1080
# 57      1200
# 58      1080
# 59      1080
# 60      1080
# 61      1080
# 62      1080
# 63      1080
# 64      1200
# 65      1800
# 66      1080
# 67      1080
# 68      1200
# 69      1080
# 70      1080
# 71      1080
# 72      1080
# 73       768
# 74      1080
# 75      1080
# 76      2160
# 77      1080
# 78      1080
# 79      1200
# 80      1080
# 81       768
# 82      1080
# 83      1080
# 84      1080
# 85      1080
# 86      1080
# 87      1080
# 88      1080
# 89      1080
# 90      1080
# 91      1080
# 92      1080
# 93      1080
# 94      1080
# 95      1080
# 96      1080
# 97      1080
# 98      2234
# 99      1200
# 100     1080
# 101     1080
# 102     1080
# 103     1200
# 104     1080
# 105     1080
# 106     1080
# 107     1080
# 108     1080
# 109     1080
# 110     1080
# 111     1080
# 112     1080
# 113      768
# 114     1080
# 115     1080
# 116     1080
# 117     1080
# 118     1080
# 119     1080
# 120     1080
# 121     1080
# 122     1200
# 123     1440
# 124     1200
# 125     1080
# 126     1864
# 127     1080
# 128     1080
# 129     1080
# 130     1080
# 131     1080
# 132      768
# 133     1080
# 134     1080
# 135     1080
# 136     1080
# 137     1080
# 138     1080
# 139     2000
# 140     1080
# 141      768
# 142     1800
# 143     1200
# 144     1080
# 145      768
# 146     1080
# 147     1200
# 148     1080
# 149     1200
# 150     1080
# 151     1080
# 152     1080
# 153     1080
# 154     1200
# 155     1800
# 156     1200
# 157     1080
# 158     1080
# 159     1080
# 160     1800
# 161     1080
# 162     1080
# 163     1080
# 164     1080
# 165     1080
# 166     1800
# 167     1200
# 168     1400
# 169     1080
# 170     1080
# 171     1600
# 172     1080
# 173     1080
# 174     1080
# 175     1080
# 176     1200
# 177     1080
# 178     1080
# 179     1080
# 180     1200
# 181     2000
# 182     1080
# 183     1620
# 184     1080
# 185     1600
# 186     1600
# 187     1200
# 188     1080
# 189     1080
# 190     1080
# 191     1080
# 192     1080
# 193      768
# 194     1080
# 195     1080
# 196     1080
# 197     1080
# 198     1080
# 199     1080
# 200     1080
# 201     1080
# 202     1080
# 203     1080
# 204     1080
# 205     1080
# 206     1664
# 207     1600
# 208     1080
# 209     1600
# 210     1964
# 211     1080
# 212     1964
# 213     1080
# 214     1600
# 215     1080
# 216     1080
# 217      768
# 218     1080
# 219     1080
# 220     1080
# 221     1080
# 222     1080
# 223     1080
# 224     1080
# 225     1080
# 226     1080
# 227      768
# 228      768
# 229     1200
# 230     1080
# 231     1080
# 232     1080
# 233     1080
# 234     1080
# 235     1080
# 236     1080
# 237     1080
# 238     1080
# 239     1080
# 240     1080
# 241     1200
# 242     1080
# 243     1080
# 244     1080
# 245     1080
# 246     1080
# 247     1080
# 248     1080
# 249     1200
# 250     1440
# 251     1080
# 252     1200
# 253     1080
# 254     1080
# 255     1080
# 256     1080
# 257     2400
# 258     1080
# 259     1200
# 260     1080
# 261     1080
# 262     1080
# 263     1864
# 264     1440
# 265     1800
# 266     1080
# 267     1080
# 268     1600
# 269     1600
# 270     1800
# 271     1080
# 272     1080
# 273     1080
# 274     1080
# 275     1440
# 276     1080
# 277     1080
# 278     1080
# 279     1080
# 280     1080
# 281     1080
# 282     1620
# 283     1080
# 284     1080
# 285     1200
# 286     1080
# 287     2400
# 288     1080
# 289     1080
# 290     1080
# 291     1080
# 292     1080
# 293     1800
# 294     1080
# 295     1080
# 296     1080
# 297     1920
# 298     1080
# 299     1080
# 300     1080
# 301     1200
# 302      768
# 303     1080
# 304     1600
# 305     1080
# 306     1080
# 307     1080
# 308     1080
# 309     1080
# 310     1080
# 311     1080
# 312     1600
# 313     1080
# 314     1800
# 315     2000
# 316     2160
# 317     1080
# 318      768
# 319     1080
# 320      768
# 321     2234
# 322     1600
# 323     1080
# 324     1080
# 325     1080
# 326     1080
# 327     1080
# 328     1080
# 329      768
# 330     1800
# 331     1080
# 332      768
# 333     1920
# 334     1080
# 335     1200
# 336     1080
# 337     1080
# 338     1080
# 339     1080
# 340     1600
# 341     1600
# 342     1080
# 343     1200
# 344      768
# 345     1200
# 346     1080
# 347      768
# 348     1080
# 349     1600
# 350     1080
# 351     1080
# 352     1080
# 353     1080
# 354     1080
# 355     1080
# 356      768
# 357     1080
# 358     1200
# 359     1080
# 360     1504
# 361     1080
# 362     2000
# 363     1600
# 364     1080
# 365     1080
# 366     1080
# 367     1080
# 368     1080
# 369     1080
# 370     1080
# 371     1200
# 372     1080
# 373     1080
# 374     1080
# 375      768
# 376     1080
# 377     1080
# 378     1200
# 379     1080
# 380     1080
# 381     1200
# 382     1080
# 383     1080
# 384     1440
# 385     1080
# 386     1920
# 387     1920
# 388     2400
# 389     2400
# 390     1080
# 391     1080
# 392     1080
# 393     1080
# 394     1080
# 395     1080
# 396     1080
# 397     1080
# 398     1080
# 399     1440
# 400     1080
# 401     1080
# 402     1080
# 403     1080
# 404     1600
# 405     1080
# 406     1080
# 407     1200
# 408     2400
# 409     1080
# 410     1080
# 411     1080
# 412     1080
# 413     1080
# 414      768
# 415     1200
# 416     1800
# 417     1800
# 418     1080
# 419     1200
# 420     1080
# 421     1080
# 422     1200
# 423     1080
# 424     1440
# 425     1080
# 426      768
# 427     1080
# 428     1800
# 429     1800
# 430     1200
# 431     1080
# 432     1080
# 433     1080
# 434     1080
# 435     1080
# 436     1080
# 437     1200
# 438     1080
# 439     1080
# 440     1080
# 441     1200
# 442     1080
# 443     1080
# 444     1080
# 445     1080
# 446     1080
# 447     1200
# 448     1200
# 449     1080
# 450     1080
# 451     1080
# 452     1080
# 453     1080
# 454     1080
# 455     1080
# 456     1200
# 457      768
# 458     1080
# 459     1080
# 460     1080
# 461     1080
# 462     1600
# 463     1080
# 464     1080
# 465     1200
# 466     1080
# 467     1080
# 468     1600
# 469     1080
# 470     1080
# 471     1080
# 472     1600
# 473     1800
# 474     1620
# 475     1200
# 476     1080
# 477     1080
# 478     1080
# 479     1080
# 480     1080
# 481     1080
# 482     1080
# 483     1200
# 484     1080
# 485     1080
# 486     1080
# 487     1080
# 488      768
# 489     1800
# 490      768
# 491     1080
# 492     1080
# 493     1080
# 494     1800
# 495     1080
# 496     1080
# 497     1080
# 498     1080
# 499     1080
# 500     1080
# 501      768
# 502     1080
# 503     1080
# 504     1080
# 505     1080
# 506     1200
# 507     1800
# 508     1200
# 509     1200
# 510     1080
# 511     1200
# 512     1080
# 513     1080
# 514     1080
# 515     1080
# 516     1080
# 517     1080
# 518     1600
# 519     1080
# 520     1080
# 521     1080
# 522     1800
# 523     1080
# 524     1080
# 525     1080
# 526     1080
# 527     1080
# 528     1080
# 529     1080
# 530     1080
# 531     1964
# 532     1800
# 533     1080
# 534     1080
# 535     1200
# 536     1080
# 537     1080
# 538     1080
# 539     1080
# 540     1080
# 541     1080
# 542     1080
# 543     1080
# 544     1080
# 545     1920
# 546     1600
# 547     1080
# 548     1080
# 549     1200
# 550     1080
# 551     1080
# 552     1080
# 553     1080
# 554     1600
# 555     1600
# 556     1080
# 557     1080
# 558     1080
# 559     1200
# 560     1080
# 561     1080
# 562     1080
# 563     1080
# 564     1080
# 565     1440
# 566     1080
# 567     1080
# 568     1440
# 569     1080
# 570     1080
# 571     1080
# 572     1080
# 573     1600
# 574     1080
# 575     1080
# 576     1080
# 577     1200
# 578     1080
# 579     1080
# 580     1080
# 581      768
# 582     1080
# 583     1920
# 584     1080
# 585     1080
# 586     1200
# 587     1080
# 588     1080
# 589     1080
# 590     1080
# 591     1080
# 592     1080
# 593     1080
# 594     1080
# 595     1080
# 596     1080
# 597     1080
# 598     1080
# 599     1080
# 600     1080
# 601     1080
# 602     1920
# 603     1080
# 604     1920
# 605     1080
# 606     1080
# 607     1080
# 608     1080
# 609     1080
# 610     1964
# 611     2234
# 612      768
# 613     1080
# 614      768
# 615     1080
# 616     1080
# 617     1080
# 618     1080
# 619     1080
# 620     1080
# 621      768
# 622     1080
# 623     1080
# 624     1080
# 625     1664
# 626     1080
# 627     1080
# 628     1080
# 629     1080
# 630     1600
# 631     1200
# 632     1200
# 633     1080
# 634     1080
# 635     1080
# 636     1080
# 637     1080
# 638     1080
# 639     1964
# 640     1964
# 641     1600
# 642     1080
# 643     1080
# 644     1080
# 645     1080
# 646     2000
# 647      720
# 648      768
# 649     1800
# 650     1080
# 651     1080
# 652     1600
# 653     1200
# 654     1200
# 655     1080
# 656     1080
# 657     1600
# 658     1080
# 659     1200
# 660     1080
# 661     1200
# 662     1080
# 663     1080
# 664     1440
# 665     1080
# 666     1200
# 667     1080
# 668     1080
# 669     1080
# 670     1200
# 671     1080
# 672     1080
# 673     1600
# 674      768
# 675     1200
# 676     1200
# 677     1080
# 678     1080
# 679     1080
# 680     1080
# 681     1440
# 682     1080
# 683      768
# 684     1080
# 685     1080
# 686     1080
# 687     1080
# 688     1080
# 689     1600
# 690     1080
# 691     1440
# 692     1080
# 693     1080
# 694     1080
# 695      768
# 696     1080
# 697     1080
# 698     1080
# 699     1080
# 700     1600
# 701     1200
# 702     1600
# 703     1600
# 704     1080
# 705     1600
# 706     1600
# 707     1080
# 708     1200
# 709     1080
# 710      768
# 711     1080
# 712     1080
# 713     1200
# 714     1024
# 715     1080
# 716     1080
# 717     1080
# 718     1200
# 719     1080
# 720     1080
# 721     1080
# 722     1200
# 723     1080
# 724     1080
# 725     1080
# 726     1080
# 727     1200
# 728     1080
# 729     1200
# 730     1080
# 731     1080
# 732     1080
# 733     1200
# 734     1200
# 735     1080
# 736     1200
# 737     1600
# 738     1080
# 739     1080
# 740     1080
# 741     1080
# 742     1600
# 743     1920
# 744     1600
# 745     1080
# 746     1080
# 747      768
# 748     1080
# 749     1080
# 750     1080
# 751     1080
# 752     1080
# 753     1080
# 754     1800
# 755     1200
# 756     1200
# 757     1080
# 758     1080
# 759     1200
# Name: resolution_height, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              760 non-null    int64
#  1   name               760 non-null    object
#  2   price              760 non-null    int64
#  3   os                 756 non-null    object
#  4   graphics           753 non-null    object
#  5   display            760 non-null    object
#  6   ram                760 non-null    object
#  7   rom                14 non-null     object
#  8   warranty           741 non-null    object
#  9   rating             492 non-null    float64
#  10  core               757 non-null    object
#  11  intel_core         760 non-null    object
#  12  brand              760 non-null    object
#  13  Touchscreen        760 non-null    object
#  14  Gaming             760 non-null    object
#  15  display_inches     760 non-null    object
#  16  resolution_width   760 non-null    object
#  17  resolution_height  760 non-null    object
# dtypes: float64(1), int64(2), object(15)
# memory usage: 107.0+ KB

# %%
df['display_inches']=df['display_inches'].astype(float)

# %%
df['resolution_width']=df['resolution_width'].astype(int)

# %%
df['resolution_height']=df['resolution_height'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              760 non-null    int64
#  1   name               760 non-null    object
#  2   price              760 non-null    int64
#  3   os                 756 non-null    object
#  4   graphics           753 non-null    object
#  5   display            760 non-null    object
#  6   ram                760 non-null    object
#  7   rom                14 non-null     object
#  8   warranty           741 non-null    object
#  9   rating             492 non-null    float64
#  10  core               757 non-null    object
#  11  intel_core         760 non-null    object
#  12  brand              760 non-null    object
#  13  Touchscreen        760 non-null    object
#  14  Gaming             760 non-null    object
#  15  display_inches     760 non-null    float64
#  16  resolution_width   760 non-null    int64
#  17  resolution_height  760 non-null    int64
# dtypes: float64(2), int64(4), object(12)
# memory usage: 107.0+ KB

# %%
df['ram']
# Out:
# 0                 8 GB DDR4 RAM
# 1                 8 GB DDR4 RAM
# 2              16 GB LPDDR5 RAM
# 3                 8 GB DDR4 RAM
# 4                16 GB DDR4 RAM
# 5                16 GB DDR4 RAM
# 6                 8 GB DDR4 RAM
# 7                 8 GB DDR4 RAM
# 8                 8 GB DDR4 RAM
# 9                 8 GB DDR4 RAM
# 10               16 GB DDR4 RAM
# 11                8 GB DDR4 RAM
# 12                8 GB DDR4 RAM
# 13                8 GB DDR4 RAM
# 14              8 GB LPDDR5 RAM
# 15                8 GB DDR4 RAM
# 16               16 GB DDR4 RAM
# 17         16 GB DDR5 SDRAM RAM
# 18               16 GB DDR4 RAM
# 19            16 GB LPDDR4X RAM
# 20               16 GB DDR4 RAM
# 21             16 GB LPDDR5 RAM
# 22                8 GB DDR4 RAM
# 23                8 GB DDR4 RAM
# 24              4 GB LPDDR4 RAM
# 25               16 GB DDR4 RAM
# 26             8 GB LPDDR4X RAM
# 27               16 GB DDR5 RAM
# 28               16 GB DDR4 RAM
# 29                8 GB DDR4 RAM
# 30               16 GB DDR4 RAM
# 31               16 GB DDR4 RAM
# 32                8 GB DDR4 RAM
# 33               16 GB DDR4 RAM
# 34                8 GB DDR4 RAM
# 35               16 GB DDR4 RAM
# 36                8 GB DDR4 RAM
# 37               16 GB DDR5 RAM
# 38               16 GB DDR4 RAM
# 39               16 GB DDR4 RAM
# 40            32 GB LPDDR5X RAM
# 41                4 GB DDR4 RAM
# 42            16 GB LPDDR4X RAM
# 43               16 GB DDR4 RAM
# 44               16 GB DDR4 RAM
# 45               16 GB DDR4 RAM
# 46                4 GB DDR4 RAM
# 47               16 GB DDR4 RAM
# 48                8 GB DDR4 RAM
# 49                8 GB DDR4 RAM
# 50               16 GB DDR4 RAM
# 51              4 GB LPDDR4 RAM
# 52             16 GB LPDDR4 RAM
# 53                8 GB DDR5 RAM
# 54                8 GB DDR4 RAM
# 55                8 GB DDR4 RAM
# 56               16 GB DDR4 RAM
# 57               16 GB DDR5 RAM
# 58                8 GB DDR4 RAM
# 59               16 GB DDR4 RAM
# 60               16 GB DDR5 RAM
# 61               16 GB DDR4 RAM
# 62               16 GB DDR4 RAM
# 63               16 GB DDR4 RAM
# 64               16 GB DDR4 RAM
# 65             16 GB LPDDR5 RAM
# 66                8 GB DDR5 RAM
# 67                   512 GB SSD
# 68            16 GB LPDDR5  RAM
# 69                8 GB DDR4 RAM
# 70              8 GB LPDDR5 RAM
# 71                8 GB DDR4 RAM
# 72               16 GB DDR4 RAM
# 73                8 GB DDR4 RAM
# 74               16 GB DDR4 RAM
# 75              8 GB LPDDR5 RAM
# 76               64 GB DDR5 RAM
# 77             8 GB LPDDR4X RAM
# 78                8 GB DDR4 RAM
# 79                8 GB DDR4 RAM
# 80               16 GB DDR4 RAM
# 81                4 GB DDR4 RAM
# 82              8 GB LPDDR5 RAM
# 83                8 GB DDR4 RAM
# 84               16 GB DDR5 RAM
# 85               16 GB DDR4 RAM
# 86            16 GB LPDDR4X RAM
# 87               16 GB DDR5 RAM
# 88               16 GB DDR5 RAM
# 89               16 GB DDR4 RAM
# 90               16 GB DDR4 RAM
# 91              8 GB LPDDR5 RAM
# 92               16 GB DDR4 RAM
# 93                8 GB DDR4 RAM
# 94                8 GB DDR4 RAM
# 95                8 GB DDR4 RAM
# 96                8 GB DDR4 RAM
# 97              8 GB LPDDR5 RAM
# 98                   36 GB  RAM
# 99             16 GB LPDDR5 RAM
# 100              16 GB DDR4 RAM
# 101               8 GB DDR4 RAM
# 102              16 GB DDR5 RAM
# 103              16 GB DDR4 RAM
# 104              16 GB DDR5 RAM
# 105               8 GB DDR4 RAM
# 106               8 GB DDR4 RAM
# 107               8 GB DDR4 RAM
# 108              16 GB DDR4 RAM
# 109              16 GB DDR4 RAM
# 110              16 GB DDR4 RAM
# 111              16 GB DDR5 RAM
# 112               8 GB DDR5 RAM
# 113              16 GB DDR4 RAM
# 114            16 GB LPDDR5 RAM
# 115              16 GB DDR5 RAM
# 116           16 GB LPDDR5X RAM
# 117               8 GB DDR4 RAM
# 118              16 GB DDR4 RAM
# 119             8 GB LPDDR5 RAM
# 120              16 GB DDR4 RAM
# 121               8 GB DDR4 RAM
# 122              16 GB DDR5 RAM
# 123              16 GB DDR5 RAM
# 124              16 GB DDR4 RAM
# 125              16 GB DDR4 RAM
# 126               8 GB DDR4 RAM
# 127              16 GB DDR4 RAM
# 128             8 GB LPDDR5 RAM
# 129              16 GB DDR4 RAM
# 130               8 GB DDR4 RAM
# 131              16 GB DDR5 RAM
# 132             4 GB LPDDR4 RAM
# 133               8 GB DDR4 RAM
# 134               8 GB DDR4 RAM
# 135               8 GB DDR4 RAM
# 136               8 GB DDR4 RAM
# 137               8 GB DDR5 RAM
# 138              16 GB DDR4 RAM
# 139              16 GB DDR4 RAM
# 140              16 GB DDR4 RAM
# 141               8 GB DDR4 RAM
# 142           16 GB LPDDR5x RAM
# 143           16 GB LPDDR5X RAM
# 144              32 GB DDR5 RAM
# 145             4 GB LPDDR4 RAM
# 146              16 GB DDR4 RAM
# 147              16 GB DDR4 RAM
# 148               8 GB DDR4 RAM
# 149              16 GB DDR5 RAM
# 150               8 GB DDR4 RAM
# 151           16 GB LPDDR4X RAM
# 152              16 GB DDR4 RAM
# 153            16 GB LPDDR5 RAM
# 154                  16 GB  RAM
# 155              16 GB DDR5 RAM
# 156                  16 GB  RAM
# 157               8 GB DDR4 RAM
# 158             8 GB LPDDR5 RAM
# 159               8 GB DDR4 RAM
# 160              16 GB DDR4 RAM
# 161               8 GB DDR4 RAM
# 162               8 GB DDR4 RAM
# 163              16 GB DDR4 RAM
# 164               8 GB DDR4 RAM
# 165              16 GB DDR4 RAM
# 166              16 GB DDR4 RAM
# 167           16 GB LPDDR5  RAM
# 168              16 GB DDR4 RAM
# 169              16 GB DDR4 RAM
# 170              16 GB DDR4 RAM
# 171           16 GB LPDDR5  RAM
# 172               8 GB DDR4 RAM
# 173              16 GB DDR4 RAM
# 174              16 GB DDR4 RAM
# 175              16 GB DDR4 RAM
# 176              16 GB DDR4 RAM
# 177              16 GB DDR4 RAM
# 178              16 GB DDR4 RAM
# 179              16 GB DDR4 RAM
# 180              16 GB DDR5 RAM
# 181              16 GB DDR5 RAM
# 182              16 GB DDR5 RAM
# 183            16 GB LPDDR5 RAM
# 184            8 GB LPDDR4X RAM
# 185              64 GB DDR5 RAM
# 186            16 GB LPDDR5 RAM
# 187              16 GB DDR4 RAM
# 188             8 GB LPDDR5 RAM
# 189               8 GB DDR4 RAM
# 190               8 GB DDR4 RAM
# 191              16 GB DDR4 RAM
# 192              12 GB DDR4 RAM
# 193            4 GB LPDDR4x RAM
# 194            16 GB LPDDR5 RAM
# 195              16 GB DDR4 RAM
# 196            8 GB LPDDR4X RAM
# 197              8 GB DDR4  RAM
# 198               8 GB DDR4 RAM
# 199               8 GB DDR4 RAM
# 200             8 GB LPDDR4 RAM
# 201              16 GB DDR5 RAM
# 202              16 GB DDR4 RAM
# 203               8 GB DDR4 RAM
# 204                   8 GB  RAM
# 205               8 GB DDR4 RAM
# 206     8 GB Unified Memory RAM
# 207                   8 GB  RAM
# 208                   8 GB  RAM
# 209               8 GB DDR4 RAM
# 210                  18 GB  RAM
# 211             8 GB LPDDR5 RAM
# 212                   8 GB  RAM
# 213               8 GB DDR4 RAM
# 214              16 GB DDR5 RAM
# 215               8 GB DDR4 RAM
# 216               8 GB DDR4 RAM
# 217               8 GB DDR4 RAM
# 218               8 GB DDR4 RAM
# 219               8 GB DDR4 RAM
# 220               8 GB DDR4 RAM
# 221               8 GB DDR4 RAM
# 222                   8 GB  RAM
# 223              16 GB DDR4 RAM
# 224               8 GB DDR4 RAM
# 225               8 GB DDR4 RAM
# 226              16 GB DDR4 RAM
# 227               8 GB DDR4 RAM
# 228               8 GB DDR4 RAM
# 229            16 GB LPDDR5 RAM
# 230            4 GB LPDDR4X RAM
# 231               8 GB DDR4 RAM
# 232               8 GB DDR5 RAM
# 233               8 GB DDR4 RAM
# 234               8 GB DDR4 RAM
# 235              16 GB DDR5 RAM
# 236              16 GB DDR5 RAM
# 237               8 GB DDR5 RAM
# 238               8 GB DDR4 RAM
# 239               8 GB DDR4 RAM
# 240              16 GB DDR4 RAM
# 241           16 GB  LPDDR5 RAM
# 242              8 GB DDR4  RAM
# 243              16 GB DDR5 RAM
# 244              16 GB DDR4 RAM
# 245              16 GB DDR4 RAM
# 246              16 GB DDR4 RAM
# 247               8 GB DDR4 RAM
# 248              16 GB DDR4 RAM
# 249            8 GB LPDDR5  RAM
# 250              16 GB DDR5 RAM
# 251           32 GB LPDDR5X RAM
# 252               8 GB DDR4 RAM
# 253             8 GB LPDDR5 RAM
# 254              16 GB DDR4 RAM
# 255               8 GB DDR5 RAM
# 256              16 GB DDR4 RAM
# 257              32 GB DDR5 RAM
# 258              16 GB DDR4 RAM
# 259              16 GB DDR4 RAM
# 260              16 GB DDR4 RAM
# 261             8 GB LPDDR5 RAM
# 262              16 GB DDR4 RAM
# 263               8 GB DDR4 RAM
# 264              16 GB DDR4 RAM
# 265           16 GB LPDDR4X RAM
# 266               8 GB DDR5 RAM
# 267              16 GB DDR4 RAM
# 268              16 GB DDR5 RAM
# 269            16 GB LPDDR5 RAM
# 270            16 GB LPDDR5 RAM
# 271              16 GB DDR4 RAM
# 272            16 GB LPDDR5 RAM
# 273               8 GB DDR4 RAM
# 274               8 GB DDR4 RAM
# 275            8 GB LPDDR4X RAM
# 276              16 GB DDR5 RAM
# 277               8 GB DDR4 RAM
# 278              16 GB DDR4 RAM
# 279               8 GB DDR4 RAM
# 280             8 GB LPDDR5 RAM
# 281              16 GB DDR4 RAM
# 282            16 GB LPDDR5 RAM
# 283              16 GB DDR4 RAM
# 284               8 GB DDR4 RAM
# 285               8 GB DDR4 RAM
# 286               8 GB DDR4 RAM
# 287              32 GB DDR5 RAM
# 288              16 GB DDR5 RAM
# 289             8 GB LPDDR5 RAM
# 290             8 GB LPDDR5 RAM
# 291             8 GB LPDDR5 RAM
# 292           16 GB LPDDR4x RAM
# 293            32 GB LPDDR5 RAM
# 294               8 GB DDR4 RAM
# 295             16 GB DDR4  RAM
# 296              16 GB DDR4 RAM
# 297              16 GB DDR4 RAM
# 298               8 GB DDR4 RAM
# 299              16 GB DDR4 RAM
# 300               8 GB DDR4 RAM
# 301              16 GB DDR4 RAM
# 302               8 GB DDR4 RAM
# 303              16 GB DDR4 RAM
# 304            16 GB LPDDR5 RAM
# 305                   8 GB  RAM
# 306               8 GB DDR4 RAM
# 307              16 GB DDR4 RAM
# 308               8 GB DDR4 RAM
# 309              16 GB DDR4 RAM
# 310              16 GB DDR4 RAM
# 311              16 GB DDR4 RAM
# 312                   8 GB  RAM
# 313              16 GB DDR4 RAM
# 314              16 GB DDR4 RAM
# 315               8 GB DDR4 RAM
# 316           8 GB LPDDR4x  RAM
# 317               8 GB DDR4 RAM
# 318               8 GB DDR4 RAM
# 319               8 GB DDR4 RAM
# 320               2 GB DDR3 RAM
# 321                  18 GB  RAM
# 322              16 GB DDR5 RAM
# 323               8 GB DDR5 RAM
# 324              16 GB DDR5 RAM
# 325              8 GB DDR4  RAM
# 326               8 GB DDR5 RAM
# 327              16 GB DDR5 RAM
# 328             8 GB LPDDR5 RAM
# 329               8 GB DDR4 RAM
# 330            16 GB LPDDR5 RAM
# 331               8 GB DDR4 RAM
# 332               4 GB DDR4 RAM
# 333            8 GB LPDDR4X RAM
# 334               8 GB DDR4 RAM
# 335             8 GB LPDDR5 RAM
# 336               8 GB DDR4 RAM
# 337            8 GB LPDDR4X RAM
# 338           16 GB LPDDR4X RAM
# 339             8 GB LPDDR4 RAM
# 340              16 GB DDR5 RAM
# 341              32 GB DDR5 RAM
# 342              16 GB DDR5 RAM
# 343            16 GB LPDDR5 RAM
# 344             4 GB LPDDR4 RAM
# 345           16 GB LPDDR4X RAM
# 346            8 GB LPDDR4X RAM
# 347               8 GB DDR4 RAM
# 348               8 GB DDR4 RAM
# 349              16 GB DDR5 RAM
# 350              16 GB DDR4 RAM
# 351              16 GB DDR4 RAM
# 352               8 GB DDR5 RAM
# 353              16 GB DDR4 RAM
# 354              16 GB DDR4 RAM
# 355               8 GB DDR4 RAM
# 356             8 GB LPDDR5 RAM
# 357              16 GB DDR4 RAM
# 358              16 GB DDR5 RAM
# 359             16 GB DDR5  RAM
# 360            12 GB LPDDR4 RAM
# 361               8 GB DDR4 RAM
# 362              16 GB DDR5 RAM
# 363              16 GB DDR5 RAM
# 364               8 GB DDR5 RAM
# 365            16 GB LPDDR4 RAM
# 366              16 GB DDR4 RAM
# 367              16 GB DDR4 RAM
# 368             16 GB DDR4- RAM
# 369              16 GB DDR4 RAM
# 370              16 GB DDR4 RAM
# 371            16 GB LPDDR5 RAM
# 372                  16 GB  RAM
# 373               8 GB DDR4 RAM
# 374              16 GB DDR5 RAM
# 375               8 GB DDR4 RAM
# 376            4 GB LPDDR4X RAM
# 377               8 GB DDR4 RAM
# 378            16 GB LPDDR5 RAM
# 379            16 GB LPDDR5 RAM
# 380             8 GB LPDDR5 RAM
# 381              16 GB DDR4 RAM
# 382              16 GB DDR4 RAM
# 383             8 GB LPDDR5 RAM
# 384              32 GB DDR5 RAM
# 385               8 GB DDR4 RAM
# 386            16 GB LPDDR4 RAM
# 387             8 GB LPDDR4 RAM
# 388              32 GB DDR5 RAM
# 389              32 GB DDR5 RAM
# 390           16 GB LPDDR4X RAM
# 391               8 GB DDR4 RAM
# 392           16 GB  LPDDR5 RAM
# 393               8 GB DDR4 RAM
# 394              16 GB DDR4 RAM
# 395               8 GB DDR4 RAM
# 396           16 GB  LPDDR5 RAM
# 397              16 GB DDR4 RAM
# 398              16 GB DDR4 RAM
# 399               8 GB DDR5 RAM
# 400               8 GB DDR4 RAM
# 401               8 GB DDR4 RAM
# 402           16 GB  LPDDR5 RAM
# 403              16 GB DDR5 RAM
# 404              16 GB DDR5 RAM
# 405              16 GB DDR4 RAM
# 406              16 GB DDR4 RAM
# 407           16 GB  LPDDR5 RAM
# 408            16 GB LPDDR5 RAM
# 409              16 GB DDR5 RAM
# 410              16 GB DDR5 RAM
# 411              16 GB DDR4 RAM
# 412              16 GB DDR5 RAM
# 413               8 GB DDR4 RAM
# 414            4 GB ‎LPDDR4 RAM
# 415           16 GB  LPDDR5 RAM
# 416            64 GB LPDDR5 RAM
# 417                  16 GB  RAM
# 418            16 GB LPDDR5 RAM
# 419              16 GB DDR4 RAM
# 420              16 GB DDR4 RAM
# 421              16 GB DDR4 RAM
# 422              16 GB DDR4 RAM
# 423               4 GB DDR4 RAM
# 424              16 GB DDR5 RAM
# 425               8 GB DDR4 RAM
# 426               8 GB DDR4 RAM
# 427              16 GB DDR4 RAM
# 428              16 GB DDR4 RAM
# 429              16 GB DDR4 RAM
# 430             8 GB LPDDR5 RAM
# 431               8 GB DDR4 RAM
# 432               8 GB DDR4 RAM
# 433              16 GB DDR5 RAM
# 434             8 GB LPDDR4 RAM
# 435               8 GB DDR4 RAM
# 436            16 GB LPDDR5 RAM
# 437              16 GB DDR4 RAM
# 438               8 GB DDR4 RAM
# 439              16 GB DDR4 RAM
# 440             8 GB LPDDR5 RAM
# 441              16 GB DDR4 RAM
# 442               8 GB DDR5 RAM
# 443               8 GB DDR4 RAM
# 444             8 GB LPDDR5 RAM
# 445              16 GB DDR4 RAM
# 446              16 GB DDR5 RAM
# 447             8 GB LPDDR5 RAM
# 448               8 GB DDR4 RAM
# 449              16 GB DDR4 RAM
# 450               8 GB DDR4 RAM
# 451               8 GB DDR4 RAM
# 452              16 GB DDR4 RAM
# 453               8 GB DDR4 RAM
# 454               4 GB DDR4 RAM
# 455               8 GB DDR4 RAM
# 456            16 GB LPDDR5 RAM
# 457              8 GB DDR4  RAM
# 458            8 GB LPDDR4X RAM
# 459            8 GB LPDDR5  RAM
# 460               8 GB DDR4 RAM
# 461               8 GB DDR4 RAM
# 462              16 GB DDR5 RAM
# 463              16 GB DDR4 RAM
# 464              16 GB DDR4 RAM
# 465              16 GB DDR5 RAM
# 466              16 GB DDR5 RAM
# 467              16 GB DDR5 RAM
# 468              16 GB DDR5 RAM
# 469              16 GB DDR4 RAM
# 470              16 GB DDR5 RAM
# 471               8 GB DDR4 RAM
# 472              16 GB DDR5 RAM
# 473              16 GB DDR4 RAM
# 474              16 GB DDR5 RAM
# 475              16 GB DDR4 RAM
# 476              16 GB DDR4 RAM
# 477               8 GB DDR4 RAM
# 478               8 GB DDR4 RAM
# 479               8 GB DDR4 RAM
# 480               8 GB DDR4 RAM
# 481              16 GB DDR4 RAM
# 482              16 GB DDR4 RAM
# 483              16 GB DDR4 RAM
# 484              16 GB DDR4 RAM
# 485               8 GB DDR4 RAM
# 486               8 GB DDR5 RAM
# 487            16 GB LPDDR5 RAM
# 488               8 GB DDR4 RAM
# 489            16 GB LPDDR5 RAM
# 490               8 GB DDR4 RAM
# 491              16 GB DDR4 RAM
# 492              16 GB DDR5 RAM
# 493           16 GB LPDDR4x RAM
# 494            16 GB LPDDR5 RAM
# 495                  256 GB SSD
# 496                  32 GB  RAM
# 497               8 GB DDR4 RAM
# 498             8 GB LPDDR5 RAM
# 499               8 GB DDR4 RAM
# 500            16 GB LPDDR5 RAM
# 501            4 GB LPDDR4x RAM
# 502            16 GB LPDDR5 RAM
# 503               8 GB DDR4 RAM
# 504              16 GB DDR4 RAM
# 505              16 GB DDR4 RAM
# 506              16 GB DDR4 RAM
# 507           16 GB LPDDR4X RAM
# 508            16 GB LPDDR5 RAM
# 509            16 GB LPDDR5 RAM
# 510              16 GB DDR4 RAM
# 511              16 GB DDR4 RAM
# 512            8 GB LPDDR4x RAM
# 513           16 GB LPDDR4x RAM
# 514               8 GB DDR4 RAM
# 515            16 GB LPDDR4 RAM
# 516             8 GB LPDDR5 RAM
# 517              16 GB DDR4 RAM
# 518              32 GB DDR4 RAM
# 519              16 GB DDR4 RAM
# 520           16 GB LPDDR4x RAM
# 521           16 GB LPDDR4x RAM
# 522              16 GB DDR5 RAM
# 523           16 GB LPDDR4x RAM
# 524               8 GB DDR4 RAM
# 525            16 GB LPDDR5 RAM
# 526              8 GB DDR4  RAM
# 527               8 GB DDR4 RAM
# 528              16 GB DDR4 RAM
# 529              16 GB DDR4 RAM
# 530               8 GB DDR4 RAM
# 531    16 GB Unified Memory RAM
# 532              16 GB DDR4 RAM
# 533               8 GB DDR4 RAM
# 534              16 GB DDR4 RAM
# 535           16 GB LPDDR4X RAM
# 536              16 GB DDR4 RAM
# 537               8 GB DDR4 RAM
# 538               8 GB DDR4 RAM
# 539              16 GB DDR4 RAM
# 540              16 GB DDR4 RAM
# 541               4 GB DDR4 RAM
# 542               8 GB DDR4 RAM
# 543              16 GB DDR4 RAM
# 544               8 GB DDR4 RAM
# 545            32 GB LPDDR5 RAM
# 546              32 GB DDR5 RAM
# 547              16 GB DDR4 RAM
# 548               8 GB DDR4 RAM
# 549              16 GB DDR4 RAM
# 550               8 GB DDR4 RAM
# 551               8 GB DDR4 RAM
# 552               8 GB DDR4 RAM
# 553               8 GB DDR4 RAM
# 554              16 GB DDR5 RAM
# 555              32 GB DDR5 RAM
# 556               8 GB DDR4 RAM
# 557               8 GB DDR4 RAM
# 558            8 GB LPDDR4x RAM
# 559              16 GB DDR4 RAM
# 560               8 GB DDR4 RAM
# 561              16 GB DDR5 RAM
# 562               8 GB DDR4 RAM
# 563               8 GB DDR4 RAM
# 564               8 GB DDR4 RAM
# 565              16 GB DDR5 RAM
# 566               8 GB DDR4 RAM
# 567              16 GB DDR4 RAM
# 568              16 GB DDR5 RAM
# 569               8 GB DDR4 RAM
# 570              16 GB DDR4 RAM
# 571               8 GB DDR4 RAM
# 572              16 GB DDR4 RAM
# 573              32 GB DDR5 RAM
# 574               8 GB DDR4 RAM
# 575               8 GB DDR4 RAM
# 576               8 GB DDR4 RAM
# 577               8 GB DDR4 RAM
# 578              16 GB DDR4 RAM
# 579              16 GB DDR4 RAM
# 580              16 GB DDR4 RAM
# 581               8 GB DDR4 RAM
# 582              16 GB DDR5 RAM
# 583               8 GB DDR4 RAM
# 584               8 GB DDR4 RAM
# 585              16 GB DDR4 RAM
# 586               8 GB DDR4 RAM
# 587              16 GB DDR4 RAM
# 588            16 GB LPDDR5 RAM
# 589               8 GB DDR4 RAM
# 590               8 GB DDR4 RAM
# 591               8 GB DDR4 RAM
# 592              16 GB DDR4 RAM
# 593               8 GB DDR4 RAM
# 594              16 GB DDR4 RAM
# 595            16 GB LPDDR4 RAM
# 596              16 GB DDR4 RAM
# 597              16 GB DDR4 RAM
# 598               8 GB DDR4 RAM
# 599               8 GB DDR4 RAM
# 600               8 GB DDR4 RAM
# 601            128 GB Hard Disk
# 602            16 GB LPDDR5 RAM
# 603              16 GB DDR5 RAM
# 604            16 GB LPDDR5 RAM
# 605               8 GB DDR4 RAM
# 606               8 GB DDR4 RAM
# 607               8 GB DDR4 RAM
# 608               8 GB DDR4 RAM
# 609               8 GB DDR4 RAM
# 610    16 GB Unified Memory RAM
# 611    32 GB Unified Memory RAM
# 612               4 GB DDR4 RAM
# 613               8 GB DDR4 RAM
# 614             4 GB LPDDR4 RAM
# 615               8 GB DDR4 RAM
# 616               8 GB DDR4 RAM
# 617              16 GB DDR4 RAM
# 618               8 GB DDR4 RAM
# 619              16 GB DDR4 RAM
# 620               8 GB DDR4 RAM
# 621               4 GB DDR4 RAM
# 622               8 GB DDR4 RAM
# 623               8 GB DDR4 RAM
# 624              16 GB DDR4 RAM
# 625               8 GB DDR4 RAM
# 626               8 GB DDR4 RAM
# 627               8 GB DDR4 RAM
# 628               8 GB DDR4 RAM
# 629               8 GB DDR4 RAM
# 630            32 GB LPDDR5 RAM
# 631              16 GB DDR4 RAM
# 632            16 GB LPDDR5 RAM
# 633                   8 GB  RAM
# 634              16 GB DDR4 RAM
# 635               8 GB DDR4 RAM
# 636               8 GB DDR4 RAM
# 637               8 GB DDR4 RAM
# 638               8 GB DDR4 RAM
# 639                  18 GB  RAM
# 640                   8 GB  RAM
# 641            16 GB LPDDR5 RAM
# 642            8 GB LPDDR4X RAM
# 643               8 GB DDR4 RAM
# 644            8 GB LPDDR4X RAM
# 645               8 GB DDR4 RAM
# 646           16 GB LPDDR4X RAM
# 647               8 GB DDR4 RAM
# 648              16 GB DDR4 RAM
# 649           16 GB LPDDR4x RAM
# 650              16 GB DDR4 RAM
# 651            8 GB LPDDR4X RAM
# 652              32 GB DDR5 RAM
# 653            16 GB LPDDR5 RAM
# 654             8 GB LPDDR5 RAM
# 655               8 GB DDR4 RAM
# 656              16 GB DDR4 RAM
# 657              16 GB DDR5 RAM
# 658              16 GB DDR4 RAM
# 659              16 GB DDR4 RAM
# 660             8 GB LPDDR5 RAM
# 661              16 GB DDR4 RAM
# 662              16 GB DDR4 RAM
# 663              16 GB DDR5 RAM
# 664              16 GB DDR5 RAM
# 665               8 GB DDR4 RAM
# 666              16 GB DDR4 RAM
# 667              16 GB DDR4 RAM
# 668              16 GB DDR5 RAM
# 669               8 GB DDR5 RAM
# 670           16 GB LPDDR4X RAM
# 671              16 GB DDR4 RAM
# 672               8 GB DDR4 RAM
# 673            16 GB LPDDR5 RAM
# 674               8 GB DDR4 RAM
# 675              16 GB DDR4 RAM
# 676              16 GB DDR4 RAM
# 677               8 GB DDR4 RAM
# 678            16 GB LPDDR5 RAM
# 679              16 GB DDR4 RAM
# 680               8 GB DDR4 RAM
# 681              32 GB DDR5 RAM
# 682               8 GB DDR4 RAM
# 683             4 GB LPDDR4 RAM
# 684              16 GB DDR4 RAM
# 685              16 GB DDR4 RAM
# 686               8 GB DDR5 RAM
# 687              16 GB DDR4 RAM
# 688              16 GB DDR4 RAM
# 689              16 GB DDR5 RAM
# 690               8 GB DDR5 RAM
# 691              16 GB DDR5 RAM
# 692               8 GB DDR4 RAM
# 693               8 GB DDR4 RAM
# 694              16 GB DDR4 RAM
# 695               4 GB DDR4 RAM
# 696              16 GB DDR4 RAM
# 697               8 GB DDR4 RAM
# 698            8 GB LPDDR5  RAM
# 699               8 GB DDR4 RAM
# 700              32 GB DDR5 RAM
# 701            16 GB LPDDR5 RAM
# 702              16 GB DDR5 RAM
# 703              16 GB DDR4 RAM
# 704             8 GB LPDDR5 RAM
# 705            16 GB LPDDR5 RAM
# 706              64 GB DDR5 RAM
# 707               8 GB DDR4 RAM
# 708           16 GB LPDDR4X RAM
# 709              16 GB DDR5 RAM
# 710              8 GB DDR4  RAM
# 711             8 GB LPDDR5 RAM
# 712              16 GB DDR5 RAM
# 713              16 GB DDR4 RAM
# 714            8 GB LPDDR4X RAM
# 715              16 GB DDR4 RAM
# 716              16 GB DDR4 RAM
# 717               8 GB DDR4 RAM
# 718              16 GB DDR4 RAM
# 719             8 GB LPDDR5 RAM
# 720               8 GB DDR4 RAM
# 721             8 GB LPDDR5 RAM
# 722              32 GB DDR5 RAM
# 723               8 GB DDR4 RAM
# 724               8 GB DDR4 RAM
# 725                  16 GB  RAM
# 726             8 GB LPDDR5 RAM
# 727           16 GB LPDDR4X RAM
# 728               8 GB DDR4 RAM
# 729              16 GB DDR5 RAM
# 730              16 GB DDR4 RAM
# 731              16 GB DDR4 RAM
# 732               8 GB DDR4 RAM
# 733           16 GB LPDDR4X RAM
# 734              16 GB DDR4 RAM
# 735               8 GB DDR4 RAM
# 736              16 GB DDR5 RAM
# 737              16 GB DDR5 RAM
# 738              16 GB DDR4 RAM
# 739              16 GB DDR4 RAM
# 740                   8 GB  RAM
# 741              16 GB DDR4 RAM
# 742           16 GB  LPDDR5 RAM
# 743           16 GB  LPDDR5 RAM
# 744              32 GB DDR5 RAM
# 745             8 GB LPDDR5 RAM
# 746           16 GB LPDDR4X RAM
# 747               8 GB DDR4 RAM
# 748              16 GB DDR5 RAM
# 749              16 GB DDR5 RAM
# 750             8 GB LPDDR4 RAM
# 751              16 GB DDR4 RAM
# 752               8 GB DDR5 RAM
# 753               8 GB DDR4 RAM
# 754            16 GB LPDDR5 RAM
# 755                  16 GB  RAM
# 756              16 GB DDR4 RAM
# 757              16 GB DDR4 RAM
# 758               8 GB DDR4 RAM
# 759              16 GB DDR4 RAM
# Name: ram, dtype: object

# %%
temp_df12=df[df['ram'].str.contains("128")]

# %%
temp_df12
# Out:
#      index                                               name  price     os  \
# 601    602  Samsung Galaxy Book Go Laptop (Snapdragon 7c/ ...  29990  other
#
#     graphics                        display               ram  rom  \
# 601      NaN  14 inches, 1920 x 1080 pixels  128 GB Hard Disk  NaN
#
#             warranty  rating core                      intel_core    brand  \
# 601  1 Year Warranty     NaN  NaN  2nd Gen Qualcomm Snapdragon 7c  Samsung
#
#          Touchscreen      Gaming  display_inches  resolution_width  \
# 601  not-touchscreen  not-gaming            14.0              1920
#
#      resolution_height
# 601               1080

# %%
temp_df11['rom']=temp_df11['ram']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\43660533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df11['rom']=temp_df11['ram']

# %%
temp_df12['ram']=np.nan
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\2809463555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df12['ram']=np.nan

# %%
df.loc[temp_df12.index,temp_df12.columns]=temp_df12.values

# %%
df['ram_gb']=df['ram_gb'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\LENOVO\OneDrive\Desktop\Walmart-Project\my_env1\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ram_gb'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 df['ram_gb']=df['ram_gb'].str.strip()
#
# File c:\Users\LENOVO\OneDrive\Desktop\Walmart-Project\my_env1\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\LENOVO\OneDrive\Desktop\Walmart-Project\my_env1\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'ram_gb'

# %%
df['ram_gb']=2

# %%
df.drop(columns="ram_gb",inplace=True)

# %%
df['ram_gb']=df['ram'].str.split("GB").str[0]

# %%
df['ram_gb'].value_counts()
# Out:
# ram_gb
# 16      381
# 8       320
# 32       23
# 4        22
# 64        4
# 18        3
# 12        2
# 36        1
# 512       1
# 2         1
# 256       1
# Name: count, dtype: int64

# %%
df['ram']
# Out:
# 0                 8 GB DDR4 RAM
# 1                 8 GB DDR4 RAM
# 2              16 GB LPDDR5 RAM
# 3                 8 GB DDR4 RAM
# 4                16 GB DDR4 RAM
# 5                16 GB DDR4 RAM
# 6                 8 GB DDR4 RAM
# 7                 8 GB DDR4 RAM
# 8                 8 GB DDR4 RAM
# 9                 8 GB DDR4 RAM
# 10               16 GB DDR4 RAM
# 11                8 GB DDR4 RAM
# 12                8 GB DDR4 RAM
# 13                8 GB DDR4 RAM
# 14              8 GB LPDDR5 RAM
# 15                8 GB DDR4 RAM
# 16               16 GB DDR4 RAM
# 17         16 GB DDR5 SDRAM RAM
# 18               16 GB DDR4 RAM
# 19            16 GB LPDDR4X RAM
# 20               16 GB DDR4 RAM
# 21             16 GB LPDDR5 RAM
# 22                8 GB DDR4 RAM
# 23                8 GB DDR4 RAM
# 24              4 GB LPDDR4 RAM
# 25               16 GB DDR4 RAM
# 26             8 GB LPDDR4X RAM
# 27               16 GB DDR5 RAM
# 28               16 GB DDR4 RAM
# 29                8 GB DDR4 RAM
# 30               16 GB DDR4 RAM
# 31               16 GB DDR4 RAM
# 32                8 GB DDR4 RAM
# 33               16 GB DDR4 RAM
# 34                8 GB DDR4 RAM
# 35               16 GB DDR4 RAM
# 36                8 GB DDR4 RAM
# 37               16 GB DDR5 RAM
# 38               16 GB DDR4 RAM
# 39               16 GB DDR4 RAM
# 40            32 GB LPDDR5X RAM
# 41                4 GB DDR4 RAM
# 42            16 GB LPDDR4X RAM
# 43               16 GB DDR4 RAM
# 44               16 GB DDR4 RAM
# 45               16 GB DDR4 RAM
# 46                4 GB DDR4 RAM
# 47               16 GB DDR4 RAM
# 48                8 GB DDR4 RAM
# 49                8 GB DDR4 RAM
# 50               16 GB DDR4 RAM
# 51              4 GB LPDDR4 RAM
# 52             16 GB LPDDR4 RAM
# 53                8 GB DDR5 RAM
# 54                8 GB DDR4 RAM
# 55                8 GB DDR4 RAM
# 56               16 GB DDR4 RAM
# 57               16 GB DDR5 RAM
# 58                8 GB DDR4 RAM
# 59               16 GB DDR4 RAM
# 60               16 GB DDR5 RAM
# 61               16 GB DDR4 RAM
# 62               16 GB DDR4 RAM
# 63               16 GB DDR4 RAM
# 64               16 GB DDR4 RAM
# 65             16 GB LPDDR5 RAM
# 66                8 GB DDR5 RAM
# 67                   512 GB SSD
# 68            16 GB LPDDR5  RAM
# 69                8 GB DDR4 RAM
# 70              8 GB LPDDR5 RAM
# 71                8 GB DDR4 RAM
# 72               16 GB DDR4 RAM
# 73                8 GB DDR4 RAM
# 74               16 GB DDR4 RAM
# 75              8 GB LPDDR5 RAM
# 76               64 GB DDR5 RAM
# 77             8 GB LPDDR4X RAM
# 78                8 GB DDR4 RAM
# 79                8 GB DDR4 RAM
# 80               16 GB DDR4 RAM
# 81                4 GB DDR4 RAM
# 82              8 GB LPDDR5 RAM
# 83                8 GB DDR4 RAM
# 84               16 GB DDR5 RAM
# 85               16 GB DDR4 RAM
# 86            16 GB LPDDR4X RAM
# 87               16 GB DDR5 RAM
# 88               16 GB DDR5 RAM
# 89               16 GB DDR4 RAM
# 90               16 GB DDR4 RAM
# 91              8 GB LPDDR5 RAM
# 92               16 GB DDR4 RAM
# 93                8 GB DDR4 RAM
# 94                8 GB DDR4 RAM
# 95                8 GB DDR4 RAM
# 96                8 GB DDR4 RAM
# 97              8 GB LPDDR5 RAM
# 98                   36 GB  RAM
# 99             16 GB LPDDR5 RAM
# 100              16 GB DDR4 RAM
# 101               8 GB DDR4 RAM
# 102              16 GB DDR5 RAM
# 103              16 GB DDR4 RAM
# 104              16 GB DDR5 RAM
# 105               8 GB DDR4 RAM
# 106               8 GB DDR4 RAM
# 107               8 GB DDR4 RAM
# 108              16 GB DDR4 RAM
# 109              16 GB DDR4 RAM
# 110              16 GB DDR4 RAM
# 111              16 GB DDR5 RAM
# 112               8 GB DDR5 RAM
# 113              16 GB DDR4 RAM
# 114            16 GB LPDDR5 RAM
# 115              16 GB DDR5 RAM
# 116           16 GB LPDDR5X RAM
# 117               8 GB DDR4 RAM
# 118              16 GB DDR4 RAM
# 119             8 GB LPDDR5 RAM
# 120              16 GB DDR4 RAM
# 121               8 GB DDR4 RAM
# 122              16 GB DDR5 RAM
# 123              16 GB DDR5 RAM
# 124              16 GB DDR4 RAM
# 125              16 GB DDR4 RAM
# 126               8 GB DDR4 RAM
# 127              16 GB DDR4 RAM
# 128             8 GB LPDDR5 RAM
# 129              16 GB DDR4 RAM
# 130               8 GB DDR4 RAM
# 131              16 GB DDR5 RAM
# 132             4 GB LPDDR4 RAM
# 133               8 GB DDR4 RAM
# 134               8 GB DDR4 RAM
# 135               8 GB DDR4 RAM
# 136               8 GB DDR4 RAM
# 137               8 GB DDR5 RAM
# 138              16 GB DDR4 RAM
# 139              16 GB DDR4 RAM
# 140              16 GB DDR4 RAM
# 141               8 GB DDR4 RAM
# 142           16 GB LPDDR5x RAM
# 143           16 GB LPDDR5X RAM
# 144              32 GB DDR5 RAM
# 145             4 GB LPDDR4 RAM
# 146              16 GB DDR4 RAM
# 147              16 GB DDR4 RAM
# 148               8 GB DDR4 RAM
# 149              16 GB DDR5 RAM
# 150               8 GB DDR4 RAM
# 151           16 GB LPDDR4X RAM
# 152              16 GB DDR4 RAM
# 153            16 GB LPDDR5 RAM
# 154                  16 GB  RAM
# 155              16 GB DDR5 RAM
# 156                  16 GB  RAM
# 157               8 GB DDR4 RAM
# 158             8 GB LPDDR5 RAM
# 159               8 GB DDR4 RAM
# 160              16 GB DDR4 RAM
# 161               8 GB DDR4 RAM
# 162               8 GB DDR4 RAM
# 163              16 GB DDR4 RAM
# 164               8 GB DDR4 RAM
# 165              16 GB DDR4 RAM
# 166              16 GB DDR4 RAM
# 167           16 GB LPDDR5  RAM
# 168              16 GB DDR4 RAM
# 169              16 GB DDR4 RAM
# 170              16 GB DDR4 RAM
# 171           16 GB LPDDR5  RAM
# 172               8 GB DDR4 RAM
# 173              16 GB DDR4 RAM
# 174              16 GB DDR4 RAM
# 175              16 GB DDR4 RAM
# 176              16 GB DDR4 RAM
# 177              16 GB DDR4 RAM
# 178              16 GB DDR4 RAM
# 179              16 GB DDR4 RAM
# 180              16 GB DDR5 RAM
# 181              16 GB DDR5 RAM
# 182              16 GB DDR5 RAM
# 183            16 GB LPDDR5 RAM
# 184            8 GB LPDDR4X RAM
# 185              64 GB DDR5 RAM
# 186            16 GB LPDDR5 RAM
# 187              16 GB DDR4 RAM
# 188             8 GB LPDDR5 RAM
# 189               8 GB DDR4 RAM
# 190               8 GB DDR4 RAM
# 191              16 GB DDR4 RAM
# 192              12 GB DDR4 RAM
# 193            4 GB LPDDR4x RAM
# 194            16 GB LPDDR5 RAM
# 195              16 GB DDR4 RAM
# 196            8 GB LPDDR4X RAM
# 197              8 GB DDR4  RAM
# 198               8 GB DDR4 RAM
# 199               8 GB DDR4 RAM
# 200             8 GB LPDDR4 RAM
# 201              16 GB DDR5 RAM
# 202              16 GB DDR4 RAM
# 203               8 GB DDR4 RAM
# 204                   8 GB  RAM
# 205               8 GB DDR4 RAM
# 206     8 GB Unified Memory RAM
# 207                   8 GB  RAM
# 208                   8 GB  RAM
# 209               8 GB DDR4 RAM
# 210                  18 GB  RAM
# 211             8 GB LPDDR5 RAM
# 212                   8 GB  RAM
# 213               8 GB DDR4 RAM
# 214              16 GB DDR5 RAM
# 215               8 GB DDR4 RAM
# 216               8 GB DDR4 RAM
# 217               8 GB DDR4 RAM
# 218               8 GB DDR4 RAM
# 219               8 GB DDR4 RAM
# 220               8 GB DDR4 RAM
# 221               8 GB DDR4 RAM
# 222                   8 GB  RAM
# 223              16 GB DDR4 RAM
# 224               8 GB DDR4 RAM
# 225               8 GB DDR4 RAM
# 226              16 GB DDR4 RAM
# 227               8 GB DDR4 RAM
# 228               8 GB DDR4 RAM
# 229            16 GB LPDDR5 RAM
# 230            4 GB LPDDR4X RAM
# 231               8 GB DDR4 RAM
# 232               8 GB DDR5 RAM
# 233               8 GB DDR4 RAM
# 234               8 GB DDR4 RAM
# 235              16 GB DDR5 RAM
# 236              16 GB DDR5 RAM
# 237               8 GB DDR5 RAM
# 238               8 GB DDR4 RAM
# 239               8 GB DDR4 RAM
# 240              16 GB DDR4 RAM
# 241           16 GB  LPDDR5 RAM
# 242              8 GB DDR4  RAM
# 243              16 GB DDR5 RAM
# 244              16 GB DDR4 RAM
# 245              16 GB DDR4 RAM
# 246              16 GB DDR4 RAM
# 247               8 GB DDR4 RAM
# 248              16 GB DDR4 RAM
# 249            8 GB LPDDR5  RAM
# 250              16 GB DDR5 RAM
# 251           32 GB LPDDR5X RAM
# 252               8 GB DDR4 RAM
# 253             8 GB LPDDR5 RAM
# 254              16 GB DDR4 RAM
# 255               8 GB DDR5 RAM
# 256              16 GB DDR4 RAM
# 257              32 GB DDR5 RAM
# 258              16 GB DDR4 RAM
# 259              16 GB DDR4 RAM
# 260              16 GB DDR4 RAM
# 261             8 GB LPDDR5 RAM
# 262              16 GB DDR4 RAM
# 263               8 GB DDR4 RAM
# 264              16 GB DDR4 RAM
# 265           16 GB LPDDR4X RAM
# 266               8 GB DDR5 RAM
# 267              16 GB DDR4 RAM
# 268              16 GB DDR5 RAM
# 269            16 GB LPDDR5 RAM
# 270            16 GB LPDDR5 RAM
# 271              16 GB DDR4 RAM
# 272            16 GB LPDDR5 RAM
# 273               8 GB DDR4 RAM
# 274               8 GB DDR4 RAM
# 275            8 GB LPDDR4X RAM
# 276              16 GB DDR5 RAM
# 277               8 GB DDR4 RAM
# 278              16 GB DDR4 RAM
# 279               8 GB DDR4 RAM
# 280             8 GB LPDDR5 RAM
# 281              16 GB DDR4 RAM
# 282            16 GB LPDDR5 RAM
# 283              16 GB DDR4 RAM
# 284               8 GB DDR4 RAM
# 285               8 GB DDR4 RAM
# 286               8 GB DDR4 RAM
# 287              32 GB DDR5 RAM
# 288              16 GB DDR5 RAM
# 289             8 GB LPDDR5 RAM
# 290             8 GB LPDDR5 RAM
# 291             8 GB LPDDR5 RAM
# 292           16 GB LPDDR4x RAM
# 293            32 GB LPDDR5 RAM
# 294               8 GB DDR4 RAM
# 295             16 GB DDR4  RAM
# 296              16 GB DDR4 RAM
# 297              16 GB DDR4 RAM
# 298               8 GB DDR4 RAM
# 299              16 GB DDR4 RAM
# 300               8 GB DDR4 RAM
# 301              16 GB DDR4 RAM
# 302               8 GB DDR4 RAM
# 303              16 GB DDR4 RAM
# 304            16 GB LPDDR5 RAM
# 305                   8 GB  RAM
# 306               8 GB DDR4 RAM
# 307              16 GB DDR4 RAM
# 308               8 GB DDR4 RAM
# 309              16 GB DDR4 RAM
# 310              16 GB DDR4 RAM
# 311              16 GB DDR4 RAM
# 312                   8 GB  RAM
# 313              16 GB DDR4 RAM
# 314              16 GB DDR4 RAM
# 315               8 GB DDR4 RAM
# 316           8 GB LPDDR4x  RAM
# 317               8 GB DDR4 RAM
# 318               8 GB DDR4 RAM
# 319               8 GB DDR4 RAM
# 320               2 GB DDR3 RAM
# 321                  18 GB  RAM
# 322              16 GB DDR5 RAM
# 323               8 GB DDR5 RAM
# 324              16 GB DDR5 RAM
# 325              8 GB DDR4  RAM
# 326               8 GB DDR5 RAM
# 327              16 GB DDR5 RAM
# 328             8 GB LPDDR5 RAM
# 329               8 GB DDR4 RAM
# 330            16 GB LPDDR5 RAM
# 331               8 GB DDR4 RAM
# 332               4 GB DDR4 RAM
# 333            8 GB LPDDR4X RAM
# 334               8 GB DDR4 RAM
# 335             8 GB LPDDR5 RAM
# 336               8 GB DDR4 RAM
# 337            8 GB LPDDR4X RAM
# 338           16 GB LPDDR4X RAM
# 339             8 GB LPDDR4 RAM
# 340              16 GB DDR5 RAM
# 341              32 GB DDR5 RAM
# 342              16 GB DDR5 RAM
# 343            16 GB LPDDR5 RAM
# 344             4 GB LPDDR4 RAM
# 345           16 GB LPDDR4X RAM
# 346            8 GB LPDDR4X RAM
# 347               8 GB DDR4 RAM
# 348               8 GB DDR4 RAM
# 349              16 GB DDR5 RAM
# 350              16 GB DDR4 RAM
# 351              16 GB DDR4 RAM
# 352               8 GB DDR5 RAM
# 353              16 GB DDR4 RAM
# 354              16 GB DDR4 RAM
# 355               8 GB DDR4 RAM
# 356             8 GB LPDDR5 RAM
# 357              16 GB DDR4 RAM
# 358              16 GB DDR5 RAM
# 359             16 GB DDR5  RAM
# 360            12 GB LPDDR4 RAM
# 361               8 GB DDR4 RAM
# 362              16 GB DDR5 RAM
# 363              16 GB DDR5 RAM
# 364               8 GB DDR5 RAM
# 365            16 GB LPDDR4 RAM
# 366              16 GB DDR4 RAM
# 367              16 GB DDR4 RAM
# 368             16 GB DDR4- RAM
# 369              16 GB DDR4 RAM
# 370              16 GB DDR4 RAM
# 371            16 GB LPDDR5 RAM
# 372                  16 GB  RAM
# 373               8 GB DDR4 RAM
# 374              16 GB DDR5 RAM
# 375               8 GB DDR4 RAM
# 376            4 GB LPDDR4X RAM
# 377               8 GB DDR4 RAM
# 378            16 GB LPDDR5 RAM
# 379            16 GB LPDDR5 RAM
# 380             8 GB LPDDR5 RAM
# 381              16 GB DDR4 RAM
# 382              16 GB DDR4 RAM
# 383             8 GB LPDDR5 RAM
# 384              32 GB DDR5 RAM
# 385               8 GB DDR4 RAM
# 386            16 GB LPDDR4 RAM
# 387             8 GB LPDDR4 RAM
# 388              32 GB DDR5 RAM
# 389              32 GB DDR5 RAM
# 390           16 GB LPDDR4X RAM
# 391               8 GB DDR4 RAM
# 392           16 GB  LPDDR5 RAM
# 393               8 GB DDR4 RAM
# 394              16 GB DDR4 RAM
# 395               8 GB DDR4 RAM
# 396           16 GB  LPDDR5 RAM
# 397              16 GB DDR4 RAM
# 398              16 GB DDR4 RAM
# 399               8 GB DDR5 RAM
# 400               8 GB DDR4 RAM
# 401               8 GB DDR4 RAM
# 402           16 GB  LPDDR5 RAM
# 403              16 GB DDR5 RAM
# 404              16 GB DDR5 RAM
# 405              16 GB DDR4 RAM
# 406              16 GB DDR4 RAM
# 407           16 GB  LPDDR5 RAM
# 408            16 GB LPDDR5 RAM
# 409              16 GB DDR5 RAM
# 410              16 GB DDR5 RAM
# 411              16 GB DDR4 RAM
# 412              16 GB DDR5 RAM
# 413               8 GB DDR4 RAM
# 414            4 GB ‎LPDDR4 RAM
# 415           16 GB  LPDDR5 RAM
# 416            64 GB LPDDR5 RAM
# 417                  16 GB  RAM
# 418            16 GB LPDDR5 RAM
# 419              16 GB DDR4 RAM
# 420              16 GB DDR4 RAM
# 421              16 GB DDR4 RAM
# 422              16 GB DDR4 RAM
# 423               4 GB DDR4 RAM
# 424              16 GB DDR5 RAM
# 425               8 GB DDR4 RAM
# 426               8 GB DDR4 RAM
# 427              16 GB DDR4 RAM
# 428              16 GB DDR4 RAM
# 429              16 GB DDR4 RAM
# 430             8 GB LPDDR5 RAM
# 431               8 GB DDR4 RAM
# 432               8 GB DDR4 RAM
# 433              16 GB DDR5 RAM
# 434             8 GB LPDDR4 RAM
# 435               8 GB DDR4 RAM
# 436            16 GB LPDDR5 RAM
# 437              16 GB DDR4 RAM
# 438               8 GB DDR4 RAM
# 439              16 GB DDR4 RAM
# 440             8 GB LPDDR5 RAM
# 441              16 GB DDR4 RAM
# 442               8 GB DDR5 RAM
# 443               8 GB DDR4 RAM
# 444             8 GB LPDDR5 RAM
# 445              16 GB DDR4 RAM
# 446              16 GB DDR5 RAM
# 447             8 GB LPDDR5 RAM
# 448               8 GB DDR4 RAM
# 449              16 GB DDR4 RAM
# 450               8 GB DDR4 RAM
# 451               8 GB DDR4 RAM
# 452              16 GB DDR4 RAM
# 453               8 GB DDR4 RAM
# 454               4 GB DDR4 RAM
# 455               8 GB DDR4 RAM
# 456            16 GB LPDDR5 RAM
# 457              8 GB DDR4  RAM
# 458            8 GB LPDDR4X RAM
# 459            8 GB LPDDR5  RAM
# 460               8 GB DDR4 RAM
# 461               8 GB DDR4 RAM
# 462              16 GB DDR5 RAM
# 463              16 GB DDR4 RAM
# 464              16 GB DDR4 RAM
# 465              16 GB DDR5 RAM
# 466              16 GB DDR5 RAM
# 467              16 GB DDR5 RAM
# 468              16 GB DDR5 RAM
# 469              16 GB DDR4 RAM
# 470              16 GB DDR5 RAM
# 471               8 GB DDR4 RAM
# 472              16 GB DDR5 RAM
# 473              16 GB DDR4 RAM
# 474              16 GB DDR5 RAM
# 475              16 GB DDR4 RAM
# 476              16 GB DDR4 RAM
# 477               8 GB DDR4 RAM
# 478               8 GB DDR4 RAM
# 479               8 GB DDR4 RAM
# 480               8 GB DDR4 RAM
# 481              16 GB DDR4 RAM
# 482              16 GB DDR4 RAM
# 483              16 GB DDR4 RAM
# 484              16 GB DDR4 RAM
# 485               8 GB DDR4 RAM
# 486               8 GB DDR5 RAM
# 487            16 GB LPDDR5 RAM
# 488               8 GB DDR4 RAM
# 489            16 GB LPDDR5 RAM
# 490               8 GB DDR4 RAM
# 491              16 GB DDR4 RAM
# 492              16 GB DDR5 RAM
# 493           16 GB LPDDR4x RAM
# 494            16 GB LPDDR5 RAM
# 495                  256 GB SSD
# 496                  32 GB  RAM
# 497               8 GB DDR4 RAM
# 498             8 GB LPDDR5 RAM
# 499               8 GB DDR4 RAM
# 500            16 GB LPDDR5 RAM
# 501            4 GB LPDDR4x RAM
# 502            16 GB LPDDR5 RAM
# 503               8 GB DDR4 RAM
# 504              16 GB DDR4 RAM
# 505              16 GB DDR4 RAM
# 506              16 GB DDR4 RAM
# 507           16 GB LPDDR4X RAM
# 508            16 GB LPDDR5 RAM
# 509            16 GB LPDDR5 RAM
# 510              16 GB DDR4 RAM
# 511              16 GB DDR4 RAM
# 512            8 GB LPDDR4x RAM
# 513           16 GB LPDDR4x RAM
# 514               8 GB DDR4 RAM
# 515            16 GB LPDDR4 RAM
# 516             8 GB LPDDR5 RAM
# 517              16 GB DDR4 RAM
# 518              32 GB DDR4 RAM
# 519              16 GB DDR4 RAM
# 520           16 GB LPDDR4x RAM
# 521           16 GB LPDDR4x RAM
# 522              16 GB DDR5 RAM
# 523           16 GB LPDDR4x RAM
# 524               8 GB DDR4 RAM
# 525            16 GB LPDDR5 RAM
# 526              8 GB DDR4  RAM
# 527               8 GB DDR4 RAM
# 528              16 GB DDR4 RAM
# 529              16 GB DDR4 RAM
# 530               8 GB DDR4 RAM
# 531    16 GB Unified Memory RAM
# 532              16 GB DDR4 RAM
# 533               8 GB DDR4 RAM
# 534              16 GB DDR4 RAM
# 535           16 GB LPDDR4X RAM
# 536              16 GB DDR4 RAM
# 537               8 GB DDR4 RAM
# 538               8 GB DDR4 RAM
# 539              16 GB DDR4 RAM
# 540              16 GB DDR4 RAM
# 541               4 GB DDR4 RAM
# 542               8 GB DDR4 RAM
# 543              16 GB DDR4 RAM
# 544               8 GB DDR4 RAM
# 545            32 GB LPDDR5 RAM
# 546              32 GB DDR5 RAM
# 547              16 GB DDR4 RAM
# 548               8 GB DDR4 RAM
# 549              16 GB DDR4 RAM
# 550               8 GB DDR4 RAM
# 551               8 GB DDR4 RAM
# 552               8 GB DDR4 RAM
# 553               8 GB DDR4 RAM
# 554              16 GB DDR5 RAM
# 555              32 GB DDR5 RAM
# 556               8 GB DDR4 RAM
# 557               8 GB DDR4 RAM
# 558            8 GB LPDDR4x RAM
# 559              16 GB DDR4 RAM
# 560               8 GB DDR4 RAM
# 561              16 GB DDR5 RAM
# 562               8 GB DDR4 RAM
# 563               8 GB DDR4 RAM
# 564               8 GB DDR4 RAM
# 565              16 GB DDR5 RAM
# 566               8 GB DDR4 RAM
# 567              16 GB DDR4 RAM
# 568              16 GB DDR5 RAM
# 569               8 GB DDR4 RAM
# 570              16 GB DDR4 RAM
# 571               8 GB DDR4 RAM
# 572              16 GB DDR4 RAM
# 573              32 GB DDR5 RAM
# 574               8 GB DDR4 RAM
# 575               8 GB DDR4 RAM
# 576               8 GB DDR4 RAM
# 577               8 GB DDR4 RAM
# 578              16 GB DDR4 RAM
# 579              16 GB DDR4 RAM
# 580              16 GB DDR4 RAM
# 581               8 GB DDR4 RAM
# 582              16 GB DDR5 RAM
# 583               8 GB DDR4 RAM
# 584               8 GB DDR4 RAM
# 585              16 GB DDR4 RAM
# 586               8 GB DDR4 RAM
# 587              16 GB DDR4 RAM
# 588            16 GB LPDDR5 RAM
# 589               8 GB DDR4 RAM
# 590               8 GB DDR4 RAM
# 591               8 GB DDR4 RAM
# 592              16 GB DDR4 RAM
# 593               8 GB DDR4 RAM
# 594              16 GB DDR4 RAM
# 595            16 GB LPDDR4 RAM
# 596              16 GB DDR4 RAM
# 597              16 GB DDR4 RAM
# 598               8 GB DDR4 RAM
# 599               8 GB DDR4 RAM
# 600               8 GB DDR4 RAM
# 601                         NaN
# 602            16 GB LPDDR5 RAM
# 603              16 GB DDR5 RAM
# 604            16 GB LPDDR5 RAM
# 605               8 GB DDR4 RAM
# 606               8 GB DDR4 RAM
# 607               8 GB DDR4 RAM
# 608               8 GB DDR4 RAM
# 609               8 GB DDR4 RAM
# 610    16 GB Unified Memory RAM
# 611    32 GB Unified Memory RAM
# 612               4 GB DDR4 RAM
# 613               8 GB DDR4 RAM
# 614             4 GB LPDDR4 RAM
# 615               8 GB DDR4 RAM
# 616               8 GB DDR4 RAM
# 617              16 GB DDR4 RAM
# 618               8 GB DDR4 RAM
# 619              16 GB DDR4 RAM
# 620               8 GB DDR4 RAM
# 621               4 GB DDR4 RAM
# 622               8 GB DDR4 RAM
# 623               8 GB DDR4 RAM
# 624              16 GB DDR4 RAM
# 625               8 GB DDR4 RAM
# 626               8 GB DDR4 RAM
# 627               8 GB DDR4 RAM
# 628               8 GB DDR4 RAM
# 629               8 GB DDR4 RAM
# 630            32 GB LPDDR5 RAM
# 631              16 GB DDR4 RAM
# 632            16 GB LPDDR5 RAM
# 633                   8 GB  RAM
# 634              16 GB DDR4 RAM
# 635               8 GB DDR4 RAM
# 636               8 GB DDR4 RAM
# 637               8 GB DDR4 RAM
# 638               8 GB DDR4 RAM
# 639                  18 GB  RAM
# 640                   8 GB  RAM
# 641            16 GB LPDDR5 RAM
# 642            8 GB LPDDR4X RAM
# 643               8 GB DDR4 RAM
# 644            8 GB LPDDR4X RAM
# 645               8 GB DDR4 RAM
# 646           16 GB LPDDR4X RAM
# 647               8 GB DDR4 RAM
# 648              16 GB DDR4 RAM
# 649           16 GB LPDDR4x RAM
# 650              16 GB DDR4 RAM
# 651            8 GB LPDDR4X RAM
# 652              32 GB DDR5 RAM
# 653            16 GB LPDDR5 RAM
# 654             8 GB LPDDR5 RAM
# 655               8 GB DDR4 RAM
# 656              16 GB DDR4 RAM
# 657              16 GB DDR5 RAM
# 658              16 GB DDR4 RAM
# 659              16 GB DDR4 RAM
# 660             8 GB LPDDR5 RAM
# 661              16 GB DDR4 RAM
# 662              16 GB DDR4 RAM
# 663              16 GB DDR5 RAM
# 664              16 GB DDR5 RAM
# 665               8 GB DDR4 RAM
# 666              16 GB DDR4 RAM
# 667              16 GB DDR4 RAM
# 668              16 GB DDR5 RAM
# 669               8 GB DDR5 RAM
# 670           16 GB LPDDR4X RAM
# 671              16 GB DDR4 RAM
# 672               8 GB DDR4 RAM
# 673            16 GB LPDDR5 RAM
# 674               8 GB DDR4 RAM
# 675              16 GB DDR4 RAM
# 676              16 GB DDR4 RAM
# 677               8 GB DDR4 RAM
# 678            16 GB LPDDR5 RAM
# 679              16 GB DDR4 RAM
# 680               8 GB DDR4 RAM
# 681              32 GB DDR5 RAM
# 682               8 GB DDR4 RAM
# 683             4 GB LPDDR4 RAM
# 684              16 GB DDR4 RAM
# 685              16 GB DDR4 RAM
# 686               8 GB DDR5 RAM
# 687              16 GB DDR4 RAM
# 688              16 GB DDR4 RAM
# 689              16 GB DDR5 RAM
# 690               8 GB DDR5 RAM
# 691              16 GB DDR5 RAM
# 692               8 GB DDR4 RAM
# 693               8 GB DDR4 RAM
# 694              16 GB DDR4 RAM
# 695               4 GB DDR4 RAM
# 696              16 GB DDR4 RAM
# 697               8 GB DDR4 RAM
# 698            8 GB LPDDR5  RAM
# 699               8 GB DDR4 RAM
# 700              32 GB DDR5 RAM
# 701            16 GB LPDDR5 RAM
# 702              16 GB DDR5 RAM
# 703              16 GB DDR4 RAM
# 704             8 GB LPDDR5 RAM
# 705            16 GB LPDDR5 RAM
# 706              64 GB DDR5 RAM
# 707               8 GB DDR4 RAM
# 708           16 GB LPDDR4X RAM
# 709              16 GB DDR5 RAM
# 710              8 GB DDR4  RAM
# 711             8 GB LPDDR5 RAM
# 712              16 GB DDR5 RAM
# 713              16 GB DDR4 RAM
# 714            8 GB LPDDR4X RAM
# 715              16 GB DDR4 RAM
# 716              16 GB DDR4 RAM
# 717               8 GB DDR4 RAM
# 718              16 GB DDR4 RAM
# 719             8 GB LPDDR5 RAM
# 720               8 GB DDR4 RAM
# 721             8 GB LPDDR5 RAM
# 722              32 GB DDR5 RAM
# 723               8 GB DDR4 RAM
# 724               8 GB DDR4 RAM
# 725                  16 GB  RAM
# 726             8 GB LPDDR5 RAM
# 727           16 GB LPDDR4X RAM
# 728               8 GB DDR4 RAM
# 729              16 GB DDR5 RAM
# 730              16 GB DDR4 RAM
# 731              16 GB DDR4 RAM
# 732               8 GB DDR4 RAM
# 733           16 GB LPDDR4X RAM
# 734              16 GB DDR4 RAM
# 735               8 GB DDR4 RAM
# 736              16 GB DDR5 RAM
# 737              16 GB DDR5 RAM
# 738              16 GB DDR4 RAM
# 739              16 GB DDR4 RAM
# 740                   8 GB  RAM
# 741              16 GB DDR4 RAM
# 742           16 GB  LPDDR5 RAM
# 743           16 GB  LPDDR5 RAM
# 744              32 GB DDR5 RAM
# 745             8 GB LPDDR5 RAM
# 746           16 GB LPDDR4X RAM
# 747               8 GB DDR4 RAM
# 748              16 GB DDR5 RAM
# 749              16 GB DDR5 RAM
# 750             8 GB LPDDR4 RAM
# 751              16 GB DDR4 RAM
# 752               8 GB DDR5 RAM
# 753               8 GB DDR4 RAM
# 754            16 GB LPDDR5 RAM
# 755                  16 GB  RAM
# 756              16 GB DDR4 RAM
# 757              16 GB DDR4 RAM
# 758               8 GB DDR4 RAM
# 759              16 GB DDR4 RAM
# Name: ram, dtype: object

# %%
df['ram_type']=df['ram'].str.split("RAM").str[0].str.split("GB").str[-1]

# %%
df['ram_type'].value_counts()
# Out:
# ram_type
# DDR4               444
# DDR5               113
# LPDDR5              83
# LPDDR4X             31
#                     21
# LPDDR4              18
# LPDDR4x             11
#  LPDDR5              8
# DDR4                 7
# LPDDR5               6
# Unified Memory       4
# LPDDR5X              4
# SSD                  2
# DDR5 SD              1
# LPDDR5x              1
# LPDDR4x              1
# DDR3                 1
# DDR5                 1
# DDR4-                1
# ‎LPDDR4              1
# Name: count, dtype: int64

# %%
df['ram_type']=df['ram_type'].str.strip()

# %%
df['ram_type']=df['ram_type'].replace("LPDDR4x","LPDDR4X")

# %%
df['ram_type']=df['ram_type'].replace("LPDDR5x","LPDDR5X")

# %%
df['ram_type']=df['ram_type'].replace("DDR4-","DDR4")

# %%
df['ram_type']=df['ram_type'].replace("DDR5 SD","DDR5")

# %%
df['ram_type'].fillna("",inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3036\1530386723.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ram_type'].fillna("",inplace=True)

# %%
df['ram_type']=df['ram_type'].apply(lambda x:"LPDDR4" if "LPDDR4" in x and "X" not in x else x)

# %%
df['ram_type'].value_counts()
# Out:
# ram_type
# DDR4              452
# DDR5              115
# LPDDR5             97
# LPDDR4X            43
#                    22
# LPDDR4             19
# LPDDR5X             5
# Unified Memory      4
# SSD                 2
# DDR3                1
# Name: count, dtype: int64

# %%
df['ram_type']=df['ram_type'].replace("",np.nan)

# %%
df['rom_gb']=df['rom'].str.split("GB").str[0]

# %%
df['rom_gb'].value_counts()
# Out:
# rom_gb
# 1 TB Hard Disk256     13
# 512                    1
# Name: count, dtype: int64

# %%
temp_df13=df[df['rom_gb'].str.contains("SSD")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 temp_df13=df[df['rom_gb'].str.contains("SSD")]
#
# File c:\Users\LENOVO\OneDrive\Desktop\Walmart-Project\my_env1\Lib\site-packages\pandas\core\frame.py:4103, in DataFrame.__getitem__(self, key)
#    4100     return self.where(key)
#    4102 # Do we have a (boolean) 1d indexer?
# -> 4103 if com.is_bool_indexer(key):
#    4104     return self._getitem_bool_array(key)
#    4106 # We are left with two options: a single key, and a collection of keys,
#    4107 # We interpret tuples as collections only for non-MultiIndex
#
# File c:\Users\LENOVO\OneDrive\Desktop\Walmart-Project\my_env1\Lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
#     135         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136         raise ValueError(na_msg)
#     137     return False
#     138 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
df['rom_gb']=1024

# %%
df.head()
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  rom  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM  NaN
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM  NaN
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM  NaN
# 4                15.6 inches, 1920 x 1080 pixels    16 GB DDR4 RAM  NaN
#
#           warranty  rating  ...                     intel_core   brand  \
# 0  1 Year Warranty    73.0  ...      5th Gen AMD Ryzen 5 5600H      HP
# 1  1 Year Warranty    60.0  ...   12th Gen Intel Core i3 1215U      HP
# 2  1 Year Warranty    66.0  ...   12th Gen Intel Core i5 1240P  Lenovo
# 3  1 Year Warranty    71.0  ...  11th Gen Intel Core i5 11300H  Lenovo
# 4  1 Year Warranty    64.0  ...  11th Gen Intel Core i5 1155G7    Acer
#
#        Touchscreen      Gaming display_inches  resolution_width  \
# 0      touchscreen      gaming           15.6              1920
# 1  not-touchscreen  not-gaming           15.6              1920
# 2  not-touchscreen  not-gaming           14.0              2240
# 3  not-touchscreen      gaming           15.6              1920
# 4  not-touchscreen  not-gaming           15.6              1920
#
#    resolution_height  ram_gb ram_type rom_gb
# 0               1080      8      DDR4   1024
# 1               1080      8      DDR4   1024
# 2               1400     16    LPDDR5   1024
# 3               1080      8      DDR4   1024
# 4               1080     16      DDR4   1024
#
# [5 rows x 21 columns]

# %%
df['rom_gb'].value_counts()
# Out:
# rom_gb
# 1024    760
# Name: count, dtype: int64
